# %%
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
import scipy.integrate as integrate
import scipy.optimize as optimize

# %%
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-3-71e12f4bac70>:1: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/michaelmcdermott/.local/share/virtualenvs/python-_2MbXz7b/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/michaelmcdermott/.local/share/virtualenvs/python-_2MbXz7b/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /Users/michaelmcdermott/.local/share/virtualenvs/python-_2MbXz7b/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/michaelmcdermott/.local/share/virtualenvs/python-_2MbXz7b/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/michaelmcdermott/.local/share/virtualenvs/python-_2MbXz7b/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
sess = tf.InteractiveSession()

# %%
saver = tf.train.import_meta_graph('mnist/conv_99_new.meta')

# %%
saver.restore(sess,'mnist/conv_99_new')
# Out:
# INFO:tensorflow:Restoring parameters from mnist/conv_99_new

# %%
print(tf.global_variables())
# Out:
# [<tf.Variable 'Variable:0' shape=(5, 5, 1, 32) dtype=float32_ref>, <tf.Variable 'Variable_1:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Variable_2:0' shape=(5, 5, 32, 64) dtype=float32_ref>, <tf.Variable 'Variable_3:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Variable_4:0' shape=(3136, 1024) dtype=float32_ref>, <tf.Variable 'Variable_5:0' shape=(1024,) dtype=float32_ref>, <tf.Variable 'Variable_6:0' shape=(1024, 10) dtype=float32_ref>, <tf.Variable 'Variable_7:0' shape=(10,) dtype=float32_ref>, <tf.Variable 'beta1_power:0' shape=() dtype=float32_ref>, <tf.Variable 'beta2_power:0' shape=() dtype=float32_ref>, <tf.Variable 'Variable/Adam:0' shape=(5, 5, 1, 32) dtype=float32_ref>, <tf.Variable 'Variable/Adam_1:0' shape=(5, 5, 1, 32) dtype=float32_ref>, <tf.Variable 'Variable_1/Adam:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Variable_1/Adam_1:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Variable_2/Adam:0' shape=(5, 5, 32, 64) dtype=float32_ref>, <tf.Variable 'Variable_2/Adam_1:0' shape=(5, 5, 32, 64) dtype=float32_ref>, <tf.Variable 'Variable_3/Adam:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Variable_3/Adam_1:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Variable_4/Adam:0' shape=(3136, 1024) dtype=float32_ref>, <tf.Variable 'Variable_4/Adam_1:0' shape=(3136, 1024) dtype=float32_ref>, <tf.Variable 'Variable_5/Adam:0' shape=(1024,) dtype=float32_ref>, <tf.Variable 'Variable_5/Adam_1:0' shape=(1024,) dtype=float32_ref>, <tf.Variable 'Variable_6/Adam:0' shape=(1024, 10) dtype=float32_ref>, <tf.Variable 'Variable_6/Adam_1:0' shape=(1024, 10) dtype=float32_ref>, <tf.Variable 'Variable_7/Adam:0' shape=(10,) dtype=float32_ref>, <tf.Variable 'Variable_7/Adam_1:0' shape=(10,) dtype=float32_ref>]

# %%
keep_prob = tf.get_default_graph().get_tensor_by_name("keep_prob:0")
x = tf.get_default_graph().get_tensor_by_name("x:0")
y_conv = tf.get_default_graph().get_tensor_by_name("y_conv:0")
y_conv_s = tf.get_default_graph().get_tensor_by_name("y_conv_s:0")

# %% [markdown]
# # Let's create a 3 pixel shifting image

# %%
pic = mnist.train.images[7]

# %%
plt.imshow(pic.reshape([28,28]))
plt.colorbar()

# %%
def make_pix_pic(coords=[(14,14)]):
    init_pic = np.zeros(784)
    init_pic = init_pic.reshape([28,28])
    for i, co in enumerate(coords):
        init_pic[co] = 0.99
    return init_pic.reshape(784)

# %%
init_pic = np.zeros(784)
init_pic = init_pic.reshape([28,28])
init_pic[14, 10] = 0.9

# %%
plt.imshow(init_pic)
plt.colorbar()

# %% [markdown]
# # Let's compute the geodesics..

# %%
def norm(x):
    return np.sqrt(np.sum(x**2))

# %%
def callbak(x,convergence):
    print('x is: ', x)
    print('val is: ', convergence)

# %%
te=optimize.differential_evolution(norm, bounds=[(0,1), (0,1), (0,1), (0.1,1)], disp=True)
# Out:
# differential_evolution step 1: f(x)= 0.313817
# differential_evolution step 2: f(x)= 0.197091
# differential_evolution step 3: f(x)= 0.197091
# differential_evolution step 4: f(x)= 0.197091
# differential_evolution step 5: f(x)= 0.187837
# differential_evolution step 6: f(x)= 0.187837
# differential_evolution step 7: f(x)= 0.187837
# differential_evolution step 8: f(x)= 0.128526
# differential_evolution step 9: f(x)= 0.128526
# differential_evolution step 10: f(x)= 0.128526
# differential_evolution step 11: f(x)= 0.128526
# differential_evolution step 12: f(x)= 0.128526
# differential_evolution step 13: f(x)= 0.128526
# differential_evolution step 14: f(x)= 0.128526
# differential_evolution step 15: f(x)= 0.128526
# differential_evolution step 16: f(x)= 0.115863
# differential_evolution step 17: f(x)= 0.115863
# differential_evolution step 18: f(x)= 0.115863
# differential_evolution step 19: f(x)= 0.113893
# differential_evolution step 20: f(x)= 0.109933
# differential_evolution step 21: f(x)= 0.107792
# differential_evolution step 22: f(x)= 0.107792
# differential_evolution step 23: f(x)= 0.104619
# differential_evolution step 24: f(x)= 0.103663
# differential_evolution step 25: f(x)= 0.103663
# differential_evolution step 26: f(x)= 0.103663
# differential_evolution step 27: f(x)= 0.101579
# differential_evolution step 28: f(x)= 0.101579
# differential_evolution step 29: f(x)= 0.101346
# differential_evolution step 30: f(x)= 0.101346
# differential_evolution step 31: f(x)= 0.101346
# differential_evolution step 32: f(x)= 0.101346
# differential_evolution step 33: f(x)= 0.100189
# differential_evolution step 34: f(x)= 0.100189
# differential_evolution step 35: f(x)= 0.100189
# differential_evolution step 36: f(x)= 0.100189
# differential_evolution step 37: f(x)= 0.100189
# differential_evolution step 38: f(x)= 0.100189
# differential_evolution step 39: f(x)= 0.100189
# differential_evolution step 40: f(x)= 0.100189
# differential_evolution step 41: f(x)= 0.100189
# differential_evolution step 42: f(x)= 0.100189
# differential_evolution step 43: f(x)= 0.100189
# differential_evolution step 44: f(x)= 0.100189
# differential_evolution step 45: f(x)= 0.100189
# differential_evolution step 46: f(x)= 0.100189
# differential_evolution step 47: f(x)= 0.100096
# differential_evolution step 48: f(x)= 0.100096
# differential_evolution step 49: f(x)= 0.100096
# differential_evolution step 50: f(x)= 0.100096
# differential_evolution step 51: f(x)= 0.100096
# differential_evolution step 52: f(x)= 0.100096
# differential_evolution step 53: f(x)= 0.100087
# differential_evolution step 54: f(x)= 0.100087
# differential_evolution step 55: f(x)= 0.100087
# differential_evolution step 56: f(x)= 0.100057
# differential_evolution step 57: f(x)= 0.100057
# differential_evolution step 58: f(x)= 0.100036

# %%
te
# Out:
#      fun: 0.1
#      jac: array([5.13478149e-08, 5.13478149e-08, 5.13478149e-08, 9.99999999e-01])
#  message: 'Optimization terminated successfully.'
#     nfev: 3550
#      nit: 58
#  success: True
#        x: array([0. , 0. , 0. , 0.1])

# %%
def shift_pic(pic, shift=4):
    return np.roll(pic.reshape([28,28]), shift, axis=1).reshape([784,])

# %%
def apply_scalar_padding(x, unpadded_coords=[(14,15)]):
    pic = np.zeros([28, 28])
    pic[unpadded_coords] = x
    return pic.reshape(784)

# %%
def apply_padding(x, unpadded_coords=[(14, 13), (14,14), (14,15), (14,16)]):
    #pic = np.zeros([28, 28])
    pic = 1/500.*np.random.rand(28, 28)
    for i, coords in enumerate(unpadded_coords):
        pic[coords] = x[i]
    return pic.reshape(784)

# %%
def create_vec_tensor(categories, target = y_conv_s):
    vec_tens = []
    for i in range(categories):
            vec_tens.append(tf.gradients(target[:,i], x)[0])
    return vec_tens

# %%
vec_tens = create_vec_tensor(10)
def compute_vec_grad(pic, vec_tens):
    var_grad = sess.run(vec_tens, feed_dict={x: pic.reshape([1,len(pic)]), keep_prob: 1.0})
    return np.asarray(var_grad).reshape([10, 784])

# %%
def compute_metric(pic, compute_vec_grad=compute_vec_grad, alpha=0.0, beta=1.0):
    vec_grad = compute_vec_grad(pic, vec_tens)
    #vec_grad = vec_grad/np.sqrt(np.sum(vec_grad**2, axis=1)).reshape([10,1])
    return alpha*np.identity(784) + beta*np.dot(np.transpose(vec_grad),vec_grad)

# %%
def interp_integrand(start_pic, end_pic, t, metric=compute_metric):
    curr_pic = (1-t)*start_pic + t*end_pic 
    return np.sqrt( np.dot( np.dot(end_pic-start_pic, metric(curr_pic)), end_pic-start_pic))

# %%
def mid_func(midpoint, startpoint, endpoint, metric=compute_metric):
    i = integrate.romberg(lambda t: interp_integrand(startpoint, midpoint, t) + interp_integrand(midpoint, endpoint, t),0,1, tol=1, rtol=1e-4)
    return i

# %%
def distance_geod(geod):
    print("integrating geodesic")
    length = 0
    for i in range(len(geod)-1):
        length+=integrate.romberg(lambda t: interp_integrand(geod[i], geod[i+1], t), 0, 1, tol=1, rtol=1e-4)

    return length

def distance_geod_array(geod):
    print("integrating geodesic")
    length = []
    for i in range(len(geod)-1):
        length.append(integrate.romberg(lambda t: interp_integrand(geod[i], geod[i+1], t), 0, 1, tol=1, rtol=1e-4))

    return np.asarray(length)

# %%
def minimize_length_step(point_index, geod):
    bounds = [(0,1)]*4
    print('begin diff evolution')
    soln = optimize.differential_evolution(lambda x: mid_func(apply_padding(x), geod[point_index-1,:], geod[point_index+1,:]), bounds=bounds, maxiter=50,popsize=40, recombination=1, disp=True)
    print('end diff evolution')
    print('result was: ', soln['x'])
    return np.asarray(apply_padding(soln['x']))

# %%
#returns the geodesic with first index being the pt index and second being the actual point (or picture in the mnist case)
def divide(startpoint, endpoint, num_internal_pts):
    pt_divs = np.linspace(0, 1, num=num_internal_pts+2)

    geod = np.ones(len(pt_divs)).reshape([len(pt_divs),1])*startpoint.reshape([1,len(startpoint)]) + pt_divs.reshape([len(pt_divs),1])*(endpoint-startpoint).reshape([1,len(startpoint)])
    for pt_index in range(len(pt_divs))[1:-1]:
        geod[pt_index] = make_pix_pic(coords=[(14,14), (14,15)])
    return pt_divs, geod

#each layer computation splits the dividing geodesic line into two straight lines
def compute_geodesic(startpoint, endpoint, num_internal_pts=1, num_passes=1):
    grid, geod = divide(startpoint, endpoint, num_internal_pts)

    for n in range(num_passes):
        r=np.arange(len(grid))[1:-1]
        np.random.shuffle(r)
        for pt_index in r:
            geod[pt_index] = minimize_length_step(pt_index, geod)
    return geod


def refine(geod, num_passes=1, shuffle=True):
    for n in range(num_passes):
        r=np.arange(len(geod))[1:-1]
        if shuffle:
            np.random.shuffle(r)
        for pt_index in r:
            geod[pt_index] = minimize_length_step(pt_index, geod)
    return geod 

def longest_segment_left_id(geod):
    return np.argmax(distance_geod_array(geod))
        

def compute_full_geodesic(startpoint, endpoint, num_internal_pts=1, num_layers=5, num_passes=1):
    if (num_internal_pts != 1) or (num_passes!=1):
        return "Error, num internal pts and num passes must be 1 currently"
    geod = compute_geodesic(startpoint, endpoint, num_internal_pts, num_passes)
    length_layer = []
    length_layer.append(distance_geod(geod))
    for n in range(num_layers):
        #pick index at random
        print("Working on layer: ", n+1)
        #left_index = longest_segment_left_id(geod)
        #left_index = np.random.choice(len(geod)-1)
        left_index = 0
        print("using left index: ", left_index)
        new_geod = compute_geodesic(geod[left_index,:], geod[left_index+1,:], num_internal_pts, num_passes)
        geod = np.insert(geod, left_index+1, new_geod[1,:], axis=0)
        geod = refine(geod, num_passes=2)
        length_layer.append(distance_geod(geod))
    return geod, length_layer

# %%
start_pic = shift_pic(make_pix_pic(),shift=-1)
end_pic =  shift_pic(make_pix_pic(),shift=2)

# %%
plt.imshow(end_pic.reshape([28,28]))
plt.colorbar()

# %%
# bounds = [(0,1)]*3

# soln = optimize.differential_evolution(lambda x: mid_func(apply_padding(x), start_pic, end_pic), bounds=[(0,1),(0,1),(0,1)], maxiter=100,popsize=30, recombination=1, disp=True)

# %%
# soln

# %%
g = compute_full_geodesic(start_pic, end_pic)
# Out:
# begin diff evolution
# differential_evolution step 1: f(x)= 0.170504
# differential_evolution step 2: f(x)= 0.170504
# differential_evolution step 3: f(x)= 0.170504
# differential_evolution step 4: f(x)= 0.169098
# differential_evolution step 5: f(x)= 0.169098
# differential_evolution step 6: f(x)= 0.16554
# differential_evolution step 7: f(x)= 0.159589
# differential_evolution step 8: f(x)= 0.159589
# differential_evolution step 9: f(x)= 0.159589
# differential_evolution step 10: f(x)= 0.159589
# differential_evolution step 11: f(x)= 0.159589
# differential_evolution step 12: f(x)= 0.156936
# differential_evolution step 13: f(x)= 0.156936
# differential_evolution step 14: f(x)= 0.156936
# differential_evolution step 15: f(x)= 0.156696
# differential_evolution step 16: f(x)= 0.156696
# differential_evolution step 17: f(x)= 0.156364
# differential_evolution step 18: f(x)= 0.15634
# differential_evolution step 19: f(x)= 0.15634
# differential_evolution step 20: f(x)= 0.15634
# differential_evolution step 21: f(x)= 0.15634
# differential_evolution step 22: f(x)= 0.156211
# differential_evolution step 23: f(x)= 0.156211
# differential_evolution step 24: f(x)= 0.153782
# differential_evolution step 25: f(x)= 0.152617
# differential_evolution step 26: f(x)= 0.152617
# differential_evolution step 27: f(x)= 0.152617
# differential_evolution step 28: f(x)= 0.152617
# differential_evolution step 29: f(x)= 0.152579
# differential_evolution step 30: f(x)= 0.152579
# differential_evolution step 31: f(x)= 0.152579
# differential_evolution step 32: f(x)= 0.152579
# differential_evolution step 33: f(x)= 0.152579
# differential_evolution step 34: f(x)= 0.152579
# differential_evolution step 35: f(x)= 0.152579
# differential_evolution step 36: f(x)= 0.152207
# differential_evolution step 37: f(x)= 0.152207
# differential_evolution step 38: f(x)= 0.152207
# differential_evolution step 39: f(x)= 0.152207
# end diff evolution
# result was:  [0.73357477 0.0685109  0.36410856 0.10700532]
# integrating geodesic
# Working on layer:  1
# using left index:  0
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0703815
# differential_evolution step 2: f(x)= 0.0635988
# differential_evolution step 3: f(x)= 0.0635988
# differential_evolution step 4: f(x)= 0.0550566
# differential_evolution step 5: f(x)= 0.0550566
# differential_evolution step 6: f(x)= 0.051898
# differential_evolution step 7: f(x)= 0.051898
# differential_evolution step 8: f(x)= 0.0518493
# differential_evolution step 9: f(x)= 0.0498346
# differential_evolution step 10: f(x)= 0.0498346
# differential_evolution step 11: f(x)= 0.0498346
# differential_evolution step 12: f(x)= 0.0498346
# differential_evolution step 13: f(x)= 0.0492607
# differential_evolution step 14: f(x)= 0.0492607
# differential_evolution step 15: f(x)= 0.0492607
# differential_evolution step 16: f(x)= 0.0478577
# differential_evolution step 17: f(x)= 0.0478577
# differential_evolution step 18: f(x)= 0.0478577
# differential_evolution step 19: f(x)= 0.0478577
# differential_evolution step 20: f(x)= 0.0478577
# differential_evolution step 21: f(x)= 0.0478577
# differential_evolution step 22: f(x)= 0.0467199
# differential_evolution step 23: f(x)= 0.0467199
# differential_evolution step 24: f(x)= 0.0467199
# differential_evolution step 25: f(x)= 0.0467199
# differential_evolution step 26: f(x)= 0.0467199
# differential_evolution step 27: f(x)= 0.0465862
# differential_evolution step 28: f(x)= 0.0465862
# differential_evolution step 29: f(x)= 0.0465862
# differential_evolution step 30: f(x)= 0.0465862
# differential_evolution step 31: f(x)= 0.0465862
# differential_evolution step 32: f(x)= 0.0465862
# differential_evolution step 33: f(x)= 0.0465862
# differential_evolution step 34: f(x)= 0.0465862
# differential_evolution step 35: f(x)= 0.0465496
# differential_evolution step 36: f(x)= 0.0465496
# differential_evolution step 37: f(x)= 0.0465496
# differential_evolution step 38: f(x)= 0.0465496
# differential_evolution step 39: f(x)= 0.0465496
# differential_evolution step 40: f(x)= 0.0465496
# differential_evolution step 41: f(x)= 0.0465496
# differential_evolution step 42: f(x)= 0.0465496
# differential_evolution step 43: f(x)= 0.0465496
# differential_evolution step 44: f(x)= 0.0465496
# differential_evolution step 45: f(x)= 0.0465496
# differential_evolution step 46: f(x)= 0.0465496
# differential_evolution step 47: f(x)= 0.0465496
# differential_evolution step 48: f(x)= 0.0465496
# differential_evolution step 49: f(x)= 0.0465496
# differential_evolution step 50: f(x)= 0.0465496
# end diff evolution
# result was:  [0.74470281 0.06919907 0.33982386 0.10504131]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.062705
# differential_evolution step 2: f(x)= 0.062705
# differential_evolution step 3: f(x)= 0.0532343
# differential_evolution step 4: f(x)= 0.0519631
# differential_evolution step 5: f(x)= 0.0515855
# differential_evolution step 6: f(x)= 0.0502827
# differential_evolution step 7: f(x)= 0.0493483
# differential_evolution step 8: f(x)= 0.0493483
# differential_evolution step 9: f(x)= 0.0493483
# differential_evolution step 10: f(x)= 0.0490124
# differential_evolution step 11: f(x)= 0.0485082
# differential_evolution step 12: f(x)= 0.0485082
# differential_evolution step 13: f(x)= 0.0481783
# differential_evolution step 14: f(x)= 0.0481783
# differential_evolution step 15: f(x)= 0.0481783
# differential_evolution step 16: f(x)= 0.0474616
# differential_evolution step 17: f(x)= 0.0474616
# differential_evolution step 18: f(x)= 0.0474616
# differential_evolution step 19: f(x)= 0.0474616
# differential_evolution step 20: f(x)= 0.0474616
# differential_evolution step 21: f(x)= 0.0474616
# differential_evolution step 22: f(x)= 0.0474616
# differential_evolution step 23: f(x)= 0.0474616
# differential_evolution step 24: f(x)= 0.0474616
# differential_evolution step 25: f(x)= 0.0474616
# differential_evolution step 26: f(x)= 0.0474616
# differential_evolution step 27: f(x)= 0.0474616
# differential_evolution step 28: f(x)= 0.0474616
# differential_evolution step 29: f(x)= 0.0474616
# differential_evolution step 30: f(x)= 0.0474616
# differential_evolution step 31: f(x)= 0.0474616
# differential_evolution step 32: f(x)= 0.0472146
# differential_evolution step 33: f(x)= 0.0472146
# differential_evolution step 34: f(x)= 0.0472146
# differential_evolution step 35: f(x)= 0.0472146
# differential_evolution step 36: f(x)= 0.0472146
# end diff evolution
# result was:  [0.8832646  0.04439832 0.14233574 0.02122606]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.174485
# differential_evolution step 2: f(x)= 0.152237
# differential_evolution step 3: f(x)= 0.152237
# differential_evolution step 4: f(x)= 0.147146
# differential_evolution step 5: f(x)= 0.145619
# differential_evolution step 6: f(x)= 0.145619
# differential_evolution step 7: f(x)= 0.145271
# differential_evolution step 8: f(x)= 0.139801
# differential_evolution step 9: f(x)= 0.139801
# differential_evolution step 10: f(x)= 0.139801
# differential_evolution step 11: f(x)= 0.139801
# differential_evolution step 12: f(x)= 0.139801
# differential_evolution step 13: f(x)= 0.139427
# differential_evolution step 14: f(x)= 0.139373
# differential_evolution step 15: f(x)= 0.139373
# differential_evolution step 16: f(x)= 0.138365
# differential_evolution step 17: f(x)= 0.138365
# differential_evolution step 18: f(x)= 0.13833
# differential_evolution step 19: f(x)= 0.138037
# differential_evolution step 20: f(x)= 0.129022
# differential_evolution step 21: f(x)= 0.129022
# differential_evolution step 22: f(x)= 0.129022
# differential_evolution step 23: f(x)= 0.127751
# differential_evolution step 24: f(x)= 0.127751
# differential_evolution step 25: f(x)= 0.127751
# differential_evolution step 26: f(x)= 0.127751
# differential_evolution step 27: f(x)= 0.127751
# differential_evolution step 28: f(x)= 0.127751
# differential_evolution step 29: f(x)= 0.127751
# differential_evolution step 30: f(x)= 0.127751
# differential_evolution step 31: f(x)= 0.127034
# differential_evolution step 32: f(x)= 0.126577
# differential_evolution step 33: f(x)= 0.126577
# differential_evolution step 34: f(x)= 0.126577
# differential_evolution step 35: f(x)= 0.126067
# differential_evolution step 36: f(x)= 0.125753
# differential_evolution step 37: f(x)= 0.125753
# differential_evolution step 38: f(x)= 0.125753
# differential_evolution step 39: f(x)= 0.124504
# differential_evolution step 40: f(x)= 0.124504
# differential_evolution step 41: f(x)= 0.124504
# differential_evolution step 42: f(x)= 0.124504
# differential_evolution step 43: f(x)= 0.124504
# differential_evolution step 44: f(x)= 0.124504
# differential_evolution step 45: f(x)= 0.124504
# differential_evolution step 46: f(x)= 0.124504
# end diff evolution
# result was:  [0.76910166 0.13749132 0.27598321 0.02158305]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0637795
# differential_evolution step 2: f(x)= 0.0522393
# differential_evolution step 3: f(x)= 0.0443919
# differential_evolution step 4: f(x)= 0.0438947
# differential_evolution step 5: f(x)= 0.0438947
# differential_evolution step 6: f(x)= 0.0414377
# differential_evolution step 7: f(x)= 0.0381632
# differential_evolution step 8: f(x)= 0.0381632
# differential_evolution step 9: f(x)= 0.0381632
# differential_evolution step 10: f(x)= 0.0381632
# differential_evolution step 11: f(x)= 0.0381632
# differential_evolution step 12: f(x)= 0.0368084
# differential_evolution step 13: f(x)= 0.0368084
# differential_evolution step 14: f(x)= 0.0368084
# differential_evolution step 15: f(x)= 0.0366829
# differential_evolution step 16: f(x)= 0.0366829
# differential_evolution step 17: f(x)= 0.036322
# differential_evolution step 18: f(x)= 0.036322
# differential_evolution step 19: f(x)= 0.0362776
# differential_evolution step 20: f(x)= 0.0362616
# differential_evolution step 21: f(x)= 0.0362616
# differential_evolution step 22: f(x)= 0.0362616
# differential_evolution step 23: f(x)= 0.0362616
# differential_evolution step 24: f(x)= 0.0362616
# differential_evolution step 25: f(x)= 0.0362592
# differential_evolution step 26: f(x)= 0.0362592
# differential_evolution step 27: f(x)= 0.0360593
# differential_evolution step 28: f(x)= 0.0360324
# differential_evolution step 29: f(x)= 0.0358536
# differential_evolution step 30: f(x)= 0.0353176
# differential_evolution step 31: f(x)= 0.0353176
# differential_evolution step 32: f(x)= 0.0353176
# differential_evolution step 33: f(x)= 0.0353176
# differential_evolution step 34: f(x)= 0.0353176
# differential_evolution step 35: f(x)= 0.0353176
# differential_evolution step 36: f(x)= 0.0353176
# differential_evolution step 37: f(x)= 0.0353176
# differential_evolution step 38: f(x)= 0.0353176
# differential_evolution step 39: f(x)= 0.0353176
# end diff evolution
# result was:  [0.88355346 0.04313197 0.14730992 0.03144588]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.150719
# differential_evolution step 2: f(x)= 0.150598
# differential_evolution step 3: f(x)= 0.143958
# differential_evolution step 4: f(x)= 0.143682
# differential_evolution step 5: f(x)= 0.142532
# differential_evolution step 6: f(x)= 0.142532
# differential_evolution step 7: f(x)= 0.136979
# differential_evolution step 8: f(x)= 0.129989
# differential_evolution step 9: f(x)= 0.129989
# differential_evolution step 10: f(x)= 0.129989
# differential_evolution step 11: f(x)= 0.129989
# differential_evolution step 12: f(x)= 0.128857
# differential_evolution step 13: f(x)= 0.127907
# differential_evolution step 14: f(x)= 0.125703
# differential_evolution step 15: f(x)= 0.125703
# differential_evolution step 16: f(x)= 0.125703
# differential_evolution step 17: f(x)= 0.125703
# differential_evolution step 18: f(x)= 0.125518
# differential_evolution step 19: f(x)= 0.125518
# differential_evolution step 20: f(x)= 0.125357
# differential_evolution step 21: f(x)= 0.124863
# differential_evolution step 22: f(x)= 0.124863
# differential_evolution step 23: f(x)= 0.124501
# differential_evolution step 24: f(x)= 0.124501
# differential_evolution step 25: f(x)= 0.124501
# end diff evolution
# result was:  [0.77152565 0.13954672 0.27128295 0.02568543]
# integrating geodesic
# Working on layer:  2
# using left index:  0
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0614386
# differential_evolution step 2: f(x)= 0.0332041
# differential_evolution step 3: f(x)= 0.0332041
# differential_evolution step 4: f(x)= 0.0332041
# differential_evolution step 5: f(x)= 0.0332041
# differential_evolution step 6: f(x)= 0.0332041
# differential_evolution step 7: f(x)= 0.0323524
# differential_evolution step 8: f(x)= 0.022893
# differential_evolution step 9: f(x)= 0.0223081
# differential_evolution step 10: f(x)= 0.0223081
# differential_evolution step 11: f(x)= 0.0222861
# differential_evolution step 12: f(x)= 0.0222861
# differential_evolution step 13: f(x)= 0.0222861
# differential_evolution step 14: f(x)= 0.0222861
# differential_evolution step 15: f(x)= 0.0222861
# differential_evolution step 16: f(x)= 0.0214334
# differential_evolution step 17: f(x)= 0.0214334
# differential_evolution step 18: f(x)= 0.0214334
# differential_evolution step 19: f(x)= 0.0214334
# differential_evolution step 20: f(x)= 0.0214334
# differential_evolution step 21: f(x)= 0.0214334
# differential_evolution step 22: f(x)= 0.0213385
# differential_evolution step 23: f(x)= 0.0213385
# differential_evolution step 24: f(x)= 0.0213385
# differential_evolution step 25: f(x)= 0.0213385
# differential_evolution step 26: f(x)= 0.0213385
# differential_evolution step 27: f(x)= 0.0213385
# differential_evolution step 28: f(x)= 0.0213385
# differential_evolution step 29: f(x)= 0.0213385
# differential_evolution step 30: f(x)= 0.0213385
# differential_evolution step 31: f(x)= 0.0213385
# differential_evolution step 32: f(x)= 0.0212865
# differential_evolution step 33: f(x)= 0.0212865
# differential_evolution step 34: f(x)= 0.0212865
# differential_evolution step 35: f(x)= 0.0212865
# differential_evolution step 36: f(x)= 0.0212865
# differential_evolution step 37: f(x)= 0.0212865
# differential_evolution step 38: f(x)= 0.0212865
# differential_evolution step 39: f(x)= 0.0212865
# differential_evolution step 40: f(x)= 0.0212865
# differential_evolution step 41: f(x)= 0.021114
# differential_evolution step 42: f(x)= 0.021114
# differential_evolution step 43: f(x)= 0.021114
# differential_evolution step 44: f(x)= 0.021114
# differential_evolution step 45: f(x)= 0.021114
# differential_evolution step 46: f(x)= 0.021114
# differential_evolution step 47: f(x)= 0.021114
# differential_evolution step 48: f(x)= 0.021114
# differential_evolution step 49: f(x)= 0.021114
# differential_evolution step 50: f(x)= 0.021114
# end diff evolution
# result was:  [9.28313955e-01 2.52716028e-02 9.33582524e-02 7.10917478e-04]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0639029
# differential_evolution step 2: f(x)= 0.0464251
# differential_evolution step 3: f(x)= 0.0238869
# differential_evolution step 4: f(x)= 0.0238869
# differential_evolution step 5: f(x)= 0.0238869
# differential_evolution step 6: f(x)= 0.0238869
# differential_evolution step 7: f(x)= 0.0238869
# differential_evolution step 8: f(x)= 0.0236368
# differential_evolution step 9: f(x)= 0.0236368
# differential_evolution step 10: f(x)= 0.0236368
# differential_evolution step 11: f(x)= 0.0236368
# differential_evolution step 12: f(x)= 0.0236368
# differential_evolution step 13: f(x)= 0.0230011
# differential_evolution step 14: f(x)= 0.0225793
# differential_evolution step 15: f(x)= 0.0225793
# differential_evolution step 16: f(x)= 0.0225793
# differential_evolution step 17: f(x)= 0.0216416
# differential_evolution step 18: f(x)= 0.0216416
# differential_evolution step 19: f(x)= 0.0210628
# differential_evolution step 20: f(x)= 0.0210628
# differential_evolution step 21: f(x)= 0.0210628
# differential_evolution step 22: f(x)= 0.0208897
# differential_evolution step 23: f(x)= 0.0208897
# differential_evolution step 24: f(x)= 0.0208897
# differential_evolution step 25: f(x)= 0.0208897
# differential_evolution step 26: f(x)= 0.0208897
# differential_evolution step 27: f(x)= 0.0208368
# differential_evolution step 28: f(x)= 0.0208368
# differential_evolution step 29: f(x)= 0.0208368
# differential_evolution step 30: f(x)= 0.0206355
# differential_evolution step 31: f(x)= 0.0206355
# differential_evolution step 32: f(x)= 0.0206355
# differential_evolution step 33: f(x)= 0.0206355
# differential_evolution step 34: f(x)= 0.0206355
# differential_evolution step 35: f(x)= 0.0206355
# differential_evolution step 36: f(x)= 0.0206355
# differential_evolution step 37: f(x)= 0.0206355
# differential_evolution step 38: f(x)= 0.0206355
# differential_evolution step 39: f(x)= 0.0206355
# differential_evolution step 40: f(x)= 0.0206355
# differential_evolution step 41: f(x)= 0.0206355
# differential_evolution step 42: f(x)= 0.0206355
# differential_evolution step 43: f(x)= 0.0206355
# differential_evolution step 44: f(x)= 0.0206355
# differential_evolution step 45: f(x)= 0.0206355
# differential_evolution step 46: f(x)= 0.0206355
# differential_evolution step 47: f(x)= 0.0206355
# differential_evolution step 48: f(x)= 0.0206355
# differential_evolution step 49: f(x)= 0.0206355
# differential_evolution step 50: f(x)= 0.0206355
# end diff evolution
# result was:  [0.88600755 0.04539314 0.14491366 0.02096077]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0383354
# differential_evolution step 2: f(x)= 0.034775
# differential_evolution step 3: f(x)= 0.026077
# differential_evolution step 4: f(x)= 0.0191744
# differential_evolution step 5: f(x)= 0.0191744
# differential_evolution step 6: f(x)= 0.0191744
# differential_evolution step 7: f(x)= 0.0191744
# differential_evolution step 8: f(x)= 0.0191744
# differential_evolution step 9: f(x)= 0.018276
# differential_evolution step 10: f(x)= 0.018276
# differential_evolution step 11: f(x)= 0.0179774
# differential_evolution step 12: f(x)= 0.0179774
# differential_evolution step 13: f(x)= 0.0179774
# differential_evolution step 14: f(x)= 0.0179774
# differential_evolution step 15: f(x)= 0.0179774
# differential_evolution step 16: f(x)= 0.0179774
# differential_evolution step 17: f(x)= 0.0179774
# differential_evolution step 18: f(x)= 0.0177079
# differential_evolution step 19: f(x)= 0.0177079
# differential_evolution step 20: f(x)= 0.0172606
# differential_evolution step 21: f(x)= 0.0172606
# differential_evolution step 22: f(x)= 0.0172606
# differential_evolution step 23: f(x)= 0.0172606
# differential_evolution step 24: f(x)= 0.0172606
# differential_evolution step 25: f(x)= 0.0172606
# differential_evolution step 26: f(x)= 0.0172606
# differential_evolution step 27: f(x)= 0.0172606
# differential_evolution step 28: f(x)= 0.0172606
# differential_evolution step 29: f(x)= 0.0170373
# differential_evolution step 30: f(x)= 0.0170373
# differential_evolution step 31: f(x)= 0.0170373
# differential_evolution step 32: f(x)= 0.0170373
# differential_evolution step 33: f(x)= 0.0170373
# differential_evolution step 34: f(x)= 0.0170373
# differential_evolution step 35: f(x)= 0.0170373
# differential_evolution step 36: f(x)= 0.0170373
# differential_evolution step 37: f(x)= 0.0170373
# differential_evolution step 38: f(x)= 0.0170373
# differential_evolution step 39: f(x)= 0.0170239
# differential_evolution step 40: f(x)= 0.0170239
# differential_evolution step 41: f(x)= 0.0170239
# differential_evolution step 42: f(x)= 0.0170239
# differential_evolution step 43: f(x)= 0.0170239
# differential_evolution step 44: f(x)= 0.0170239
# differential_evolution step 45: f(x)= 0.0170239
# differential_evolution step 46: f(x)= 0.0170225
# differential_evolution step 47: f(x)= 0.0169182
# differential_evolution step 48: f(x)= 0.0169182
# differential_evolution step 49: f(x)= 0.0169182
# differential_evolution step 50: f(x)= 0.0167076
# end diff evolution
# result was:  [0.8732133  0.05394609 0.13962715 0.03415505]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.161219
# differential_evolution step 2: f(x)= 0.154514
# differential_evolution step 3: f(x)= 0.153365
# differential_evolution step 4: f(x)= 0.151489
# differential_evolution step 5: f(x)= 0.149185
# differential_evolution step 6: f(x)= 0.149185
# differential_evolution step 7: f(x)= 0.149185
# differential_evolution step 8: f(x)= 0.149185
# differential_evolution step 9: f(x)= 0.149185
# differential_evolution step 10: f(x)= 0.148579
# differential_evolution step 11: f(x)= 0.148579
# differential_evolution step 12: f(x)= 0.145764
# differential_evolution step 13: f(x)= 0.1424
# differential_evolution step 14: f(x)= 0.139248
# differential_evolution step 15: f(x)= 0.13797
# differential_evolution step 16: f(x)= 0.13797
# differential_evolution step 17: f(x)= 0.136099
# differential_evolution step 18: f(x)= 0.136099
# differential_evolution step 19: f(x)= 0.136099
# differential_evolution step 20: f(x)= 0.135718
# differential_evolution step 21: f(x)= 0.135718
# differential_evolution step 22: f(x)= 0.135718
# differential_evolution step 23: f(x)= 0.135718
# differential_evolution step 24: f(x)= 0.135718
# differential_evolution step 25: f(x)= 0.135718
# differential_evolution step 26: f(x)= 0.135718
# end diff evolution
# result was:  [0.45808686 0.20942868 0.05409792 0.58158015]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.154567
# differential_evolution step 2: f(x)= 0.154567
# differential_evolution step 3: f(x)= 0.154567
# differential_evolution step 4: f(x)= 0.154567
# differential_evolution step 5: f(x)= 0.154567
# differential_evolution step 6: f(x)= 0.152758
# differential_evolution step 7: f(x)= 0.145268
# differential_evolution step 8: f(x)= 0.143492
# differential_evolution step 9: f(x)= 0.137186
# differential_evolution step 10: f(x)= 0.137186
# differential_evolution step 11: f(x)= 0.137186
# differential_evolution step 12: f(x)= 0.137186
# differential_evolution step 13: f(x)= 0.137186
# differential_evolution step 14: f(x)= 0.137186
# differential_evolution step 15: f(x)= 0.132671
# differential_evolution step 16: f(x)= 0.132671
# differential_evolution step 17: f(x)= 0.131534
# differential_evolution step 18: f(x)= 0.127856
# differential_evolution step 19: f(x)= 0.126789
# differential_evolution step 20: f(x)= 0.125412
# differential_evolution step 21: f(x)= 0.125412
# differential_evolution step 22: f(x)= 0.125196
# differential_evolution step 23: f(x)= 0.124263
# differential_evolution step 24: f(x)= 0.124216
# differential_evolution step 25: f(x)= 0.124174
# differential_evolution step 26: f(x)= 0.124174
# differential_evolution step 27: f(x)= 0.124174
# differential_evolution step 28: f(x)= 0.124174
# differential_evolution step 29: f(x)= 0.124174
# differential_evolution step 30: f(x)= 0.12417
# differential_evolution step 31: f(x)= 0.123962
# differential_evolution step 32: f(x)= 0.123962
# differential_evolution step 33: f(x)= 0.123527
# differential_evolution step 34: f(x)= 0.123527
# end diff evolution
# result was:  [0.77669196 0.1411728  0.26934297 0.02817325]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0685857
# differential_evolution step 2: f(x)= 0.0498522
# differential_evolution step 3: f(x)= 0.0378351
# differential_evolution step 4: f(x)= 0.0316188
# differential_evolution step 5: f(x)= 0.0274513
# differential_evolution step 6: f(x)= 0.0274513
# differential_evolution step 7: f(x)= 0.0237162
# differential_evolution step 8: f(x)= 0.0237162
# differential_evolution step 9: f(x)= 0.0237162
# differential_evolution step 10: f(x)= 0.0237162
# differential_evolution step 11: f(x)= 0.023614
# differential_evolution step 12: f(x)= 0.0221625
# differential_evolution step 13: f(x)= 0.0221625
# differential_evolution step 14: f(x)= 0.0220628
# differential_evolution step 15: f(x)= 0.0218298
# differential_evolution step 16: f(x)= 0.0218298
# differential_evolution step 17: f(x)= 0.0218298
# differential_evolution step 18: f(x)= 0.0214652
# differential_evolution step 19: f(x)= 0.0214652
# differential_evolution step 20: f(x)= 0.0214652
# differential_evolution step 21: f(x)= 0.0214652
# differential_evolution step 22: f(x)= 0.0214652
# differential_evolution step 23: f(x)= 0.0214652
# differential_evolution step 24: f(x)= 0.0214652
# differential_evolution step 25: f(x)= 0.0214652
# differential_evolution step 26: f(x)= 0.0214652
# differential_evolution step 27: f(x)= 0.0214652
# differential_evolution step 28: f(x)= 0.0214652
# differential_evolution step 29: f(x)= 0.0214652
# differential_evolution step 30: f(x)= 0.0214652
# differential_evolution step 31: f(x)= 0.0214652
# differential_evolution step 32: f(x)= 0.0214652
# differential_evolution step 33: f(x)= 0.0214334
# differential_evolution step 34: f(x)= 0.0213968
# differential_evolution step 35: f(x)= 0.0213968
# differential_evolution step 36: f(x)= 0.021257
# differential_evolution step 37: f(x)= 0.021257
# differential_evolution step 38: f(x)= 0.021257
# differential_evolution step 39: f(x)= 0.021257
# differential_evolution step 40: f(x)= 0.021257
# differential_evolution step 41: f(x)= 0.021257
# differential_evolution step 42: f(x)= 0.021257
# differential_evolution step 43: f(x)= 0.021257
# differential_evolution step 44: f(x)= 0.021257
# differential_evolution step 45: f(x)= 0.021257
# differential_evolution step 46: f(x)= 0.021257
# differential_evolution step 47: f(x)= 0.021257
# differential_evolution step 48: f(x)= 0.021257
# differential_evolution step 49: f(x)= 0.021257
# differential_evolution step 50: f(x)= 0.021257
# end diff evolution
# result was:  [0.88404884 0.04810225 0.1386314  0.01704726]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0500167
# differential_evolution step 2: f(x)= 0.0227204
# differential_evolution step 3: f(x)= 0.0227204
# differential_evolution step 4: f(x)= 0.0227204
# differential_evolution step 5: f(x)= 0.0227204
# differential_evolution step 6: f(x)= 0.0190985
# differential_evolution step 7: f(x)= 0.0190985
# differential_evolution step 8: f(x)= 0.0190985
# differential_evolution step 9: f(x)= 0.0183801
# differential_evolution step 10: f(x)= 0.0182601
# differential_evolution step 11: f(x)= 0.0175662
# differential_evolution step 12: f(x)= 0.0167561
# differential_evolution step 13: f(x)= 0.0167376
# differential_evolution step 14: f(x)= 0.0167376
# differential_evolution step 15: f(x)= 0.0167376
# differential_evolution step 16: f(x)= 0.0162103
# differential_evolution step 17: f(x)= 0.0162103
# differential_evolution step 18: f(x)= 0.0161925
# differential_evolution step 19: f(x)= 0.0158212
# differential_evolution step 20: f(x)= 0.0158212
# differential_evolution step 21: f(x)= 0.0158212
# differential_evolution step 22: f(x)= 0.0158212
# differential_evolution step 23: f(x)= 0.0158212
# differential_evolution step 24: f(x)= 0.0158212
# differential_evolution step 25: f(x)= 0.0158212
# differential_evolution step 26: f(x)= 0.0158212
# differential_evolution step 27: f(x)= 0.0157787
# differential_evolution step 28: f(x)= 0.0157787
# differential_evolution step 29: f(x)= 0.0157787
# differential_evolution step 30: f(x)= 0.0157787
# differential_evolution step 31: f(x)= 0.0157787
# differential_evolution step 32: f(x)= 0.0157787
# differential_evolution step 33: f(x)= 0.0157787
# differential_evolution step 34: f(x)= 0.0157787
# differential_evolution step 35: f(x)= 0.0157787
# differential_evolution step 36: f(x)= 0.0157787
# differential_evolution step 37: f(x)= 0.0157787
# differential_evolution step 38: f(x)= 0.0157787
# differential_evolution step 39: f(x)= 0.0157184
# differential_evolution step 40: f(x)= 0.0157184
# differential_evolution step 41: f(x)= 0.0157184
# differential_evolution step 42: f(x)= 0.0157184
# differential_evolution step 43: f(x)= 0.0157184
# differential_evolution step 44: f(x)= 0.0157184
# differential_evolution step 45: f(x)= 0.0157184
# differential_evolution step 46: f(x)= 0.0157184
# differential_evolution step 47: f(x)= 0.0157184
# differential_evolution step 48: f(x)= 0.0157184
# differential_evolution step 49: f(x)= 0.0157184
# differential_evolution step 50: f(x)= 0.0157184
# end diff evolution
# result was:  [0.87984298 0.05433702 0.13420929 0.0187613 ]
# integrating geodesic
# Working on layer:  3
# using left index:  0
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0267893
# differential_evolution step 2: f(x)= 0.0267893
# differential_evolution step 3: f(x)= 0.0267893
# differential_evolution step 4: f(x)= 0.0267893
# differential_evolution step 5: f(x)= 0.0257253
# differential_evolution step 6: f(x)= 0.0257253
# differential_evolution step 7: f(x)= 0.0236053
# differential_evolution step 8: f(x)= 0.0234766
# differential_evolution step 9: f(x)= 0.0234766
# differential_evolution step 10: f(x)= 0.0209401
# differential_evolution step 11: f(x)= 0.0209401
# differential_evolution step 12: f(x)= 0.0209401
# differential_evolution step 13: f(x)= 0.0209401
# differential_evolution step 14: f(x)= 0.0209401
# differential_evolution step 15: f(x)= 0.0209062
# differential_evolution step 16: f(x)= 0.0208187
# differential_evolution step 17: f(x)= 0.0208187
# differential_evolution step 18: f(x)= 0.0208187
# differential_evolution step 19: f(x)= 0.0206088
# differential_evolution step 20: f(x)= 0.0204244
# differential_evolution step 21: f(x)= 0.0204244
# differential_evolution step 22: f(x)= 0.0203208
# differential_evolution step 23: f(x)= 0.0203208
# differential_evolution step 24: f(x)= 0.0202672
# differential_evolution step 25: f(x)= 0.0202672
# differential_evolution step 26: f(x)= 0.0200606
# differential_evolution step 27: f(x)= 0.0200606
# differential_evolution step 28: f(x)= 0.019703
# differential_evolution step 29: f(x)= 0.019703
# differential_evolution step 30: f(x)= 0.019703
# differential_evolution step 31: f(x)= 0.019703
# differential_evolution step 32: f(x)= 0.019703
# differential_evolution step 33: f(x)= 0.019703
# differential_evolution step 34: f(x)= 0.019703
# differential_evolution step 35: f(x)= 0.019703
# differential_evolution step 36: f(x)= 0.019703
# differential_evolution step 37: f(x)= 0.019703
# differential_evolution step 38: f(x)= 0.019703
# differential_evolution step 39: f(x)= 0.019703
# differential_evolution step 40: f(x)= 0.019703
# differential_evolution step 41: f(x)= 0.019703
# differential_evolution step 42: f(x)= 0.019703
# differential_evolution step 43: f(x)= 0.019703
# differential_evolution step 44: f(x)= 0.019703
# differential_evolution step 45: f(x)= 0.019703
# differential_evolution step 46: f(x)= 0.019703
# differential_evolution step 47: f(x)= 0.019703
# differential_evolution step 48: f(x)= 0.019703
# differential_evolution step 49: f(x)= 0.019703
# differential_evolution step 50: f(x)= 0.019703
# end diff evolution
# result was:  [0.92619463 0.02310572 0.09385303 0.00577034]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0727726
# differential_evolution step 2: f(x)= 0.0340718
# differential_evolution step 3: f(x)= 0.0340718
# differential_evolution step 4: f(x)= 0.0265979
# differential_evolution step 5: f(x)= 0.0230182
# differential_evolution step 6: f(x)= 0.0230182
# differential_evolution step 7: f(x)= 0.0230182
# differential_evolution step 8: f(x)= 0.0230182
# differential_evolution step 9: f(x)= 0.0229103
# differential_evolution step 10: f(x)= 0.0229103
# differential_evolution step 11: f(x)= 0.021693
# differential_evolution step 12: f(x)= 0.0213577
# differential_evolution step 13: f(x)= 0.0210347
# differential_evolution step 14: f(x)= 0.0209577
# differential_evolution step 15: f(x)= 0.0200057
# differential_evolution step 16: f(x)= 0.0200057
# differential_evolution step 17: f(x)= 0.0200057
# differential_evolution step 18: f(x)= 0.0200057
# differential_evolution step 19: f(x)= 0.0200057
# differential_evolution step 20: f(x)= 0.0200057
# differential_evolution step 21: f(x)= 0.0200004
# differential_evolution step 22: f(x)= 0.0199257
# differential_evolution step 23: f(x)= 0.0199257
# differential_evolution step 24: f(x)= 0.0199257
# differential_evolution step 25: f(x)= 0.0197666
# differential_evolution step 26: f(x)= 0.0197666
# differential_evolution step 27: f(x)= 0.0197666
# differential_evolution step 28: f(x)= 0.0197666
# differential_evolution step 29: f(x)= 0.0197666
# differential_evolution step 30: f(x)= 0.0197666
# differential_evolution step 31: f(x)= 0.0197666
# differential_evolution step 32: f(x)= 0.0197666
# differential_evolution step 33: f(x)= 0.0197666
# differential_evolution step 34: f(x)= 0.0197666
# differential_evolution step 35: f(x)= 0.0197666
# differential_evolution step 36: f(x)= 0.0197666
# differential_evolution step 37: f(x)= 0.0197187
# differential_evolution step 38: f(x)= 0.0197187
# differential_evolution step 39: f(x)= 0.0197187
# differential_evolution step 40: f(x)= 0.0197187
# differential_evolution step 41: f(x)= 0.0197187
# differential_evolution step 42: f(x)= 0.0197187
# differential_evolution step 43: f(x)= 0.0197187
# differential_evolution step 44: f(x)= 0.0197187
# differential_evolution step 45: f(x)= 0.0197187
# differential_evolution step 46: f(x)= 0.0197187
# differential_evolution step 47: f(x)= 0.0197187
# differential_evolution step 48: f(x)= 0.0197184
# differential_evolution step 49: f(x)= 0.0197184
# differential_evolution step 50: f(x)= 0.0197184
# end diff evolution
# result was:  [9.36495535e-01 8.58403889e-03 9.86417988e-02 2.41064921e-05]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0387542
# differential_evolution step 2: f(x)= 0.0387542
# differential_evolution step 3: f(x)= 0.0176016
# differential_evolution step 4: f(x)= 0.0176016
# differential_evolution step 5: f(x)= 0.0108721
# differential_evolution step 6: f(x)= 0.0108721
# differential_evolution step 7: f(x)= 0.0108721
# differential_evolution step 8: f(x)= 0.00932341
# differential_evolution step 9: f(x)= 0.00932341
# differential_evolution step 10: f(x)= 0.00835427
# differential_evolution step 11: f(x)= 0.00835427
# differential_evolution step 12: f(x)= 0.00779474
# differential_evolution step 13: f(x)= 0.00779474
# differential_evolution step 14: f(x)= 0.00779474
# differential_evolution step 15: f(x)= 0.00772733
# differential_evolution step 16: f(x)= 0.00772733
# differential_evolution step 17: f(x)= 0.00772733
# differential_evolution step 18: f(x)= 0.00772733
# differential_evolution step 19: f(x)= 0.00772733
# differential_evolution step 20: f(x)= 0.00772733
# differential_evolution step 21: f(x)= 0.00772733
# differential_evolution step 22: f(x)= 0.00764939
# differential_evolution step 23: f(x)= 0.00764939
# differential_evolution step 24: f(x)= 0.00764939
# differential_evolution step 25: f(x)= 0.00764939
# differential_evolution step 26: f(x)= 0.00764939
# differential_evolution step 27: f(x)= 0.00764939
# differential_evolution step 28: f(x)= 0.00764939
# differential_evolution step 29: f(x)= 0.00764939
# differential_evolution step 30: f(x)= 0.00764939
# differential_evolution step 31: f(x)= 0.00764939
# differential_evolution step 32: f(x)= 0.00764939
# differential_evolution step 33: f(x)= 0.00760956
# differential_evolution step 34: f(x)= 0.00760956
# differential_evolution step 35: f(x)= 0.00760956
# differential_evolution step 36: f(x)= 0.00760956
# differential_evolution step 37: f(x)= 0.00760956
# differential_evolution step 38: f(x)= 0.00760956
# differential_evolution step 39: f(x)= 0.00760956
# differential_evolution step 40: f(x)= 0.00760956
# differential_evolution step 41: f(x)= 0.00760956
# differential_evolution step 42: f(x)= 0.00760956
# differential_evolution step 43: f(x)= 0.00747469
# differential_evolution step 44: f(x)= 0.00747469
# differential_evolution step 45: f(x)= 0.00747469
# differential_evolution step 46: f(x)= 0.00747469
# differential_evolution step 47: f(x)= 0.00747469
# differential_evolution step 48: f(x)= 0.00747469
# differential_evolution step 49: f(x)= 0.00747469
# differential_evolution step 50: f(x)= 0.00747469
# end diff evolution
# result was:  [0.903994   0.02955028 0.12635378 0.01253952]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.149414
# differential_evolution step 2: f(x)= 0.149414
# differential_evolution step 3: f(x)= 0.148288
# differential_evolution step 4: f(x)= 0.14316
# differential_evolution step 5: f(x)= 0.14316
# differential_evolution step 6: f(x)= 0.14316
# differential_evolution step 7: f(x)= 0.138436
# differential_evolution step 8: f(x)= 0.134918
# differential_evolution step 9: f(x)= 0.131924
# differential_evolution step 10: f(x)= 0.131924
# differential_evolution step 11: f(x)= 0.131924
# differential_evolution step 12: f(x)= 0.131924
# differential_evolution step 13: f(x)= 0.13013
# differential_evolution step 14: f(x)= 0.13013
# differential_evolution step 15: f(x)= 0.128223
# differential_evolution step 16: f(x)= 0.128223
# differential_evolution step 17: f(x)= 0.128223
# differential_evolution step 18: f(x)= 0.128223
# differential_evolution step 19: f(x)= 0.127229
# differential_evolution step 20: f(x)= 0.127229
# differential_evolution step 21: f(x)= 0.127229
# differential_evolution step 22: f(x)= 0.126867
# differential_evolution step 23: f(x)= 0.126639
# differential_evolution step 24: f(x)= 0.125865
# differential_evolution step 25: f(x)= 0.125865
# differential_evolution step 26: f(x)= 0.125865
# differential_evolution step 27: f(x)= 0.125865
# differential_evolution step 28: f(x)= 0.125633
# differential_evolution step 29: f(x)= 0.12548
# differential_evolution step 30: f(x)= 0.125208
# differential_evolution step 31: f(x)= 0.125208
# differential_evolution step 32: f(x)= 0.124775
# differential_evolution step 33: f(x)= 0.124775
# differential_evolution step 34: f(x)= 0.124775
# differential_evolution step 35: f(x)= 0.124775
# end diff evolution
# result was:  [0.77126616 0.13991316 0.26855139 0.02442924]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0462141
# differential_evolution step 2: f(x)= 0.0359147
# differential_evolution step 3: f(x)= 0.0250564
# differential_evolution step 4: f(x)= 0.0250564
# differential_evolution step 5: f(x)= 0.0250564
# differential_evolution step 6: f(x)= 0.0235349
# differential_evolution step 7: f(x)= 0.0235349
# differential_evolution step 8: f(x)= 0.0235349
# differential_evolution step 9: f(x)= 0.0213785
# differential_evolution step 10: f(x)= 0.0213785
# differential_evolution step 11: f(x)= 0.0204171
# differential_evolution step 12: f(x)= 0.0198283
# differential_evolution step 13: f(x)= 0.0198283
# differential_evolution step 14: f(x)= 0.0198283
# differential_evolution step 15: f(x)= 0.0198283
# differential_evolution step 16: f(x)= 0.0191382
# differential_evolution step 17: f(x)= 0.0191382
# differential_evolution step 18: f(x)= 0.0191382
# differential_evolution step 19: f(x)= 0.0191382
# differential_evolution step 20: f(x)= 0.0191382
# differential_evolution step 21: f(x)= 0.0191382
# differential_evolution step 22: f(x)= 0.0191382
# differential_evolution step 23: f(x)= 0.0191382
# differential_evolution step 24: f(x)= 0.0191382
# differential_evolution step 25: f(x)= 0.0191382
# differential_evolution step 26: f(x)= 0.0191382
# differential_evolution step 27: f(x)= 0.0191382
# differential_evolution step 28: f(x)= 0.0191382
# differential_evolution step 29: f(x)= 0.0191382
# differential_evolution step 30: f(x)= 0.0191382
# differential_evolution step 31: f(x)= 0.0191382
# differential_evolution step 32: f(x)= 0.0191382
# differential_evolution step 33: f(x)= 0.0191382
# differential_evolution step 34: f(x)= 0.0191382
# differential_evolution step 35: f(x)= 0.0191382
# differential_evolution step 36: f(x)= 0.0191382
# differential_evolution step 37: f(x)= 0.0191382
# differential_evolution step 38: f(x)= 0.0191382
# differential_evolution step 39: f(x)= 0.0191382
# differential_evolution step 40: f(x)= 0.0191382
# differential_evolution step 41: f(x)= 0.0188632
# differential_evolution step 42: f(x)= 0.0188632
# differential_evolution step 43: f(x)= 0.0188632
# differential_evolution step 44: f(x)= 0.018706
# differential_evolution step 45: f(x)= 0.018706
# differential_evolution step 46: f(x)= 0.018706
# differential_evolution step 47: f(x)= 0.018706
# differential_evolution step 48: f(x)= 0.018706
# differential_evolution step 49: f(x)= 0.018706
# differential_evolution step 50: f(x)= 0.018706
# end diff evolution
# result was:  [0.8807141  0.04719096 0.14668586 0.0299775 ]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0683115
# differential_evolution step 2: f(x)= 0.0153506
# differential_evolution step 3: f(x)= 0.0153506
# differential_evolution step 4: f(x)= 0.0097472
# differential_evolution step 5: f(x)= 0.0097472
# differential_evolution step 6: f(x)= 0.0097472
# differential_evolution step 7: f(x)= 0.0097472
# differential_evolution step 8: f(x)= 0.00932271
# differential_evolution step 9: f(x)= 0.00932271
# differential_evolution step 10: f(x)= 0.00927282
# differential_evolution step 11: f(x)= 0.00912656
# differential_evolution step 12: f(x)= 0.00904769
# differential_evolution step 13: f(x)= 0.00898202
# differential_evolution step 14: f(x)= 0.00846024
# differential_evolution step 15: f(x)= 0.00846024
# differential_evolution step 16: f(x)= 0.00846024
# differential_evolution step 17: f(x)= 0.00846024
# differential_evolution step 18: f(x)= 0.00846024
# differential_evolution step 19: f(x)= 0.00846024
# differential_evolution step 20: f(x)= 0.0081438
# differential_evolution step 21: f(x)= 0.0081438
# differential_evolution step 22: f(x)= 0.0081438
# differential_evolution step 23: f(x)= 0.0081438
# differential_evolution step 24: f(x)= 0.0081438
# differential_evolution step 25: f(x)= 0.0081438
# differential_evolution step 26: f(x)= 0.0081438
# differential_evolution step 27: f(x)= 0.0081438
# differential_evolution step 28: f(x)= 0.0081438
# differential_evolution step 29: f(x)= 0.0081438
# differential_evolution step 30: f(x)= 0.0081438
# differential_evolution step 31: f(x)= 0.0081438
# differential_evolution step 32: f(x)= 0.00811848
# differential_evolution step 33: f(x)= 0.00811848
# differential_evolution step 34: f(x)= 0.00811848
# differential_evolution step 35: f(x)= 0.00811848
# differential_evolution step 36: f(x)= 0.00811848
# differential_evolution step 37: f(x)= 0.00811848
# differential_evolution step 38: f(x)= 0.00811848
# differential_evolution step 39: f(x)= 0.00811848
# differential_evolution step 40: f(x)= 0.00811848
# differential_evolution step 41: f(x)= 0.00811848
# differential_evolution step 42: f(x)= 0.00811848
# differential_evolution step 43: f(x)= 0.00811848
# differential_evolution step 44: f(x)= 0.00811848
# differential_evolution step 45: f(x)= 0.00811848
# differential_evolution step 46: f(x)= 0.00811848
# differential_evolution step 47: f(x)= 0.00811848
# differential_evolution step 48: f(x)= 0.00811848
# differential_evolution step 49: f(x)= 0.00811848
# differential_evolution step 50: f(x)= 0.00801278
# end diff evolution
# result was:  [0.90984865 0.03316857 0.10941913 0.00462478]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0640935
# differential_evolution step 2: f(x)= 0.0455885
# differential_evolution step 3: f(x)= 0.0455885
# differential_evolution step 4: f(x)= 0.025012
# differential_evolution step 5: f(x)= 0.025012
# differential_evolution step 6: f(x)= 0.025012
# differential_evolution step 7: f(x)= 0.020151
# differential_evolution step 8: f(x)= 0.020151
# differential_evolution step 9: f(x)= 0.0177683
# differential_evolution step 10: f(x)= 0.0177683
# differential_evolution step 11: f(x)= 0.0177683
# differential_evolution step 12: f(x)= 0.0174322
# differential_evolution step 13: f(x)= 0.0163988
# differential_evolution step 14: f(x)= 0.0163988
# differential_evolution step 15: f(x)= 0.0163988
# differential_evolution step 16: f(x)= 0.0163988
# differential_evolution step 17: f(x)= 0.0163988
# differential_evolution step 18: f(x)= 0.0163988
# differential_evolution step 19: f(x)= 0.0162007
# differential_evolution step 20: f(x)= 0.0162007
# differential_evolution step 21: f(x)= 0.0162007
# differential_evolution step 22: f(x)= 0.0162007
# differential_evolution step 23: f(x)= 0.0161834
# differential_evolution step 24: f(x)= 0.0161834
# differential_evolution step 25: f(x)= 0.0157651
# differential_evolution step 26: f(x)= 0.0157651
# differential_evolution step 27: f(x)= 0.0157651
# differential_evolution step 28: f(x)= 0.0157651
# differential_evolution step 29: f(x)= 0.0157651
# differential_evolution step 30: f(x)= 0.0157651
# differential_evolution step 31: f(x)= 0.0157651
# differential_evolution step 32: f(x)= 0.0157651
# differential_evolution step 33: f(x)= 0.0157651
# differential_evolution step 34: f(x)= 0.0157651
# differential_evolution step 35: f(x)= 0.0157651
# differential_evolution step 36: f(x)= 0.0157651
# differential_evolution step 37: f(x)= 0.0157651
# differential_evolution step 38: f(x)= 0.0157651
# differential_evolution step 39: f(x)= 0.0157651
# differential_evolution step 40: f(x)= 0.0157651
# differential_evolution step 41: f(x)= 0.0157651
# differential_evolution step 42: f(x)= 0.0157651
# differential_evolution step 43: f(x)= 0.0157651
# differential_evolution step 44: f(x)= 0.0157651
# differential_evolution step 45: f(x)= 0.0157651
# differential_evolution step 46: f(x)= 0.0157651
# differential_evolution step 47: f(x)= 0.0157651
# differential_evolution step 48: f(x)= 0.0157651
# differential_evolution step 49: f(x)= 0.0157651
# differential_evolution step 50: f(x)= 0.0157651
# end diff evolution
# result was:  [0.92984536 0.02305989 0.09570325 0.0014377 ]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0414188
# differential_evolution step 2: f(x)= 0.0304791
# differential_evolution step 3: f(x)= 0.0304791
# differential_evolution step 4: f(x)= 0.0304791
# differential_evolution step 5: f(x)= 0.0244054
# differential_evolution step 6: f(x)= 0.0237904
# differential_evolution step 7: f(x)= 0.0237904
# differential_evolution step 8: f(x)= 0.0237904
# differential_evolution step 9: f(x)= 0.0217314
# differential_evolution step 10: f(x)= 0.0217314
# differential_evolution step 11: f(x)= 0.0217314
# differential_evolution step 12: f(x)= 0.0217314
# differential_evolution step 13: f(x)= 0.0215076
# differential_evolution step 14: f(x)= 0.0213077
# differential_evolution step 15: f(x)= 0.0210355
# differential_evolution step 16: f(x)= 0.0210355
# differential_evolution step 17: f(x)= 0.0210355
# differential_evolution step 18: f(x)= 0.0210355
# differential_evolution step 19: f(x)= 0.0210355
# differential_evolution step 20: f(x)= 0.0210355
# differential_evolution step 21: f(x)= 0.0210355
# differential_evolution step 22: f(x)= 0.0209734
# differential_evolution step 23: f(x)= 0.0209734
# differential_evolution step 24: f(x)= 0.0209734
# differential_evolution step 25: f(x)= 0.0209734
# differential_evolution step 26: f(x)= 0.0209734
# differential_evolution step 27: f(x)= 0.0209734
# differential_evolution step 28: f(x)= 0.0209734
# differential_evolution step 29: f(x)= 0.0209734
# differential_evolution step 30: f(x)= 0.0209734
# differential_evolution step 31: f(x)= 0.0209734
# differential_evolution step 32: f(x)= 0.0209734
# differential_evolution step 33: f(x)= 0.0209734
# differential_evolution step 34: f(x)= 0.0209734
# differential_evolution step 35: f(x)= 0.0209283
# differential_evolution step 36: f(x)= 0.0209283
# differential_evolution step 37: f(x)= 0.0209283
# differential_evolution step 38: f(x)= 0.0209283
# differential_evolution step 39: f(x)= 0.0209283
# differential_evolution step 40: f(x)= 0.0209075
# differential_evolution step 41: f(x)= 0.0206788
# differential_evolution step 42: f(x)= 0.0201895
# differential_evolution step 43: f(x)= 0.0201895
# differential_evolution step 44: f(x)= 0.0201895
# differential_evolution step 45: f(x)= 0.0201895
# differential_evolution step 46: f(x)= 0.0201895
# differential_evolution step 47: f(x)= 0.0201895
# differential_evolution step 48: f(x)= 0.0201895
# differential_evolution step 49: f(x)= 0.0201895
# differential_evolution step 50: f(x)= 0.0201895
# end diff evolution
# result was:  [0.8833921  0.04501685 0.14327544 0.02563658]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.151838
# differential_evolution step 2: f(x)= 0.151838
# differential_evolution step 3: f(x)= 0.15073
# differential_evolution step 4: f(x)= 0.15073
# differential_evolution step 5: f(x)= 0.147122
# differential_evolution step 6: f(x)= 0.147122
# differential_evolution step 7: f(x)= 0.147122
# differential_evolution step 8: f(x)= 0.137434
# differential_evolution step 9: f(x)= 0.137434
# differential_evolution step 10: f(x)= 0.137434
# differential_evolution step 11: f(x)= 0.137434
# differential_evolution step 12: f(x)= 0.136271
# differential_evolution step 13: f(x)= 0.132804
# differential_evolution step 14: f(x)= 0.132804
# differential_evolution step 15: f(x)= 0.132804
# differential_evolution step 16: f(x)= 0.132804
# differential_evolution step 17: f(x)= 0.132804
# differential_evolution step 18: f(x)= 0.127336
# differential_evolution step 19: f(x)= 0.126752
# differential_evolution step 20: f(x)= 0.126752
# differential_evolution step 21: f(x)= 0.126752
# differential_evolution step 22: f(x)= 0.126752
# differential_evolution step 23: f(x)= 0.125375
# differential_evolution step 24: f(x)= 0.125375
# differential_evolution step 25: f(x)= 0.124592
# differential_evolution step 26: f(x)= 0.124592
# differential_evolution step 27: f(x)= 0.124592
# differential_evolution step 28: f(x)= 0.12349
# differential_evolution step 29: f(x)= 0.12349
# differential_evolution step 30: f(x)= 0.12349
# differential_evolution step 31: f(x)= 0.12349
# ...
# differential_evolution step 30: f(x)= 0.00868892
# differential_evolution step 31: f(x)= 0.00868892
# differential_evolution step 32: f(x)= 0.00868892
# differential_evolution step 33: f(x)= 0.00868892
# differential_evolution step 34: f(x)= 0.00868892
# differential_evolution step 35: f(x)= 0.00868892
# differential_evolution step 36: f(x)= 0.00868892
# differential_evolution step 37: f(x)= 0.00867915
# differential_evolution step 38: f(x)= 0.00867915
# differential_evolution step 39: f(x)= 0.00867915
# differential_evolution step 40: f(x)= 0.00867915
# differential_evolution step 41: f(x)= 0.00867915
# differential_evolution step 42: f(x)= 0.00867915
# differential_evolution step 43: f(x)= 0.00867915
# differential_evolution step 44: f(x)= 0.00867915
# differential_evolution step 45: f(x)= 0.00867915
# differential_evolution step 46: f(x)= 0.00867915
# differential_evolution step 47: f(x)= 0.00867915
# differential_evolution step 48: f(x)= 0.0086022
# differential_evolution step 49: f(x)= 0.0086022
# differential_evolution step 50: f(x)= 0.0086022
# end diff evolution
# result was:  [0.91151561 0.03269501 0.12247057 0.0104569 ]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0610003
# differential_evolution step 2: f(x)= 0.0407876
# differential_evolution step 3: f(x)= 0.0346359
# differential_evolution step 4: f(x)= 0.0320618
# differential_evolution step 5: f(x)= 0.0320618
# differential_evolution step 6: f(x)= 0.0184489
# differential_evolution step 7: f(x)= 0.0184489
# differential_evolution step 8: f(x)= 0.0174825
# differential_evolution step 9: f(x)= 0.0174825
# differential_evolution step 10: f(x)= 0.0174825
# differential_evolution step 11: f(x)= 0.0174825
# differential_evolution step 12: f(x)= 0.0152686
# differential_evolution step 13: f(x)= 0.0144215
# differential_evolution step 14: f(x)= 0.0144215
# differential_evolution step 15: f(x)= 0.0144215
# differential_evolution step 16: f(x)= 0.0144215
# differential_evolution step 17: f(x)= 0.0143692
# differential_evolution step 18: f(x)= 0.0143692
# differential_evolution step 19: f(x)= 0.0143692
# differential_evolution step 20: f(x)= 0.0132195
# differential_evolution step 21: f(x)= 0.0132195
# differential_evolution step 22: f(x)= 0.0132195
# differential_evolution step 23: f(x)= 0.0132195
# differential_evolution step 24: f(x)= 0.0128757
# differential_evolution step 25: f(x)= 0.0128757
# differential_evolution step 26: f(x)= 0.0128757
# differential_evolution step 27: f(x)= 0.0128757
# differential_evolution step 28: f(x)= 0.0128757
# differential_evolution step 29: f(x)= 0.0127771
# differential_evolution step 30: f(x)= 0.0127771
# differential_evolution step 31: f(x)= 0.0127771
# differential_evolution step 32: f(x)= 0.0127771
# differential_evolution step 33: f(x)= 0.0127771
# differential_evolution step 34: f(x)= 0.0127771
# differential_evolution step 35: f(x)= 0.0127771
# differential_evolution step 36: f(x)= 0.0126414
# differential_evolution step 37: f(x)= 0.0126414
# differential_evolution step 38: f(x)= 0.0126414
# differential_evolution step 39: f(x)= 0.0126414
# differential_evolution step 40: f(x)= 0.0126414
# differential_evolution step 41: f(x)= 0.0126414
# differential_evolution step 42: f(x)= 0.0126414
# differential_evolution step 43: f(x)= 0.0124486
# differential_evolution step 44: f(x)= 0.0124486
# differential_evolution step 45: f(x)= 0.0124486
# differential_evolution step 46: f(x)= 0.0124486
# differential_evolution step 47: f(x)= 0.0124486
# differential_evolution step 48: f(x)= 0.0124486
# differential_evolution step 49: f(x)= 0.0124486
# differential_evolution step 50: f(x)= 0.0124486
# end diff evolution
# result was:  [0.94475964 0.00813247 0.09389614 0.00518627]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.069571
# differential_evolution step 2: f(x)= 0.0232179
# differential_evolution step 3: f(x)= 0.0232179
# differential_evolution step 4: f(x)= 0.0222112
# differential_evolution step 5: f(x)= 0.0222112
# differential_evolution step 6: f(x)= 0.0222112
# differential_evolution step 7: f(x)= 0.0222112
# differential_evolution step 8: f(x)= 0.0202894
# differential_evolution step 9: f(x)= 0.0178805
# differential_evolution step 10: f(x)= 0.0178805
# differential_evolution step 11: f(x)= 0.0178805
# differential_evolution step 12: f(x)= 0.0178805
# differential_evolution step 13: f(x)= 0.0173287
# differential_evolution step 14: f(x)= 0.0173287
# differential_evolution step 15: f(x)= 0.017302
# differential_evolution step 16: f(x)= 0.016919
# differential_evolution step 17: f(x)= 0.0166804
# differential_evolution step 18: f(x)= 0.0166804
# differential_evolution step 19: f(x)= 0.0166804
# differential_evolution step 20: f(x)= 0.0166804
# differential_evolution step 21: f(x)= 0.0166356
# differential_evolution step 22: f(x)= 0.0166356
# differential_evolution step 23: f(x)= 0.0166356
# differential_evolution step 24: f(x)= 0.016446
# differential_evolution step 25: f(x)= 0.016446
# differential_evolution step 26: f(x)= 0.016446
# differential_evolution step 27: f(x)= 0.016446
# differential_evolution step 28: f(x)= 0.016446
# differential_evolution step 29: f(x)= 0.016437
# differential_evolution step 30: f(x)= 0.0162772
# differential_evolution step 31: f(x)= 0.0162772
# differential_evolution step 32: f(x)= 0.0162772
# differential_evolution step 33: f(x)= 0.0162772
# differential_evolution step 34: f(x)= 0.0162772
# differential_evolution step 35: f(x)= 0.0162772
# differential_evolution step 36: f(x)= 0.0162772
# differential_evolution step 37: f(x)= 0.0162772
# differential_evolution step 38: f(x)= 0.0162772
# differential_evolution step 39: f(x)= 0.0162772
# differential_evolution step 40: f(x)= 0.0162772
# differential_evolution step 41: f(x)= 0.0162772
# differential_evolution step 42: f(x)= 0.0162772
# differential_evolution step 43: f(x)= 0.0162772
# differential_evolution step 44: f(x)= 0.0162772
# differential_evolution step 45: f(x)= 0.0162772
# differential_evolution step 46: f(x)= 0.0162772
# differential_evolution step 47: f(x)= 0.0162772
# differential_evolution step 48: f(x)= 0.0162772
# differential_evolution step 49: f(x)= 0.0162772
# differential_evolution step 50: f(x)= 0.0162772
# end diff evolution
# result was:  [0.85937393 0.06391993 0.1818793  0.02972632]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0418777
# differential_evolution step 2: f(x)= 0.0368376
# differential_evolution step 3: f(x)= 0.0368376
# differential_evolution step 4: f(x)= 0.0116819
# differential_evolution step 5: f(x)= 0.0116819
# differential_evolution step 6: f(x)= 0.0116819
# differential_evolution step 7: f(x)= 0.0110727
# differential_evolution step 8: f(x)= 0.0110727
# differential_evolution step 9: f(x)= 0.01079
# differential_evolution step 10: f(x)= 0.0107058
# differential_evolution step 11: f(x)= 0.0104193
# differential_evolution step 12: f(x)= 0.00891079
# differential_evolution step 13: f(x)= 0.00836957
# differential_evolution step 14: f(x)= 0.00836957
# differential_evolution step 15: f(x)= 0.00819263
# differential_evolution step 16: f(x)= 0.0079906
# differential_evolution step 17: f(x)= 0.0079906
# differential_evolution step 18: f(x)= 0.0079906
# differential_evolution step 19: f(x)= 0.0079906
# differential_evolution step 20: f(x)= 0.0079906
# differential_evolution step 21: f(x)= 0.0079906
# differential_evolution step 22: f(x)= 0.0079906
# differential_evolution step 23: f(x)= 0.0079906
# differential_evolution step 24: f(x)= 0.0079906
# differential_evolution step 25: f(x)= 0.0079906
# differential_evolution step 26: f(x)= 0.0079906
# differential_evolution step 27: f(x)= 0.0079906
# differential_evolution step 28: f(x)= 0.0079906
# differential_evolution step 29: f(x)= 0.00779462
# differential_evolution step 30: f(x)= 0.00779462
# differential_evolution step 31: f(x)= 0.00779462
# differential_evolution step 32: f(x)= 0.00779462
# differential_evolution step 33: f(x)= 0.00779462
# differential_evolution step 34: f(x)= 0.00779462
# differential_evolution step 35: f(x)= 0.00779462
# differential_evolution step 36: f(x)= 0.00779462
# differential_evolution step 37: f(x)= 0.00779462
# differential_evolution step 38: f(x)= 0.00779462
# differential_evolution step 39: f(x)= 0.00779462
# differential_evolution step 40: f(x)= 0.00779462
# differential_evolution step 41: f(x)= 0.00779462
# differential_evolution step 42: f(x)= 0.00779462
# differential_evolution step 43: f(x)= 0.00779462
# differential_evolution step 44: f(x)= 0.00779462
# differential_evolution step 45: f(x)= 0.00779462
# differential_evolution step 46: f(x)= 0.00779462
# differential_evolution step 47: f(x)= 0.00779462
# differential_evolution step 48: f(x)= 0.00779462
# differential_evolution step 49: f(x)= 0.00779462
# differential_evolution step 50: f(x)= 0.00779462
# end diff evolution
# result was:  [0.8879866  0.04994268 0.14644187 0.0201237 ]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0792299
# differential_evolution step 2: f(x)= 0.0525487
# differential_evolution step 3: f(x)= 0.0230653
# differential_evolution step 4: f(x)= 0.0218145
# differential_evolution step 5: f(x)= 0.0218145
# differential_evolution step 6: f(x)= 0.0150095
# differential_evolution step 7: f(x)= 0.0150095
# differential_evolution step 8: f(x)= 0.0129677
# differential_evolution step 9: f(x)= 0.00988435
# differential_evolution step 10: f(x)= 0.00718685
# differential_evolution step 11: f(x)= 0.00718106
# differential_evolution step 12: f(x)= 0.00717472
# differential_evolution step 13: f(x)= 0.00717472
# differential_evolution step 14: f(x)= 0.00671645
# differential_evolution step 15: f(x)= 0.00645031
# differential_evolution step 16: f(x)= 0.00645031
# differential_evolution step 17: f(x)= 0.00645031
# differential_evolution step 18: f(x)= 0.00606247
# differential_evolution step 19: f(x)= 0.00606247
# differential_evolution step 20: f(x)= 0.00582923
# differential_evolution step 21: f(x)= 0.00579047
# differential_evolution step 22: f(x)= 0.00559544
# differential_evolution step 23: f(x)= 0.00552372
# differential_evolution step 24: f(x)= 0.00552372
# differential_evolution step 25: f(x)= 0.00552372
# differential_evolution step 26: f(x)= 0.00552372
# differential_evolution step 27: f(x)= 0.00552372
# differential_evolution step 28: f(x)= 0.00541657
# differential_evolution step 29: f(x)= 0.00541657
# differential_evolution step 30: f(x)= 0.00541657
# differential_evolution step 31: f(x)= 0.0053176
# differential_evolution step 32: f(x)= 0.0053176
# differential_evolution step 33: f(x)= 0.0053176
# differential_evolution step 34: f(x)= 0.0053176
# differential_evolution step 35: f(x)= 0.0053176
# differential_evolution step 36: f(x)= 0.0052597
# differential_evolution step 37: f(x)= 0.0052597
# differential_evolution step 38: f(x)= 0.0052597
# differential_evolution step 39: f(x)= 0.0052597
# differential_evolution step 40: f(x)= 0.0052597
# differential_evolution step 41: f(x)= 0.0052597
# differential_evolution step 42: f(x)= 0.0052597
# differential_evolution step 43: f(x)= 0.0052597
# differential_evolution step 44: f(x)= 0.0052597
# differential_evolution step 45: f(x)= 0.0052597
# differential_evolution step 46: f(x)= 0.0052597
# differential_evolution step 47: f(x)= 0.0052597
# differential_evolution step 48: f(x)= 0.0052597
# differential_evolution step 49: f(x)= 0.0052597
# differential_evolution step 50: f(x)= 0.00510066
# end diff evolution
# result was:  [0.9244591  0.02556626 0.10626358 0.00759491]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0102525
# differential_evolution step 2: f(x)= 0.0102525
# differential_evolution step 3: f(x)= 0.0102525
# differential_evolution step 4: f(x)= 0.0102525
# differential_evolution step 5: f(x)= 0.0102525
# differential_evolution step 6: f(x)= 0.0102525
# differential_evolution step 7: f(x)= 0.0102525
# differential_evolution step 8: f(x)= 0.0102525
# differential_evolution step 9: f(x)= 0.00708161
# differential_evolution step 10: f(x)= 0.00708161
# differential_evolution step 11: f(x)= 0.00708161
# differential_evolution step 12: f(x)= 0.00577068
# differential_evolution step 13: f(x)= 0.00577068
# differential_evolution step 14: f(x)= 0.00540703
# differential_evolution step 15: f(x)= 0.00540703
# differential_evolution step 16: f(x)= 0.00540703
# differential_evolution step 17: f(x)= 0.00540703
# differential_evolution step 18: f(x)= 0.00523354
# differential_evolution step 19: f(x)= 0.00523354
# differential_evolution step 20: f(x)= 0.00523354
# differential_evolution step 21: f(x)= 0.00523354
# differential_evolution step 22: f(x)= 0.00523354
# differential_evolution step 23: f(x)= 0.00523354
# differential_evolution step 24: f(x)= 0.00512479
# differential_evolution step 25: f(x)= 0.00512479
# differential_evolution step 26: f(x)= 0.00512479
# differential_evolution step 27: f(x)= 0.00491813
# differential_evolution step 28: f(x)= 0.00491813
# differential_evolution step 29: f(x)= 0.00491813
# differential_evolution step 30: f(x)= 0.00485334
# differential_evolution step 31: f(x)= 0.00485334
# differential_evolution step 32: f(x)= 0.00485334
# differential_evolution step 33: f(x)= 0.00485334
# differential_evolution step 34: f(x)= 0.00485334
# differential_evolution step 35: f(x)= 0.00485334
# differential_evolution step 36: f(x)= 0.00485334
# differential_evolution step 37: f(x)= 0.00485334
# differential_evolution step 38: f(x)= 0.00485334
# differential_evolution step 39: f(x)= 0.00485334
# differential_evolution step 40: f(x)= 0.00485334
# differential_evolution step 41: f(x)= 0.00485334
# differential_evolution step 42: f(x)= 0.00485334
# differential_evolution step 43: f(x)= 0.00485334
# differential_evolution step 44: f(x)= 0.00485334
# differential_evolution step 45: f(x)= 0.00485334
# differential_evolution step 46: f(x)= 0.00485334
# differential_evolution step 47: f(x)= 0.00485334
# differential_evolution step 48: f(x)= 0.00485334
# differential_evolution step 49: f(x)= 0.00485334
# differential_evolution step 50: f(x)= 0.00485334
# end diff evolution
# result was:  [0.90440628 0.04241666 0.12540985 0.00437727]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.172073
# differential_evolution step 2: f(x)= 0.162077
# differential_evolution step 3: f(x)= 0.150251
# differential_evolution step 4: f(x)= 0.144844
# differential_evolution step 5: f(x)= 0.144357
# differential_evolution step 6: f(x)= 0.144357
# differential_evolution step 7: f(x)= 0.14022
# differential_evolution step 8: f(x)= 0.14022
# differential_evolution step 9: f(x)= 0.14022
# differential_evolution step 10: f(x)= 0.14022
# differential_evolution step 11: f(x)= 0.14022
# differential_evolution step 12: f(x)= 0.136937
# differential_evolution step 13: f(x)= 0.136937
# differential_evolution step 14: f(x)= 0.136937
# differential_evolution step 15: f(x)= 0.136937
# differential_evolution step 16: f(x)= 0.136937
# differential_evolution step 17: f(x)= 0.136937
# differential_evolution step 18: f(x)= 0.136937
# differential_evolution step 19: f(x)= 0.136937
# differential_evolution step 20: f(x)= 0.136937
# differential_evolution step 21: f(x)= 0.136937
# differential_evolution step 22: f(x)= 0.136937
# differential_evolution step 23: f(x)= 0.136937
# differential_evolution step 24: f(x)= 0.136937
# differential_evolution step 25: f(x)= 0.136937
# differential_evolution step 26: f(x)= 0.136937
# differential_evolution step 27: f(x)= 0.136937
# differential_evolution step 28: f(x)= 0.135958
# differential_evolution step 29: f(x)= 0.135958
# differential_evolution step 30: f(x)= 0.135958
# differential_evolution step 31: f(x)= 0.135958
# differential_evolution step 32: f(x)= 0.135958
# differential_evolution step 33: f(x)= 0.135958
# differential_evolution step 34: f(x)= 0.135958
# differential_evolution step 35: f(x)= 0.135958
# differential_evolution step 36: f(x)= 0.135958
# differential_evolution step 37: f(x)= 0.135958
# differential_evolution step 38: f(x)= 0.135958
# differential_evolution step 39: f(x)= 0.135958
# differential_evolution step 40: f(x)= 0.135958
# differential_evolution step 41: f(x)= 0.135958
# differential_evolution step 42: f(x)= 0.135958
# differential_evolution step 43: f(x)= 0.135958
# differential_evolution step 44: f(x)= 0.135958
# differential_evolution step 45: f(x)= 0.135958
# differential_evolution step 46: f(x)= 0.135958
# differential_evolution step 47: f(x)= 0.135958
# differential_evolution step 48: f(x)= 0.135958
# end diff evolution
# result was:  [0.44343538 0.11717046 0.12846678 0.57199139]
# integrating geodesic

# %%
g[0].shape
# Out:
# (8, 784)

# %%
for i in range(10):
    print('vals: ', (g[0][i,:].reshape([28,28])[14,13:17]))
    plt.imshow(g[0][i,:].reshape([28,28]))
    plt.show()
# Out:
# vals:  [0.99 0.   0.   0.  ]
# vals:  [0.89106159 0.02588778 0.1420648  0.06053382]
# vals:  [0.87488074 0.02966389 0.17745059 0.0600001 ]
# vals:  [0.80989253 0.05551816 0.33338041 0.04471733]
# vals:  [0.80188901 0.06061963 0.39687983 0.0373307 ]
# vals:  [0.79861629 0.06125658 0.40464408 0.03358493]
# vals:  [0.42719821 0.11252943 0.14630344 0.54202308]
# vals:  [0.   0.   0.   0.99]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-200ab714ccd1> in <module>()
#       1 for i in range(10):
# ----> 2     print('vals: ', (g[0][i,:].reshape([28,28])[14,13:17]))
#       3     plt.imshow(g[0][i,:].reshape([28,28]))
#       4     plt.show()
#
# IndexError: index 8 is out of bounds for axis 0 with size 8

# %%
a=[20,100]
np.argmax(a)
# Out:
# 1

# %%
distance_geod_array(g[0])
# Out:
# integrating geodesic
# array([0.02008545, 0.00465986, 0.0109797 , 0.00343901, 0.00181201,
#        0.06800249, 0.0499361 ])

# %%
longest_segment_left_id(g[0])
# Out:
# integrating geodesic
# 5

# %%
g[1]
# Out:
# [1.0818588935413311,
#  0.6231872190120271,
#  0.6149587269146082,
#  0.6343641304973838,
#  0.329266784642128,
#  0.27012866206809627,
#  0.25857159658919887,
#  0.24159813139569078,
#  0.24172192268957018,
#  0.2379037446827261,
#  0.24355719674162096,
#  0.24492951953712966,
#  0.23907058939769718]

# %%
g[1]
# Out:
# [0.15185054596990333,
#  0.15159184165441025,
#  0.1577698703161675,
#  0.16365391655126482,
#  0.1598736987253802,
#  0.15891462190633263]
