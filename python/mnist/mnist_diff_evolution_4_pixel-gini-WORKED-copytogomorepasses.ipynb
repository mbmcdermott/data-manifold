# %%
from tensorflow.examples.tutorials.mnist import input_data
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
import scipy.integrate as integrate
import scipy.optimize as optimize

# %%
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-3-71e12f4bac70>:1: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /Users/michaelmcdermott/.local/share/virtualenvs/python-_2MbXz7b/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /Users/michaelmcdermott/.local/share/virtualenvs/python-_2MbXz7b/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /Users/michaelmcdermott/.local/share/virtualenvs/python-_2MbXz7b/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/michaelmcdermott/.local/share/virtualenvs/python-_2MbXz7b/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /Users/michaelmcdermott/.local/share/virtualenvs/python-_2MbXz7b/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
sess = tf.InteractiveSession()

# %%
saver = tf.train.import_meta_graph('mnist/conv_99_new.meta')

# %%
saver.restore(sess,'mnist/conv_99_new')
# Out:
# INFO:tensorflow:Restoring parameters from mnist/conv_99_new

# %%
print(tf.global_variables())
# Out:
# [<tf.Variable 'Variable:0' shape=(5, 5, 1, 32) dtype=float32_ref>, <tf.Variable 'Variable_1:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Variable_2:0' shape=(5, 5, 32, 64) dtype=float32_ref>, <tf.Variable 'Variable_3:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Variable_4:0' shape=(3136, 1024) dtype=float32_ref>, <tf.Variable 'Variable_5:0' shape=(1024,) dtype=float32_ref>, <tf.Variable 'Variable_6:0' shape=(1024, 10) dtype=float32_ref>, <tf.Variable 'Variable_7:0' shape=(10,) dtype=float32_ref>, <tf.Variable 'beta1_power:0' shape=() dtype=float32_ref>, <tf.Variable 'beta2_power:0' shape=() dtype=float32_ref>, <tf.Variable 'Variable/Adam:0' shape=(5, 5, 1, 32) dtype=float32_ref>, <tf.Variable 'Variable/Adam_1:0' shape=(5, 5, 1, 32) dtype=float32_ref>, <tf.Variable 'Variable_1/Adam:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Variable_1/Adam_1:0' shape=(32,) dtype=float32_ref>, <tf.Variable 'Variable_2/Adam:0' shape=(5, 5, 32, 64) dtype=float32_ref>, <tf.Variable 'Variable_2/Adam_1:0' shape=(5, 5, 32, 64) dtype=float32_ref>, <tf.Variable 'Variable_3/Adam:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Variable_3/Adam_1:0' shape=(64,) dtype=float32_ref>, <tf.Variable 'Variable_4/Adam:0' shape=(3136, 1024) dtype=float32_ref>, <tf.Variable 'Variable_4/Adam_1:0' shape=(3136, 1024) dtype=float32_ref>, <tf.Variable 'Variable_5/Adam:0' shape=(1024,) dtype=float32_ref>, <tf.Variable 'Variable_5/Adam_1:0' shape=(1024,) dtype=float32_ref>, <tf.Variable 'Variable_6/Adam:0' shape=(1024, 10) dtype=float32_ref>, <tf.Variable 'Variable_6/Adam_1:0' shape=(1024, 10) dtype=float32_ref>, <tf.Variable 'Variable_7/Adam:0' shape=(10,) dtype=float32_ref>, <tf.Variable 'Variable_7/Adam_1:0' shape=(10,) dtype=float32_ref>]

# %%
keep_prob = tf.get_default_graph().get_tensor_by_name("keep_prob:0")
x = tf.get_default_graph().get_tensor_by_name("x:0")
y_conv = tf.get_default_graph().get_tensor_by_name("y_conv:0")
y_conv_s = tf.get_default_graph().get_tensor_by_name("y_conv_s:0")

# %% [markdown]
# # Let's create a 3 pixel shifting image

# %%
pic = mnist.train.images[7]

# %%
plt.imshow(pic.reshape([28,28]))
plt.colorbar()

# %%
def make_pix_pic(coords=[(14,14)]):
    init_pic = np.zeros(784)
    init_pic = init_pic.reshape([28,28])
    for i, co in enumerate(coords):
        init_pic[co] = 0.5
    return init_pic.reshape(784)

# %%
init_pic = np.zeros(784)
init_pic = init_pic.reshape([28,28])
init_pic[14, 10] = 0.9

# %%
plt.imshow(init_pic)
plt.colorbar()

# %% [markdown]
# # Let's compute the geodesics..

# %%
def norm(x):
    return np.sqrt(np.sum(x**2))

# %%
def callbak(x,convergence):
    print('x is: ', x)
    print('val is: ', convergence)

# %%
te=optimize.differential_evolution(norm, bounds=[(0,1), (0,1), (0,1), (0.1,1)], disp=True)
# Out:
# differential_evolution step 1: f(x)= 0.242315
# differential_evolution step 2: f(x)= 0.238803
# differential_evolution step 3: f(x)= 0.238803
# differential_evolution step 4: f(x)= 0.13882
# differential_evolution step 5: f(x)= 0.13882
# differential_evolution step 6: f(x)= 0.13882
# differential_evolution step 7: f(x)= 0.133188
# differential_evolution step 8: f(x)= 0.133188
# differential_evolution step 9: f(x)= 0.133188
# differential_evolution step 10: f(x)= 0.133188
# differential_evolution step 11: f(x)= 0.125149
# differential_evolution step 12: f(x)= 0.111671
# differential_evolution step 13: f(x)= 0.111671
# differential_evolution step 14: f(x)= 0.111671
# differential_evolution step 15: f(x)= 0.111671
# differential_evolution step 16: f(x)= 0.111671
# differential_evolution step 17: f(x)= 0.10703
# differential_evolution step 18: f(x)= 0.10703
# differential_evolution step 19: f(x)= 0.105032
# differential_evolution step 20: f(x)= 0.100709
# differential_evolution step 21: f(x)= 0.100709
# differential_evolution step 22: f(x)= 0.100709
# differential_evolution step 23: f(x)= 0.100709
# differential_evolution step 24: f(x)= 0.100709
# differential_evolution step 25: f(x)= 0.100709
# differential_evolution step 26: f(x)= 0.100709
# differential_evolution step 27: f(x)= 0.100709
# differential_evolution step 28: f(x)= 0.100665
# differential_evolution step 29: f(x)= 0.100137
# differential_evolution step 30: f(x)= 0.100051
# differential_evolution step 31: f(x)= 0.100051
# differential_evolution step 32: f(x)= 0.100051
# differential_evolution step 33: f(x)= 0.100051
# differential_evolution step 34: f(x)= 0.100051
# differential_evolution step 35: f(x)= 0.100051
# differential_evolution step 36: f(x)= 0.100051
# differential_evolution step 37: f(x)= 0.100051
# differential_evolution step 38: f(x)= 0.100051
# differential_evolution step 39: f(x)= 0.100051
# differential_evolution step 40: f(x)= 0.100051
# differential_evolution step 41: f(x)= 0.100051
# differential_evolution step 42: f(x)= 0.100051
# differential_evolution step 43: f(x)= 0.100051
# differential_evolution step 44: f(x)= 0.100026
# differential_evolution step 45: f(x)= 0.100026
# differential_evolution step 46: f(x)= 0.100026
# differential_evolution step 47: f(x)= 0.100026
# differential_evolution step 48: f(x)= 0.100026

# %%
te
# Out:
#      fun: 0.1
#      jac: array([5.13478149e-08, 5.13478149e-08, 5.13478149e-08, 9.99999999e-01])
#  message: 'Optimization terminated successfully.'
#     nfev: 2950
#      nit: 48
#  success: True
#        x: array([0. , 0. , 0. , 0.1])

# %%
def shift_pic(pic, shift=4):
    return np.roll(pic.reshape([28,28]), shift, axis=1).reshape([784,])

# %%
def apply_scalar_padding(x, unpadded_coords=[(14,15)]):
    pic = np.zeros([28, 28])
    pic[unpadded_coords] = x
    return pic.reshape(784)

# %%
def apply_padding(x, unpadded_coords=[(14, 13), (14,14), (14,15), (14,16)]):
    pic = np.zeros([28, 28])
    #pic = 1/100.*np.random.rand(28, 28)
    for i, coords in enumerate(unpadded_coords):
        pic[coords] = x[i]
    return pic.reshape(784)

# %%
def create_vec_tensor(categories, target = y_conv_s):
    vec_tens = []
    for i in range(categories):
            vec_tens.append(tf.gradients(target[:,i], x)[0])
    return vec_tens

# %%
vec_tens = create_vec_tensor(10)
def compute_vec_grad(pic, vec_tens):
    var_grad = sess.run(vec_tens, feed_dict={x: pic.reshape([1,len(pic)]), keep_prob: 1.0})
    return np.asarray(var_grad).reshape([10, 784])

# %%
def compute_metric(pic, compute_vec_grad=compute_vec_grad, alpha=0.0, beta=1.0):
    vec_grad = compute_vec_grad(pic, vec_tens)
    #vec_grad = vec_grad/np.sqrt(np.sum(vec_grad**2, axis=1)).reshape([10,1])
    return alpha*np.identity(784) + beta*np.dot(np.transpose(vec_grad),vec_grad)

# %%
def interp_integrand(start_pic, end_pic, t, metric=compute_metric):
    curr_pic = (1-t)*start_pic + t*end_pic 
    return np.sqrt( np.dot( np.dot(end_pic-start_pic, metric(curr_pic)), end_pic-start_pic))

# %%
def mid_func(midpoint, startpoint, endpoint, metric=compute_metric):
    l = integrate.romberg(lambda t: interp_integrand(startpoint, midpoint, t),0,1, tol=1e-3, rtol=1e-4)
    r = integrate.romberg(lambda t: interp_integrand(midpoint, endpoint, t),0,1, tol=1e-3, rtol=1e-4)
    segment_sum = l + r
    gini = (l**2+r**2)/(l+r)**2 - 0.5
#     print("seg1: ", l)
#     print("seg2: ", r)
#     print("gini: ", gini)
    return segment_sum + gini

# %%
def distance_geod(geod):
    print("integrating geodesic")
    length = 0
    for i in range(len(geod)-1):
        length+=integrate.romberg(lambda t: interp_integrand(geod[i], geod[i+1], t), 0, 1, tol=1e-1, rtol=1e-4)

    return length


def distance_geod_array(geod):
    print("integrating geodesic")
    length = []
    for i in range(len(geod)-1):
        length.append(integrate.romberg(lambda t: interp_integrand(geod[i], geod[i+1], t), 0, 1, tol=1e-3, rtol=1e-4))

    return np.asarray(length)

def top_n_length_ids(geod, n=4):
    return np.argsort(distance_geod_array(geod))[-n:][::-1]

def compute_mid_ids(geod):
    midid = np.floor((len(geod))/2.0)
    lowid = np.ceil(midid/2.0)
    hiid = midid + lowid
    return np.arange(int(lowid), int(hiid))

# %%
def minimize_length_step(point_index, geod):
    bounds = [(0,1)]*4
    print('begin diff evolution')
    soln = optimize.differential_evolution(lambda x: mid_func(apply_padding(x), geod[point_index-1,:], geod[point_index+1,:]), bounds=bounds, maxiter=50,popsize=50, recombination=1, disp=True)
    print('end diff evolution')
    print('result was: ', soln['x'])
    return np.asarray(apply_padding(soln['x']))

# %%
#returns the geodesic with first index being the pt index and second being the actual point (or picture in the mnist case)
def divide(startpoint, endpoint, num_div):
    pt_divs = np.linspace(0, 1, num=num_div)

    geod = np.ones(len(pt_divs)).reshape([len(pt_divs),1])*startpoint.reshape([1,len(startpoint)]) + pt_divs.reshape([len(pt_divs),1])*(endpoint-startpoint).reshape([1,len(startpoint)])
    for pt_index in range(len(pt_divs))[1:-1]:
        if pt_index < len(pt_divs)/2.:
            geod[pt_index] = make_pix_pic(coords=[(14,14)])
        else:
            geod[pt_index] = make_pix_pic(coords=[(14,15)])
    return pt_divs, geod

def refine(geod, num_passes=1, shuffle=True):
    for n in range(num_passes):
        r=np.arange(len(geod))[1:-1]
        if shuffle:
            np.random.shuffle(r)
        for pt_index in r:
            geod[pt_index] = minimize_length_step(pt_index, geod)
    return geod 

def compute_geodesic(startpoint, endpoint, num_div, num_passes=2):
    grid, geod = divide(startpoint, endpoint, num_div)
    length_pass = []
    length_pass.append(distance_geod(geod))
    for n in range(num_passes):
        r=np.arange(len(grid))[1:-1]
        np.random.shuffle(r)
        for pt_index in r:
            geod[pt_index] = minimize_length_step(pt_index, geod)
        length_pass.append(distance_geod(geod))
    return geod, length_pass

def compute_geodesic_top_n(startpoint, endpoint, num_div, num_passes=2):
    grid, geod = divide(startpoint, endpoint, num_div)
    length_pass = []
    length_pass.append(distance_geod(geod))
    for n in range(num_passes):
        r=top_n_length_ids(geod)
        print('top indices: ', r)
        np.random.shuffle(r)
        for pt_index in r:
            print("using point: ", pt_index)
            #handle endpoints:
            if pt_index == 0:
                pt_index_to_use = 1
            else:
                pt_index_to_use = pt_index
            geod[pt_index_to_use] = minimize_length_step(pt_index_to_use, geod)
        length_pass.append(distance_geod(geod))
    return geod, length_pass

def compute_one_pass_geod(startpoint, endpoint, num_internal_pts=1, num_passes=1):
    grid, geod = divide(startpoint, endpoint, num_internal_pts+2)

    for n in range(num_passes):
        r=np.arange(len(grid))[1:-1]
        np.random.shuffle(r)
        for pt_index in r:
            geod[pt_index] = minimize_length_step(pt_index, geod)
    return geod

def compute_geodesic_spreading(startpoint, endpoint, num_div, num_passes=2):
    grid, geod = divide(startpoint, endpoint, num_div)
    length_pass = []
    length_pass.append(distance_geod(geod))
    r  = compute_mid_ids(geod)
    print(r)
    print(np.arange(len(grid))[1:-1])
    rc = np.setdiff1d(np.arange(len(grid))[1:-1], r)
    print(rc)
    for n in range(num_passes):
        print('top indices: ', r)
        np.random.shuffle(r)
        for pt_index in r:
            print("using point: ", pt_index)
            geod[pt_index] = minimize_length_step(pt_index, geod)
        length_pass.append(distance_geod(geod))
    for n in range(num_passes):
        np.random.shuffle(rc)
        for pt_index in rc:
            print("using point: ", pt_index)
            geod[pt_index] = minimize_length_step(pt_index, geod)
        length_pass.append(distance_geod(geod))
    return geod, length_pass


def compute_full_geodesic(startpoint, endpoint, num_internal_pts=1, num_layers=1, num_passes=1):
    if (num_internal_pts != 1) or (num_passes!=1):
        return "Error, num internal pts and num passes must be 1 currently"
    geod = compute_one_pass_geod(startpoint, endpoint, num_internal_pts, num_passes)
    length_layer = []
    length_layer.append(distance_geod(geod))
    for n in range(num_layers):
        #pick index at random
        print("Working on layer: ", n+1)
        #left_index = longest_segment_left_id(geod)
        #left_index = np.random.choice(len(geod)-1)
        new_geod_pt = []
        curr_range = np.arange(len(geod)-1)
        for left_index in curr_range:
            print("using left index: ", left_index)
            new_geod = compute_one_pass_geod(geod[left_index,:], geod[left_index+1,:], num_internal_pts, num_passes)
            new_geod_pt.append(new_geod[1,:])
        geod = np.insert(geod, curr_range+1, new_geod_pt, axis=0)
        #geod = refine(geod, num_passes=2)
        length_layer.append(distance_geod(geod))
    return geod, length_layer

# %%
start_pic = shift_pic(make_pix_pic(),shift=-1)
end_pic =  shift_pic(make_pix_pic(),shift=2)

# %%
plt.imshow(end_pic.reshape([28,28]))
plt.colorbar()

# %%
# bounds = [(0,1)]*3

# soln = optimize.differential_evolution(lambda x: mid_func(apply_padding(x), start_pic, end_pic), bounds=[(0,1),(0,1),(0,1)], maxiter=100,popsize=30, recombination=1, disp=True)

# %%
# soln

# %%
g = compute_geodesic(start_pic, end_pic, num_div=9, num_passes=2)
# Out:
# integrating geodesic
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0982934
# differential_evolution step 2: f(x)= 0.0638884
# differential_evolution step 3: f(x)= 0.0638884
# differential_evolution step 4: f(x)= 0.0638884
# differential_evolution step 5: f(x)= 0.0638884
# differential_evolution step 6: f(x)= 0.0638884
# differential_evolution step 7: f(x)= 0.0638884
# differential_evolution step 8: f(x)= 0.0638884
# differential_evolution step 9: f(x)= 0.0638235
# differential_evolution step 10: f(x)= 0.0630611
# differential_evolution step 11: f(x)= 0.0621595
# differential_evolution step 12: f(x)= 0.0621595
# differential_evolution step 13: f(x)= 0.0621595
# differential_evolution step 14: f(x)= 0.0621595
# differential_evolution step 15: f(x)= 0.0601193
# differential_evolution step 16: f(x)= 0.0594537
# differential_evolution step 17: f(x)= 0.0584399
# differential_evolution step 18: f(x)= 0.0584399
# differential_evolution step 19: f(x)= 0.0580297
# differential_evolution step 20: f(x)= 0.0580297
# differential_evolution step 21: f(x)= 0.0580297
# differential_evolution step 22: f(x)= 0.0579251
# differential_evolution step 23: f(x)= 0.0579251
# differential_evolution step 24: f(x)= 0.0579251
# differential_evolution step 25: f(x)= 0.0570129
# differential_evolution step 26: f(x)= 0.0570129
# differential_evolution step 27: f(x)= 0.0565879
# differential_evolution step 28: f(x)= 0.0565879
# differential_evolution step 29: f(x)= 0.0565879
# differential_evolution step 30: f(x)= 0.0565609
# differential_evolution step 31: f(x)= 0.0565609
# differential_evolution step 32: f(x)= 0.0565499
# differential_evolution step 33: f(x)= 0.0564944
# differential_evolution step 34: f(x)= 0.0564944
# differential_evolution step 35: f(x)= 0.0564944
# differential_evolution step 36: f(x)= 0.056452
# end diff evolution
# result was:  [0.00758924 0.03006271 0.24541574 0.31845346]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0606003
# differential_evolution step 2: f(x)= 0.0606003
# differential_evolution step 3: f(x)= 0.0606003
# differential_evolution step 4: f(x)= 0.0606003
# differential_evolution step 5: f(x)= 0.0604923
# differential_evolution step 6: f(x)= 0.0545833
# differential_evolution step 7: f(x)= 0.0532394
# differential_evolution step 8: f(x)= 0.051454
# differential_evolution step 9: f(x)= 0.051454
# differential_evolution step 10: f(x)= 0.051454
# differential_evolution step 11: f(x)= 0.0494044
# differential_evolution step 12: f(x)= 0.0494044
# differential_evolution step 13: f(x)= 0.0494044
# differential_evolution step 14: f(x)= 0.0478613
# differential_evolution step 15: f(x)= 0.0478613
# differential_evolution step 16: f(x)= 0.0478224
# differential_evolution step 17: f(x)= 0.0473245
# differential_evolution step 18: f(x)= 0.0473245
# differential_evolution step 19: f(x)= 0.0473245
# differential_evolution step 20: f(x)= 0.0467625
# differential_evolution step 21: f(x)= 0.0444565
# differential_evolution step 22: f(x)= 0.0444565
# differential_evolution step 23: f(x)= 0.0443091
# differential_evolution step 24: f(x)= 0.0443091
# differential_evolution step 25: f(x)= 0.0443091
# differential_evolution step 26: f(x)= 0.0443091
# differential_evolution step 27: f(x)= 0.0443091
# differential_evolution step 28: f(x)= 0.0443091
# differential_evolution step 29: f(x)= 0.0443091
# differential_evolution step 30: f(x)= 0.0442401
# differential_evolution step 31: f(x)= 0.0442401
# differential_evolution step 32: f(x)= 0.0442401
# differential_evolution step 33: f(x)= 0.0440077
# differential_evolution step 34: f(x)= 0.0440077
# differential_evolution step 35: f(x)= 0.0440077
# differential_evolution step 36: f(x)= 0.0436531
# differential_evolution step 37: f(x)= 0.0436531
# differential_evolution step 38: f(x)= 0.0436531
# differential_evolution step 39: f(x)= 0.0436531
# differential_evolution step 40: f(x)= 0.0436531
# differential_evolution step 41: f(x)= 0.0436531
# differential_evolution step 42: f(x)= 0.0436531
# differential_evolution step 43: f(x)= 0.0436531
# differential_evolution step 44: f(x)= 0.0436531
# differential_evolution step 45: f(x)= 0.0436531
# differential_evolution step 46: f(x)= 0.0436531
# differential_evolution step 47: f(x)= 0.0436398
# differential_evolution step 48: f(x)= 0.0434739
# differential_evolution step 49: f(x)= 0.0434739
# differential_evolution step 50: f(x)= 0.0434739
# end diff evolution
# result was:  [1.00769347e-01 2.24948674e-01 3.31808046e-01 5.46254816e-06]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.049518
# differential_evolution step 2: f(x)= 0.0297841
# differential_evolution step 3: f(x)= 0.0223308
# differential_evolution step 4: f(x)= 0.0223308
# differential_evolution step 5: f(x)= 0.0223308
# differential_evolution step 6: f(x)= 0.0125834
# differential_evolution step 7: f(x)= 0.0125834
# differential_evolution step 8: f(x)= 0.0117238
# differential_evolution step 9: f(x)= 0.00927924
# differential_evolution step 10: f(x)= 0.00520207
# differential_evolution step 11: f(x)= 0.00520207
# differential_evolution step 12: f(x)= 0.00520207
# differential_evolution step 13: f(x)= 0.00520207
# differential_evolution step 14: f(x)= 0.00445072
# differential_evolution step 15: f(x)= 0.00280809
# differential_evolution step 16: f(x)= 0.00280809
# differential_evolution step 17: f(x)= 0.00230377
# differential_evolution step 18: f(x)= 0.00174255
# differential_evolution step 19: f(x)= 0.001656
# differential_evolution step 20: f(x)= 0.000695576
# differential_evolution step 21: f(x)= 0.000695576
# differential_evolution step 22: f(x)= 0.000695576
# differential_evolution step 23: f(x)= 0.000681394
# differential_evolution step 24: f(x)= 0.000613437
# differential_evolution step 25: f(x)= 0.000530047
# differential_evolution step 26: f(x)= 0.000530047
# differential_evolution step 27: f(x)= 0.000530047
# differential_evolution step 28: f(x)= 0.000530047
# differential_evolution step 29: f(x)= 0.000519454
# differential_evolution step 30: f(x)= 0.000481622
# differential_evolution step 31: f(x)= 0.000349553
# differential_evolution step 32: f(x)= 0.000345571
# differential_evolution step 33: f(x)= 0.0003261
# differential_evolution step 34: f(x)= 0.000182861
# differential_evolution step 35: f(x)= 0.000162568
# differential_evolution step 36: f(x)= 0.000157026
# differential_evolution step 37: f(x)= 0.00013315
# differential_evolution step 38: f(x)= 0.000101641
# differential_evolution step 39: f(x)= 0.000101641
# differential_evolution step 40: f(x)= 0.000101641
# differential_evolution step 41: f(x)= 0.000101641
# differential_evolution step 42: f(x)= 0.000101641
# differential_evolution step 43: f(x)= 0.000101641
# differential_evolution step 44: f(x)= 6.51545e-05
# differential_evolution step 45: f(x)= 4.84212e-05
# differential_evolution step 46: f(x)= 4.84212e-05
# differential_evolution step 47: f(x)= 4.25983e-05
# differential_evolution step 48: f(x)= 4.25983e-05
# differential_evolution step 49: f(x)= 2.83388e-05
# differential_evolution step 50: f(x)= 2.83388e-05
# end diff evolution
# result was:  [6.53617239e-17 4.99999993e-01 0.00000000e+00 0.00000000e+00]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0761963
# differential_evolution step 2: f(x)= 0.0664425
# differential_evolution step 3: f(x)= 0.0550617
# differential_evolution step 4: f(x)= 0.0421534
# differential_evolution step 5: f(x)= 0.0421534
# differential_evolution step 6: f(x)= 0.0421534
# differential_evolution step 7: f(x)= 0.0421534
# differential_evolution step 8: f(x)= 0.0421534
# differential_evolution step 9: f(x)= 0.0380265
# differential_evolution step 10: f(x)= 0.0380265
# differential_evolution step 11: f(x)= 0.0367432
# differential_evolution step 12: f(x)= 0.0367432
# differential_evolution step 13: f(x)= 0.0367209
# differential_evolution step 14: f(x)= 0.0367209
# differential_evolution step 15: f(x)= 0.0364422
# differential_evolution step 16: f(x)= 0.0347881
# differential_evolution step 17: f(x)= 0.0344665
# differential_evolution step 18: f(x)= 0.0344665
# differential_evolution step 19: f(x)= 0.034435
# differential_evolution step 20: f(x)= 0.034435
# differential_evolution step 21: f(x)= 0.034435
# differential_evolution step 22: f(x)= 0.034435
# differential_evolution step 23: f(x)= 0.0343675
# differential_evolution step 24: f(x)= 0.0343675
# differential_evolution step 25: f(x)= 0.0343044
# differential_evolution step 26: f(x)= 0.03424
# differential_evolution step 27: f(x)= 0.034072
# differential_evolution step 28: f(x)= 0.0339505
# differential_evolution step 29: f(x)= 0.0339505
# differential_evolution step 30: f(x)= 0.0339505
# differential_evolution step 31: f(x)= 0.033942
# differential_evolution step 32: f(x)= 0.0339366
# differential_evolution step 33: f(x)= 0.0339366
# end diff evolution
# result was:  [0.10670496 0.05668527 0.40059186 0.06909791]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0836904
# differential_evolution step 2: f(x)= 0.0804882
# differential_evolution step 3: f(x)= 0.0804882
# differential_evolution step 4: f(x)= 0.0804882
# differential_evolution step 5: f(x)= 0.0793464
# differential_evolution step 6: f(x)= 0.0793464
# differential_evolution step 7: f(x)= 0.0793464
# differential_evolution step 8: f(x)= 0.0788438
# differential_evolution step 9: f(x)= 0.0722237
# differential_evolution step 10: f(x)= 0.0654489
# differential_evolution step 11: f(x)= 0.0654489
# differential_evolution step 12: f(x)= 0.0654489
# differential_evolution step 13: f(x)= 0.0654489
# differential_evolution step 14: f(x)= 0.0649589
# differential_evolution step 15: f(x)= 0.0640567
# differential_evolution step 16: f(x)= 0.0628901
# differential_evolution step 17: f(x)= 0.0628901
# differential_evolution step 18: f(x)= 0.0627298
# differential_evolution step 19: f(x)= 0.0627298
# differential_evolution step 20: f(x)= 0.0627298
# differential_evolution step 21: f(x)= 0.0625775
# differential_evolution step 22: f(x)= 0.0625775
# differential_evolution step 23: f(x)= 0.0622839
# differential_evolution step 24: f(x)= 0.0622839
# differential_evolution step 25: f(x)= 0.0621675
# differential_evolution step 26: f(x)= 0.0621675
# differential_evolution step 27: f(x)= 0.0619784
# differential_evolution step 28: f(x)= 0.0619784
# differential_evolution step 29: f(x)= 0.0617958
# differential_evolution step 30: f(x)= 0.0617958
# differential_evolution step 31: f(x)= 0.0617958
# differential_evolution step 32: f(x)= 0.0616592
# differential_evolution step 33: f(x)= 0.0616592
# differential_evolution step 34: f(x)= 0.0616592
# differential_evolution step 35: f(x)= 0.06164
# end diff evolution
# result was:  [0.28057096 0.30762448 0.07725509 0.00106741]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0781098
# differential_evolution step 2: f(x)= 0.0779037
# differential_evolution step 3: f(x)= 0.042672
# differential_evolution step 4: f(x)= 0.0372663
# differential_evolution step 5: f(x)= 0.0345855
# differential_evolution step 6: f(x)= 0.0290801
# differential_evolution step 7: f(x)= 0.0266468
# differential_evolution step 8: f(x)= 0.0266468
# differential_evolution step 9: f(x)= 0.0262513
# differential_evolution step 10: f(x)= 0.0262513
# differential_evolution step 11: f(x)= 0.0262513
# differential_evolution step 12: f(x)= 0.0243583
# differential_evolution step 13: f(x)= 0.0243583
# differential_evolution step 14: f(x)= 0.0226327
# differential_evolution step 15: f(x)= 0.0226327
# differential_evolution step 16: f(x)= 0.0226327
# differential_evolution step 17: f(x)= 0.0226327
# differential_evolution step 18: f(x)= 0.0226327
# differential_evolution step 19: f(x)= 0.0224767
# differential_evolution step 20: f(x)= 0.0224767
# differential_evolution step 21: f(x)= 0.0224767
# differential_evolution step 22: f(x)= 0.0223295
# differential_evolution step 23: f(x)= 0.0223295
# differential_evolution step 24: f(x)= 0.0223028
# differential_evolution step 25: f(x)= 0.0222778
# differential_evolution step 26: f(x)= 0.0222651
# differential_evolution step 27: f(x)= 0.0222651
# differential_evolution step 28: f(x)= 0.0222651
# differential_evolution step 29: f(x)= 0.0222545
# differential_evolution step 30: f(x)= 0.0222545
# differential_evolution step 31: f(x)= 0.0222545
# differential_evolution step 32: f(x)= 0.0222545
# differential_evolution step 33: f(x)= 0.0222545
# differential_evolution step 34: f(x)= 0.0222545
# differential_evolution step 35: f(x)= 0.0222463
# differential_evolution step 36: f(x)= 0.0222463
# differential_evolution step 37: f(x)= 0.0222398
# end diff evolution
# result was:  [0.13304525 0.39867009 0.13651917 0.02566318]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0405834
# differential_evolution step 2: f(x)= 0.0405834
# differential_evolution step 3: f(x)= 0.0328216
# differential_evolution step 4: f(x)= 0.0267775
# differential_evolution step 5: f(x)= 0.0215181
# differential_evolution step 6: f(x)= 0.0215181
# differential_evolution step 7: f(x)= 0.0166521
# differential_evolution step 8: f(x)= 0.0166521
# differential_evolution step 9: f(x)= 0.0166296
# differential_evolution step 10: f(x)= 0.0166296
# differential_evolution step 11: f(x)= 0.0166296
# differential_evolution step 12: f(x)= 0.0166296
# differential_evolution step 13: f(x)= 0.0159337
# differential_evolution step 14: f(x)= 0.0135165
# differential_evolution step 15: f(x)= 0.0135165
# differential_evolution step 16: f(x)= 0.0135165
# differential_evolution step 17: f(x)= 0.0135165
# differential_evolution step 18: f(x)= 0.0130215
# differential_evolution step 19: f(x)= 0.0130215
# differential_evolution step 20: f(x)= 0.0130215
# differential_evolution step 21: f(x)= 0.0130215
# differential_evolution step 22: f(x)= 0.0129749
# differential_evolution step 23: f(x)= 0.0129749
# differential_evolution step 24: f(x)= 0.0129306
# differential_evolution step 25: f(x)= 0.0129306
# differential_evolution step 26: f(x)= 0.0128639
# differential_evolution step 27: f(x)= 0.0128639
# differential_evolution step 28: f(x)= 0.0126745
# differential_evolution step 29: f(x)= 0.0126745
# differential_evolution step 30: f(x)= 0.0126247
# differential_evolution step 31: f(x)= 0.0124003
# differential_evolution step 32: f(x)= 0.0124003
# differential_evolution step 33: f(x)= 0.0124003
# differential_evolution step 34: f(x)= 0.0124003
# differential_evolution step 35: f(x)= 0.0124003
# differential_evolution step 36: f(x)= 0.0121664
# differential_evolution step 37: f(x)= 0.0121334
# differential_evolution step 38: f(x)= 0.0121334
# differential_evolution step 39: f(x)= 0.0121334
# differential_evolution step 40: f(x)= 0.0121334
# differential_evolution step 41: f(x)= 0.0121334
# differential_evolution step 42: f(x)= 0.0121334
# differential_evolution step 43: f(x)= 0.0121334
# differential_evolution step 44: f(x)= 0.0121334
# differential_evolution step 45: f(x)= 0.0120202
# differential_evolution step 46: f(x)= 0.0120202
# differential_evolution step 47: f(x)= 0.0120202
# differential_evolution step 48: f(x)= 0.0120202
# differential_evolution step 49: f(x)= 0.0120202
# differential_evolution step 50: f(x)= 0.0120202
# end diff evolution
# result was:  [0.10074648 0.13673711 0.37318781 0.02224718]
# integrating geodesic
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0546452
# differential_evolution step 2: f(x)= 0.0546452
# differential_evolution step 3: f(x)= 0.0344685
# differential_evolution step 4: f(x)= 0.0344685
# differential_evolution step 5: f(x)= 0.0344685
# differential_evolution step 6: f(x)= 0.0341849
# differential_evolution step 7: f(x)= 0.0341849
# differential_evolution step 8: f(x)= 0.0323053
# differential_evolution step 9: f(x)= 0.0323053
# differential_evolution step 10: f(x)= 0.0262418
# differential_evolution step 11: f(x)= 0.0262418
# differential_evolution step 12: f(x)= 0.0262418
# differential_evolution step 13: f(x)= 0.0262418
# differential_evolution step 14: f(x)= 0.0261964
# differential_evolution step 15: f(x)= 0.0260866
# differential_evolution step 16: f(x)= 0.0256956
# differential_evolution step 17: f(x)= 0.0225371
# differential_evolution step 18: f(x)= 0.0225371
# differential_evolution step 19: f(x)= 0.0225371
# differential_evolution step 20: f(x)= 0.0223507
# differential_evolution step 21: f(x)= 0.0223507
# differential_evolution step 22: f(x)= 0.0223507
# differential_evolution step 23: f(x)= 0.0223507
# differential_evolution step 24: f(x)= 0.0223395
# differential_evolution step 25: f(x)= 0.0222912
# differential_evolution step 26: f(x)= 0.022282
# differential_evolution step 27: f(x)= 0.022282
# differential_evolution step 28: f(x)= 0.022282
# differential_evolution step 29: f(x)= 0.0222754
# differential_evolution step 30: f(x)= 0.0222754
# differential_evolution step 31: f(x)= 0.0222754
# differential_evolution step 32: f(x)= 0.0222754
# differential_evolution step 33: f(x)= 0.0222754
# differential_evolution step 34: f(x)= 0.0222754
# differential_evolution step 35: f(x)= 0.0222754
# differential_evolution step 36: f(x)= 0.0222754
# differential_evolution step 37: f(x)= 0.0222754
# differential_evolution step 38: f(x)= 0.0222642
# differential_evolution step 39: f(x)= 0.0222435
# differential_evolution step 40: f(x)= 0.0222435
# differential_evolution step 41: f(x)= 0.0222435
# differential_evolution step 42: f(x)= 0.0222346
# end diff evolution
# result was:  [0.13240174 0.40020281 0.13527329 0.02617936]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0467676
# differential_evolution step 2: f(x)= 0.0154898
# differential_evolution step 3: f(x)= 0.0154898
# differential_evolution step 4: f(x)= 0.0154898
# differential_evolution step 5: f(x)= 0.0154898
# differential_evolution step 6: f(x)= 0.0154898
# differential_evolution step 7: f(x)= 0.0154898
# differential_evolution step 8: f(x)= 0.0154898
# differential_evolution step 9: f(x)= 0.0154898
# differential_evolution step 10: f(x)= 0.0154898
# differential_evolution step 11: f(x)= 0.0150694
# differential_evolution step 12: f(x)= 0.0150694
# differential_evolution step 13: f(x)= 0.0150694
# differential_evolution step 14: f(x)= 0.0144131
# differential_evolution step 15: f(x)= 0.0144131
# differential_evolution step 16: f(x)= 0.014075
# differential_evolution step 17: f(x)= 0.0139504
# differential_evolution step 18: f(x)= 0.0139504
# differential_evolution step 19: f(x)= 0.0139504
# differential_evolution step 20: f(x)= 0.0138149
# differential_evolution step 21: f(x)= 0.0138149
# differential_evolution step 22: f(x)= 0.0137418
# differential_evolution step 23: f(x)= 0.0136978
# differential_evolution step 24: f(x)= 0.0136978
# differential_evolution step 25: f(x)= 0.0136114
# differential_evolution step 26: f(x)= 0.0135834
# differential_evolution step 27: f(x)= 0.0135606
# differential_evolution step 28: f(x)= 0.0135593
# differential_evolution step 29: f(x)= 0.0135593
# differential_evolution step 30: f(x)= 0.013556
# end diff evolution
# result was:  [0.19371523 0.36299434 0.15397853 0.00928987]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0786205
# differential_evolution step 2: f(x)= 0.0750616
# differential_evolution step 3: f(x)= 0.0674243
# differential_evolution step 4: f(x)= 0.0674243
# differential_evolution step 5: f(x)= 0.0542417
# differential_evolution step 6: f(x)= 0.0476264
# differential_evolution step 7: f(x)= 0.0473037
# differential_evolution step 8: f(x)= 0.0470546
# differential_evolution step 9: f(x)= 0.0470546
# differential_evolution step 10: f(x)= 0.0461714
# differential_evolution step 11: f(x)= 0.0456606
# differential_evolution step 12: f(x)= 0.0456606
# differential_evolution step 13: f(x)= 0.0456606
# differential_evolution step 14: f(x)= 0.0447911
# differential_evolution step 15: f(x)= 0.0432574
# differential_evolution step 16: f(x)= 0.0432574
# differential_evolution step 17: f(x)= 0.0427281
# differential_evolution step 18: f(x)= 0.0425035
# differential_evolution step 19: f(x)= 0.0424937
# differential_evolution step 20: f(x)= 0.0424937
# differential_evolution step 21: f(x)= 0.0423423
# differential_evolution step 22: f(x)= 0.0419856
# differential_evolution step 23: f(x)= 0.0419856
# differential_evolution step 24: f(x)= 0.0419856
# differential_evolution step 25: f(x)= 0.0419856
# differential_evolution step 26: f(x)= 0.0419856
# differential_evolution step 27: f(x)= 0.0419206
# differential_evolution step 28: f(x)= 0.0419206
# differential_evolution step 29: f(x)= 0.0419206
# differential_evolution step 30: f(x)= 0.0418835
# differential_evolution step 31: f(x)= 0.0415458
# differential_evolution step 32: f(x)= 0.0415458
# differential_evolution step 33: f(x)= 0.041406
# differential_evolution step 34: f(x)= 0.041406
# differential_evolution step 35: f(x)= 0.041406
# differential_evolution step 36: f(x)= 0.041406
# differential_evolution step 37: f(x)= 0.0413881
# differential_evolution step 38: f(x)= 0.0413881
# end diff evolution
# result was:  [0.3946935  0.16633202 0.05062666 0.00043359]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0593415
# differential_evolution step 2: f(x)= 0.0546519
# differential_evolution step 3: f(x)= 0.0546519
# differential_evolution step 4: f(x)= 0.0467159
# differential_evolution step 5: f(x)= 0.0376917
# differential_evolution step 6: f(x)= 0.029193
# differential_evolution step 7: f(x)= 0.0266741
# differential_evolution step 8: f(x)= 0.0253768
# differential_evolution step 9: f(x)= 0.0248455
# differential_evolution step 10: f(x)= 0.0248455
# differential_evolution step 11: f(x)= 0.0226524
# differential_evolution step 12: f(x)= 0.0226524
# differential_evolution step 13: f(x)= 0.0226524
# differential_evolution step 14: f(x)= 0.0224257
# differential_evolution step 15: f(x)= 0.020932
# differential_evolution step 16: f(x)= 0.020932
# differential_evolution step 17: f(x)= 0.020932
# differential_evolution step 18: f(x)= 0.0197925
# differential_evolution step 19: f(x)= 0.0195691
# differential_evolution step 20: f(x)= 0.0193056
# differential_evolution step 21: f(x)= 0.0184231
# differential_evolution step 22: f(x)= 0.0184231
# differential_evolution step 23: f(x)= 0.0181973
# differential_evolution step 24: f(x)= 0.0181523
# differential_evolution step 25: f(x)= 0.0177163
# differential_evolution step 26: f(x)= 0.0176489
# differential_evolution step 27: f(x)= 0.0176489
# differential_evolution step 28: f(x)= 0.0173008
# differential_evolution step 29: f(x)= 0.0173008
# differential_evolution step 30: f(x)= 0.017292
# differential_evolution step 31: f(x)= 0.017292
# differential_evolution step 32: f(x)= 0.017292
# differential_evolution step 33: f(x)= 0.017292
# differential_evolution step 34: f(x)= 0.0172609
# differential_evolution step 35: f(x)= 0.0172609
# differential_evolution step 36: f(x)= 0.0172186
# differential_evolution step 37: f(x)= 0.0172186
# differential_evolution step 38: f(x)= 0.0172186
# differential_evolution step 39: f(x)= 0.0172186
# differential_evolution step 40: f(x)= 0.0172027
# differential_evolution step 41: f(x)= 0.0171391
# differential_evolution step 42: f(x)= 0.0171391
# differential_evolution step 43: f(x)= 0.0171391
# differential_evolution step 44: f(x)= 0.0171391
# end diff evolution
# result was:  [0.14398521 0.24800673 0.27300201 0.00252468]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0616477
# differential_evolution step 2: f(x)= 0.0616477
# differential_evolution step 3: f(x)= 0.0616477
# differential_evolution step 4: f(x)= 0.0616477
# differential_evolution step 5: f(x)= 0.0616477
# differential_evolution step 6: f(x)= 0.0616477
# differential_evolution step 7: f(x)= 0.0616477
# differential_evolution step 8: f(x)= 0.0616477
# differential_evolution step 9: f(x)= 0.0613982
# differential_evolution step 10: f(x)= 0.0604774
# differential_evolution step 11: f(x)= 0.0604774
# differential_evolution step 12: f(x)= 0.0604774
# differential_evolution step 13: f(x)= 0.0591752
# differential_evolution step 14: f(x)= 0.0591752
# differential_evolution step 15: f(x)= 0.0591752
# differential_evolution step 16: f(x)= 0.0589234
# differential_evolution step 17: f(x)= 0.0589234
# differential_evolution step 18: f(x)= 0.0589234
# differential_evolution step 19: f(x)= 0.0589234
# differential_evolution step 20: f(x)= 0.0588949
# differential_evolution step 21: f(x)= 0.0588595
# differential_evolution step 22: f(x)= 0.0586826
# differential_evolution step 23: f(x)= 0.0584628
# differential_evolution step 24: f(x)= 0.0584628
# differential_evolution step 25: f(x)= 0.0584457
# differential_evolution step 26: f(x)= 0.0583115
# differential_evolution step 27: f(x)= 0.0583115
# differential_evolution step 28: f(x)= 0.0582373
# differential_evolution step 29: f(x)= 0.0582373
# end diff evolution
# result was:  [0.22196707 0.00844941 0.02204184 0.41646369]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0748771
# differential_evolution step 2: f(x)= 0.0643577
# differential_evolution step 3: f(x)= 0.0493493
# differential_evolution step 4: f(x)= 0.0493493
# differential_evolution step 5: f(x)= 0.0493493
# differential_evolution step 6: f(x)= 0.0493493
# differential_evolution step 7: f(x)= 0.0493493
# differential_evolution step 8: f(x)= 0.0493493
# differential_evolution step 9: f(x)= 0.0493493
# differential_evolution step 10: f(x)= 0.0463341
# differential_evolution step 11: f(x)= 0.0463341
# differential_evolution step 12: f(x)= 0.0463341
# differential_evolution step 13: f(x)= 0.0463341
# differential_evolution step 14: f(x)= 0.0463341
# differential_evolution step 15: f(x)= 0.0463341
# differential_evolution step 16: f(x)= 0.0463341
# differential_evolution step 17: f(x)= 0.0463341
# differential_evolution step 18: f(x)= 0.0450435
# differential_evolution step 19: f(x)= 0.044496
# differential_evolution step 20: f(x)= 0.0432594
# differential_evolution step 21: f(x)= 0.0423276
# differential_evolution step 22: f(x)= 0.0423276
# differential_evolution step 23: f(x)= 0.0423276
# differential_evolution step 24: f(x)= 0.0423276
# differential_evolution step 25: f(x)= 0.0410911
# differential_evolution step 26: f(x)= 0.0410911
# differential_evolution step 27: f(x)= 0.0407585
# differential_evolution step 28: f(x)= 0.0407585
# differential_evolution step 29: f(x)= 0.0407585
# differential_evolution step 30: f(x)= 0.0406781
# differential_evolution step 31: f(x)= 0.0406355
# differential_evolution step 32: f(x)= 0.0406355
# differential_evolution step 33: f(x)= 0.0405934
# differential_evolution step 34: f(x)= 0.0405927
# differential_evolution step 35: f(x)= 0.0405927
# differential_evolution step 36: f(x)= 0.0405927
# differential_evolution step 37: f(x)= 0.0405927
# end diff evolution
# result was:  [0.2264012  0.04677383 0.26049895 0.18705875]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0680337
# differential_evolution step 2: f(x)= 0.0509876
# differential_evolution step 3: f(x)= 0.0337642
# differential_evolution step 4: f(x)= 0.030419
# differential_evolution step 5: f(x)= 0.030419
# differential_evolution step 6: f(x)= 0.030419
# differential_evolution step 7: f(x)= 0.0288783
# differential_evolution step 8: f(x)= 0.0259477
# differential_evolution step 9: f(x)= 0.0256382
# differential_evolution step 10: f(x)= 0.0256382
# differential_evolution step 11: f(x)= 0.0256382
# differential_evolution step 12: f(x)= 0.022123
# differential_evolution step 13: f(x)= 0.022123
# differential_evolution step 14: f(x)= 0.022123
# differential_evolution step 15: f(x)= 0.022123
# differential_evolution step 16: f(x)= 0.022123
# differential_evolution step 17: f(x)= 0.022123
# differential_evolution step 18: f(x)= 0.0216071
# differential_evolution step 19: f(x)= 0.0216071
# differential_evolution step 20: f(x)= 0.0211166
# differential_evolution step 21: f(x)= 0.0211166
# differential_evolution step 22: f(x)= 0.0211164
# differential_evolution step 23: f(x)= 0.0211164
# differential_evolution step 24: f(x)= 0.0210877
# differential_evolution step 25: f(x)= 0.021025
# differential_evolution step 26: f(x)= 0.0210225
# differential_evolution step 27: f(x)= 0.0209696
# differential_evolution step 28: f(x)= 0.0209557
# differential_evolution step 29: f(x)= 0.0209557
# differential_evolution step 30: f(x)= 0.0209557
# end diff evolution
# result was:  [0.2015187  0.11386874 0.31613423 0.10097022]
# integrating geodesic

# %%
for i in range(12):
    print('vals: ', (g[0][i,:].reshape([28,28])[14,13:17]))
    plt.imshow(g[0][i,:].reshape([28,28]))
    plt.show()
# Out:
# vals:  [0.5 0.  0.  0. ]
# vals:  [0.3946935  0.16633202 0.05062666 0.00043359]
# vals:  [0.19371523 0.36299434 0.15397853 0.00928987]
# vals:  [0.13240174 0.40020281 0.13527329 0.02617936]
# vals:  [0.14398521 0.24800673 0.27300201 0.00252468]
# vals:  [0.2015187  0.11386874 0.31613423 0.10097022]
# vals:  [0.2264012  0.04677383 0.26049895 0.18705875]
# vals:  [0.22196707 0.00844941 0.02204184 0.41646369]
# vals:  [0.  0.  0.  0.5]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-ce43a3875c0d> in <module>()
#       1 for i in range(12):
# ----> 2     print('vals: ', (g[0][i,:].reshape([28,28])[14,13:17]))
#       3     plt.imshow(g[0][i,:].reshape([28,28]))
#       4     plt.show()
#
# IndexError: index 9 is out of bounds for axis 0 with size 9

# %% [markdown]
# # The following is the lowest total integral I've yet seen with 4 pixels which leads me to believe this is working

# %%
g[1]
# Out:
# [0.1988582764066274, 0.1367645262633253, 0.12464945440189792]

# %%
distance_geod_array(g[0])
# Out:
# integrating geodesic
# array([0.02084301, 0.02050521, 0.00672011, 0.0085199 , 0.01058388,
#        0.01011484, 0.02042101, 0.02694149])

# %% [markdown]
# # Now with 4 passes

# %%
g_four = compute_geodesic(start_pic, end_pic, num_div=9, num_passes=4)
# Out:
# integrating geodesic
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0955341
# differential_evolution step 2: f(x)= 0.085342
# differential_evolution step 3: f(x)= 0.0732929
# differential_evolution step 4: f(x)= 0.0732929
# differential_evolution step 5: f(x)= 0.0660972
# differential_evolution step 6: f(x)= 0.0660972
# differential_evolution step 7: f(x)= 0.0660972
# differential_evolution step 8: f(x)= 0.0599067
# differential_evolution step 9: f(x)= 0.0574569
# differential_evolution step 10: f(x)= 0.0574569
# differential_evolution step 11: f(x)= 0.0574569
# differential_evolution step 12: f(x)= 0.0574569
# differential_evolution step 13: f(x)= 0.0574569
# differential_evolution step 14: f(x)= 0.0574569
# differential_evolution step 15: f(x)= 0.0574569
# differential_evolution step 16: f(x)= 0.0574569
# differential_evolution step 17: f(x)= 0.0574569
# differential_evolution step 18: f(x)= 0.0571227
# differential_evolution step 19: f(x)= 0.0571227
# differential_evolution step 20: f(x)= 0.0571227
# differential_evolution step 21: f(x)= 0.0571227
# differential_evolution step 22: f(x)= 0.0571227
# differential_evolution step 23: f(x)= 0.0567868
# differential_evolution step 24: f(x)= 0.0562739
# differential_evolution step 25: f(x)= 0.056067
# differential_evolution step 26: f(x)= 0.056067
# differential_evolution step 27: f(x)= 0.0560589
# differential_evolution step 28: f(x)= 0.0560589
# end diff evolution
# result was:  [0.03229276 0.0219185  0.24782491 0.30944984]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0750784
# differential_evolution step 2: f(x)= 0.0750784
# differential_evolution step 3: f(x)= 0.06754
# differential_evolution step 4: f(x)= 0.06754
# differential_evolution step 5: f(x)= 0.0610711
# differential_evolution step 6: f(x)= 0.0595399
# differential_evolution step 7: f(x)= 0.0595399
# differential_evolution step 8: f(x)= 0.0595399
# differential_evolution step 9: f(x)= 0.0540062
# differential_evolution step 10: f(x)= 0.0516741
# differential_evolution step 11: f(x)= 0.0516741
# differential_evolution step 12: f(x)= 0.0494027
# differential_evolution step 13: f(x)= 0.0494027
# differential_evolution step 14: f(x)= 0.0494027
# differential_evolution step 15: f(x)= 0.0494027
# differential_evolution step 16: f(x)= 0.0493234
# differential_evolution step 17: f(x)= 0.0493234
# differential_evolution step 18: f(x)= 0.0477725
# differential_evolution step 19: f(x)= 0.0477725
# differential_evolution step 20: f(x)= 0.0477725
# differential_evolution step 21: f(x)= 0.0477725
# differential_evolution step 22: f(x)= 0.0477725
# differential_evolution step 23: f(x)= 0.045629
# differential_evolution step 24: f(x)= 0.0452698
# differential_evolution step 25: f(x)= 0.0452698
# differential_evolution step 26: f(x)= 0.0452698
# differential_evolution step 27: f(x)= 0.0452698
# differential_evolution step 28: f(x)= 0.0452698
# differential_evolution step 29: f(x)= 0.0452698
# differential_evolution step 30: f(x)= 0.0450054
# differential_evolution step 31: f(x)= 0.0450054
# differential_evolution step 32: f(x)= 0.0450054
# differential_evolution step 33: f(x)= 0.0449915
# differential_evolution step 34: f(x)= 0.0448654
# differential_evolution step 35: f(x)= 0.0448654
# differential_evolution step 36: f(x)= 0.0448654
# differential_evolution step 37: f(x)= 0.0446098
# differential_evolution step 38: f(x)= 0.0446098
# differential_evolution step 39: f(x)= 0.0446098
# differential_evolution step 40: f(x)= 0.0446098
# differential_evolution step 41: f(x)= 0.0446098
# differential_evolution step 42: f(x)= 0.0446098
# differential_evolution step 43: f(x)= 0.0446098
# differential_evolution step 44: f(x)= 0.0446098
# differential_evolution step 45: f(x)= 0.0445809
# differential_evolution step 46: f(x)= 0.0445809
# differential_evolution step 47: f(x)= 0.0445809
# differential_evolution step 48: f(x)= 0.0443595
# differential_evolution step 49: f(x)= 0.0443595
# differential_evolution step 50: f(x)= 0.0443595
# end diff evolution
# result was:  [0.06443509 0.18586295 0.34434817 0.010173  ]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0434954
# differential_evolution step 2: f(x)= 0.031869
# differential_evolution step 3: f(x)= 0.0301662
# differential_evolution step 4: f(x)= 0.0301662
# differential_evolution step 5: f(x)= 0.0298315
# differential_evolution step 6: f(x)= 0.0245457
# differential_evolution step 7: f(x)= 0.0245457
# differential_evolution step 8: f(x)= 0.0245457
# differential_evolution step 9: f(x)= 0.0245457
# differential_evolution step 10: f(x)= 0.0245457
# differential_evolution step 11: f(x)= 0.0245457
# differential_evolution step 12: f(x)= 0.0245457
# differential_evolution step 13: f(x)= 0.0241547
# differential_evolution step 14: f(x)= 0.0241547
# differential_evolution step 15: f(x)= 0.0241547
# differential_evolution step 16: f(x)= 0.0237261
# differential_evolution step 17: f(x)= 0.0237261
# differential_evolution step 18: f(x)= 0.0237261
# differential_evolution step 19: f(x)= 0.0237261
# differential_evolution step 20: f(x)= 0.0237261
# differential_evolution step 21: f(x)= 0.0236898
# differential_evolution step 22: f(x)= 0.0232807
# differential_evolution step 23: f(x)= 0.0232807
# differential_evolution step 24: f(x)= 0.0232807
# differential_evolution step 25: f(x)= 0.0232807
# differential_evolution step 26: f(x)= 0.0232807
# differential_evolution step 27: f(x)= 0.0227028
# differential_evolution step 28: f(x)= 0.0227028
# differential_evolution step 29: f(x)= 0.0227028
# differential_evolution step 30: f(x)= 0.022539
# differential_evolution step 31: f(x)= 0.0225004
# differential_evolution step 32: f(x)= 0.0223491
# differential_evolution step 33: f(x)= 0.0222537
# differential_evolution step 34: f(x)= 0.0222537
# differential_evolution step 35: f(x)= 0.022205
# differential_evolution step 36: f(x)= 0.0221912
# differential_evolution step 37: f(x)= 0.0221912
# differential_evolution step 38: f(x)= 0.0221563
# differential_evolution step 39: f(x)= 0.022145
# differential_evolution step 40: f(x)= 0.0221426
# differential_evolution step 41: f(x)= 0.0221426
# differential_evolution step 42: f(x)= 0.0221426
# differential_evolution step 43: f(x)= 0.0221426
# differential_evolution step 44: f(x)= 0.0221426
# differential_evolution step 45: f(x)= 0.0221426
# differential_evolution step 46: f(x)= 0.0221426
# differential_evolution step 47: f(x)= 0.0221386
# differential_evolution step 48: f(x)= 0.0221239
# end diff evolution
# result was:  [0.01883517 0.08814185 0.33848328 0.12341549]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.086279
# differential_evolution step 2: f(x)= 0.086279
# differential_evolution step 3: f(x)= 0.086279
# differential_evolution step 4: f(x)= 0.0844172
# differential_evolution step 5: f(x)= 0.0799574
# differential_evolution step 6: f(x)= 0.079082
# differential_evolution step 7: f(x)= 0.079082
# differential_evolution step 8: f(x)= 0.079082
# differential_evolution step 9: f(x)= 0.0781752
# differential_evolution step 10: f(x)= 0.0750932
# differential_evolution step 11: f(x)= 0.0705012
# differential_evolution step 12: f(x)= 0.0705012
# differential_evolution step 13: f(x)= 0.0705012
# differential_evolution step 14: f(x)= 0.0691616
# differential_evolution step 15: f(x)= 0.0691616
# differential_evolution step 16: f(x)= 0.0691616
# differential_evolution step 17: f(x)= 0.0691616
# differential_evolution step 18: f(x)= 0.0691368
# differential_evolution step 19: f(x)= 0.0691368
# differential_evolution step 20: f(x)= 0.0691368
# differential_evolution step 21: f(x)= 0.0691368
# differential_evolution step 22: f(x)= 0.0686147
# differential_evolution step 23: f(x)= 0.0686147
# differential_evolution step 24: f(x)= 0.0686147
# differential_evolution step 25: f(x)= 0.0686045
# differential_evolution step 26: f(x)= 0.0685262
# differential_evolution step 27: f(x)= 0.0685262
# differential_evolution step 28: f(x)= 0.068244
# differential_evolution step 29: f(x)= 0.0682037
# differential_evolution step 30: f(x)= 0.0681627
# differential_evolution step 31: f(x)= 0.0681627
# differential_evolution step 32: f(x)= 0.0681627
# differential_evolution step 33: f(x)= 0.0681627
# differential_evolution step 34: f(x)= 0.0676556
# end diff evolution
# result was:  [0.35071567 0.31505171 0.03057059 0.00872928]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0878689
# differential_evolution step 2: f(x)= 0.0401499
# differential_evolution step 3: f(x)= 0.0401499
# differential_evolution step 4: f(x)= 0.0401499
# differential_evolution step 5: f(x)= 0.0401499
# differential_evolution step 6: f(x)= 0.0363731
# differential_evolution step 7: f(x)= 0.0363731
# differential_evolution step 8: f(x)= 0.0363731
# differential_evolution step 9: f(x)= 0.0353536
# differential_evolution step 10: f(x)= 0.0303045
# differential_evolution step 11: f(x)= 0.0303045
# differential_evolution step 12: f(x)= 0.0303045
# differential_evolution step 13: f(x)= 0.0303045
# differential_evolution step 14: f(x)= 0.0303045
# differential_evolution step 15: f(x)= 0.0303045
# differential_evolution step 16: f(x)= 0.0297214
# differential_evolution step 17: f(x)= 0.0297214
# differential_evolution step 18: f(x)= 0.0273221
# differential_evolution step 19: f(x)= 0.0258044
# differential_evolution step 20: f(x)= 0.0257811
# differential_evolution step 21: f(x)= 0.0257811
# differential_evolution step 22: f(x)= 0.0257811
# differential_evolution step 23: f(x)= 0.0257811
# differential_evolution step 24: f(x)= 0.0257811
# differential_evolution step 25: f(x)= 0.0257811
# differential_evolution step 26: f(x)= 0.0257811
# differential_evolution step 27: f(x)= 0.0257811
# differential_evolution step 28: f(x)= 0.0257811
# differential_evolution step 29: f(x)= 0.0257811
# differential_evolution step 30: f(x)= 0.0257811
# differential_evolution step 31: f(x)= 0.0257811
# differential_evolution step 32: f(x)= 0.0257629
# differential_evolution step 33: f(x)= 0.0257629
# differential_evolution step 34: f(x)= 0.0257629
# differential_evolution step 35: f(x)= 0.0257629
# differential_evolution step 36: f(x)= 0.0257058
# differential_evolution step 37: f(x)= 0.0257058
# differential_evolution step 38: f(x)= 0.0257058
# differential_evolution step 39: f(x)= 0.0257058
# differential_evolution step 40: f(x)= 0.0248427
# differential_evolution step 41: f(x)= 0.0248427
# differential_evolution step 42: f(x)= 0.0248427
# differential_evolution step 43: f(x)= 0.0247186
# differential_evolution step 44: f(x)= 0.0247186
# differential_evolution step 45: f(x)= 0.0247186
# differential_evolution step 46: f(x)= 0.0247186
# differential_evolution step 47: f(x)= 0.0247186
# differential_evolution step 48: f(x)= 0.0247186
# differential_evolution step 49: f(x)= 0.0247186
# end diff evolution
# result was:  [0.09704172 0.41208333 0.14572962 0.04128018]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0320947
# differential_evolution step 2: f(x)= 0.0320947
# differential_evolution step 3: f(x)= 0.0252815
# differential_evolution step 4: f(x)= 0.0252815
# differential_evolution step 5: f(x)= 0.0241977
# differential_evolution step 6: f(x)= 0.0220563
# differential_evolution step 7: f(x)= 0.0146919
# differential_evolution step 8: f(x)= 0.0146919
# differential_evolution step 9: f(x)= 0.0146919
# differential_evolution step 10: f(x)= 0.0146919
# differential_evolution step 11: f(x)= 0.0146919
# differential_evolution step 12: f(x)= 0.013183
# differential_evolution step 13: f(x)= 0.0130941
# differential_evolution step 14: f(x)= 0.01296
# differential_evolution step 15: f(x)= 0.0124494
# differential_evolution step 16: f(x)= 0.0124494
# differential_evolution step 17: f(x)= 0.0124494
# differential_evolution step 18: f(x)= 0.0124494
# differential_evolution step 19: f(x)= 0.0124494
# differential_evolution step 20: f(x)= 0.0123387
# differential_evolution step 21: f(x)= 0.0123035
# differential_evolution step 22: f(x)= 0.0122332
# differential_evolution step 23: f(x)= 0.0122332
# differential_evolution step 24: f(x)= 0.011966
# differential_evolution step 25: f(x)= 0.0119272
# differential_evolution step 26: f(x)= 0.0119272
# differential_evolution step 27: f(x)= 0.0119272
# differential_evolution step 28: f(x)= 0.0117939
# differential_evolution step 29: f(x)= 0.0117939
# differential_evolution step 30: f(x)= 0.0117939
# differential_evolution step 31: f(x)= 0.0117939
# differential_evolution step 32: f(x)= 0.0117939
# differential_evolution step 33: f(x)= 0.0117939
# differential_evolution step 34: f(x)= 0.0117939
# differential_evolution step 35: f(x)= 0.0117939
# differential_evolution step 36: f(x)= 0.0117939
# differential_evolution step 37: f(x)= 0.0117847
# differential_evolution step 38: f(x)= 0.0117847
# differential_evolution step 39: f(x)= 0.0117847
# differential_evolution step 40: f(x)= 0.0117847
# differential_evolution step 41: f(x)= 0.0117702
# differential_evolution step 42: f(x)= 0.0117702
# differential_evolution step 43: f(x)= 0.0117702
# differential_evolution step 44: f(x)= 0.0117702
# differential_evolution step 45: f(x)= 0.0117631
# differential_evolution step 46: f(x)= 0.0117631
# differential_evolution step 47: f(x)= 0.0117565
# end diff evolution
# result was:  [0.01934709 0.49138183 0.04869405 0.05006848]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0427814
# differential_evolution step 2: f(x)= 0.0427814
# differential_evolution step 3: f(x)= 0.0427814
# differential_evolution step 4: f(x)= 0.0427814
# differential_evolution step 5: f(x)= 0.0416734
# differential_evolution step 6: f(x)= 0.040226
# differential_evolution step 7: f(x)= 0.0381042
# differential_evolution step 8: f(x)= 0.0381042
# differential_evolution step 9: f(x)= 0.0357531
# differential_evolution step 10: f(x)= 0.0349108
# differential_evolution step 11: f(x)= 0.0342391
# differential_evolution step 12: f(x)= 0.0340457
# differential_evolution step 13: f(x)= 0.0340457
# differential_evolution step 14: f(x)= 0.0334662
# differential_evolution step 15: f(x)= 0.0334662
# differential_evolution step 16: f(x)= 0.0333886
# differential_evolution step 17: f(x)= 0.0330492
# differential_evolution step 18: f(x)= 0.033039
# differential_evolution step 19: f(x)= 0.0328908
# differential_evolution step 20: f(x)= 0.0328908
# differential_evolution step 21: f(x)= 0.0328908
# differential_evolution step 22: f(x)= 0.0328908
# differential_evolution step 23: f(x)= 0.0328908
# differential_evolution step 24: f(x)= 0.0328405
# differential_evolution step 25: f(x)= 0.0328405
# differential_evolution step 26: f(x)= 0.0326437
# differential_evolution step 27: f(x)= 0.0326437
# differential_evolution step 28: f(x)= 0.0325594
# differential_evolution step 29: f(x)= 0.0324567
# differential_evolution step 30: f(x)= 0.0324567
# end diff evolution
# result was:  [0.20068372 0.44885984 0.05587369 0.03735427]
# integrating geodesic
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0673812
# differential_evolution step 2: f(x)= 0.0552061
# differential_evolution step 3: f(x)= 0.0552061
# differential_evolution step 4: f(x)= 0.0552061
# differential_evolution step 5: f(x)= 0.0462219
# differential_evolution step 6: f(x)= 0.0462219
# differential_evolution step 7: f(x)= 0.0453611
# differential_evolution step 8: f(x)= 0.0453611
# differential_evolution step 9: f(x)= 0.0433622
# differential_evolution step 10: f(x)= 0.0433622
# differential_evolution step 11: f(x)= 0.0433622
# differential_evolution step 12: f(x)= 0.0433622
# differential_evolution step 13: f(x)= 0.0389931
# differential_evolution step 14: f(x)= 0.0389931
# differential_evolution step 15: f(x)= 0.0389931
# differential_evolution step 16: f(x)= 0.0389931
# differential_evolution step 17: f(x)= 0.0389931
# differential_evolution step 18: f(x)= 0.0368681
# differential_evolution step 19: f(x)= 0.0368577
# differential_evolution step 20: f(x)= 0.0368577
# differential_evolution step 21: f(x)= 0.035501
# differential_evolution step 22: f(x)= 0.035501
# differential_evolution step 23: f(x)= 0.035501
# differential_evolution step 24: f(x)= 0.035501
# differential_evolution step 25: f(x)= 0.035501
# differential_evolution step 26: f(x)= 0.035501
# differential_evolution step 27: f(x)= 0.035501
# differential_evolution step 28: f(x)= 0.035445
# differential_evolution step 29: f(x)= 0.035445
# differential_evolution step 30: f(x)= 0.035445
# differential_evolution step 31: f(x)= 0.0354263
# differential_evolution step 32: f(x)= 0.0354147
# differential_evolution step 33: f(x)= 0.0354147
# differential_evolution step 34: f(x)= 0.0354128
# differential_evolution step 35: f(x)= 0.0354082
# differential_evolution step 36: f(x)= 0.0353975
# differential_evolution step 37: f(x)= 0.0353975
# differential_evolution step 38: f(x)= 0.0353975
# differential_evolution step 39: f(x)= 0.0353975
# end diff evolution
# result was:  [0.4143062  0.15179144 0.13010554 0.00950503]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0512767
# differential_evolution step 2: f(x)= 0.0512767
# differential_evolution step 3: f(x)= 0.0412889
# differential_evolution step 4: f(x)= 0.0250064
# differential_evolution step 5: f(x)= 0.0250064
# differential_evolution step 6: f(x)= 0.0250064
# differential_evolution step 7: f(x)= 0.0250064
# differential_evolution step 8: f(x)= 0.024513
# differential_evolution step 9: f(x)= 0.024513
# differential_evolution step 10: f(x)= 0.0230552
# differential_evolution step 11: f(x)= 0.0230552
# differential_evolution step 12: f(x)= 0.0230552
# differential_evolution step 13: f(x)= 0.0230552
# differential_evolution step 14: f(x)= 0.0230552
# differential_evolution step 15: f(x)= 0.0230552
# differential_evolution step 16: f(x)= 0.0230552
# differential_evolution step 17: f(x)= 0.0227605
# differential_evolution step 18: f(x)= 0.0227605
# differential_evolution step 19: f(x)= 0.0227246
# differential_evolution step 20: f(x)= 0.0227246
# differential_evolution step 21: f(x)= 0.0226149
# differential_evolution step 22: f(x)= 0.0221165
# differential_evolution step 23: f(x)= 0.0221165
# differential_evolution step 24: f(x)= 0.0221165
# differential_evolution step 25: f(x)= 0.0221165
# differential_evolution step 26: f(x)= 0.0221165
# differential_evolution step 27: f(x)= 0.0221115
# differential_evolution step 28: f(x)= 0.0221115
# differential_evolution step 29: f(x)= 0.0221115
# differential_evolution step 30: f(x)= 0.0220389
# differential_evolution step 31: f(x)= 0.0220211
# differential_evolution step 32: f(x)= 0.0219375
# differential_evolution step 33: f(x)= 0.02185
# differential_evolution step 34: f(x)= 0.02185
# differential_evolution step 35: f(x)= 0.02185
# differential_evolution step 36: f(x)= 0.02185
# differential_evolution step 37: f(x)= 0.02185
# differential_evolution step 38: f(x)= 0.0218231
# differential_evolution step 39: f(x)= 0.0218231
# differential_evolution step 40: f(x)= 0.0218231
# differential_evolution step 41: f(x)= 0.0217605
# differential_evolution step 42: f(x)= 0.0217224
# differential_evolution step 43: f(x)= 0.0217188
# differential_evolution step 44: f(x)= 0.0217131
# differential_evolution step 45: f(x)= 0.0217131
# end diff evolution
# result was:  [0.10701136 0.3800848  0.15711921 0.05016728]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0500854
# differential_evolution step 2: f(x)= 0.0284942
# differential_evolution step 3: f(x)= 0.0212605
# differential_evolution step 4: f(x)= 0.0212605
# differential_evolution step 5: f(x)= 0.0171018
# differential_evolution step 6: f(x)= 0.0171018
# differential_evolution step 7: f(x)= 0.0171018
# differential_evolution step 8: f(x)= 0.0163303
# differential_evolution step 9: f(x)= 0.0158569
# differential_evolution step 10: f(x)= 0.0158569
# differential_evolution step 11: f(x)= 0.015493
# differential_evolution step 12: f(x)= 0.0154287
# differential_evolution step 13: f(x)= 0.0154287
# differential_evolution step 14: f(x)= 0.0151147
# differential_evolution step 15: f(x)= 0.0150414
# differential_evolution step 16: f(x)= 0.0150414
# differential_evolution step 17: f(x)= 0.0147915
# differential_evolution step 18: f(x)= 0.0147915
# differential_evolution step 19: f(x)= 0.0147915
# differential_evolution step 20: f(x)= 0.0147915
# differential_evolution step 21: f(x)= 0.0147892
# differential_evolution step 22: f(x)= 0.0147892
# differential_evolution step 23: f(x)= 0.0147594
# end diff evolution
# result was:  [0.15040314 0.41432903 0.11541938 0.05158599]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0429976
# differential_evolution step 2: f(x)= 0.0429976
# differential_evolution step 3: f(x)= 0.0429976
# differential_evolution step 4: f(x)= 0.0381491
# differential_evolution step 5: f(x)= 0.0381491
# differential_evolution step 6: f(x)= 0.0359469
# differential_evolution step 7: f(x)= 0.0247619
# differential_evolution step 8: f(x)= 0.0247619
# differential_evolution step 9: f(x)= 0.0244527
# differential_evolution step 10: f(x)= 0.0244527
# differential_evolution step 11: f(x)= 0.0243635
# differential_evolution step 12: f(x)= 0.0243635
# differential_evolution step 13: f(x)= 0.0243635
# differential_evolution step 14: f(x)= 0.0229078
# differential_evolution step 15: f(x)= 0.0229078
# differential_evolution step 16: f(x)= 0.0229078
# differential_evolution step 17: f(x)= 0.0223251
# differential_evolution step 18: f(x)= 0.0223251
# differential_evolution step 19: f(x)= 0.0207444
# differential_evolution step 20: f(x)= 0.0205889
# differential_evolution step 21: f(x)= 0.0205889
# differential_evolution step 22: f(x)= 0.0205889
# differential_evolution step 23: f(x)= 0.0205889
# differential_evolution step 24: f(x)= 0.0205889
# differential_evolution step 25: f(x)= 0.019558
# differential_evolution step 26: f(x)= 0.0188084
# differential_evolution step 27: f(x)= 0.0188084
# differential_evolution step 28: f(x)= 0.0188084
# differential_evolution step 29: f(x)= 0.0188084
# differential_evolution step 30: f(x)= 0.0187119
# differential_evolution step 31: f(x)= 0.018637
# differential_evolution step 32: f(x)= 0.018637
# differential_evolution step 33: f(x)= 0.018637
# differential_evolution step 34: f(x)= 0.018637
# differential_evolution step 35: f(x)= 0.018637
# differential_evolution step 36: f(x)= 0.0186276
# differential_evolution step 37: f(x)= 0.0185663
# differential_evolution step 38: f(x)= 0.0185663
# differential_evolution step 39: f(x)= 0.0185663
# differential_evolution step 40: f(x)= 0.0184271
# differential_evolution step 41: f(x)= 0.0184271
# differential_evolution step 42: f(x)= 0.0184271
# differential_evolution step 43: f(x)= 0.0181843
# differential_evolution step 44: f(x)= 0.0181843
# differential_evolution step 45: f(x)= 0.0181218
# differential_evolution step 46: f(x)= 0.0181218
# differential_evolution step 47: f(x)= 0.018072
# differential_evolution step 48: f(x)= 0.018072
# differential_evolution step 49: f(x)= 0.0180564
# differential_evolution step 50: f(x)= 0.0180564
# end diff evolution
# result was:  [0.07078915 0.19886385 0.32184429 0.01508016]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0675727
# differential_evolution step 2: f(x)= 0.0344287
# differential_evolution step 3: f(x)= 0.0275536
# differential_evolution step 4: f(x)= 0.0275536
# differential_evolution step 5: f(x)= 0.0273833
# differential_evolution step 6: f(x)= 0.0249726
# differential_evolution step 7: f(x)= 0.0232653
# differential_evolution step 8: f(x)= 0.0222353
# differential_evolution step 9: f(x)= 0.0222353
# differential_evolution step 10: f(x)= 0.0222353
# differential_evolution step 11: f(x)= 0.0222353
# differential_evolution step 12: f(x)= 0.0220358
# differential_evolution step 13: f(x)= 0.0220358
# differential_evolution step 14: f(x)= 0.0220358
# differential_evolution step 15: f(x)= 0.0220358
# differential_evolution step 16: f(x)= 0.0220358
# differential_evolution step 17: f(x)= 0.0220358
# differential_evolution step 18: f(x)= 0.021943
# differential_evolution step 19: f(x)= 0.021943
# differential_evolution step 20: f(x)= 0.0216889
# differential_evolution step 21: f(x)= 0.0216889
# differential_evolution step 22: f(x)= 0.0215344
# differential_evolution step 23: f(x)= 0.0215344
# differential_evolution step 24: f(x)= 0.0214023
# differential_evolution step 25: f(x)= 0.0201544
# differential_evolution step 26: f(x)= 0.0201544
# differential_evolution step 27: f(x)= 0.0199225
# differential_evolution step 28: f(x)= 0.0199225
# differential_evolution step 29: f(x)= 0.0198098
# differential_evolution step 30: f(x)= 0.0197101
# differential_evolution step 31: f(x)= 0.0196725
# differential_evolution step 32: f(x)= 0.0196725
# differential_evolution step 33: f(x)= 0.0190269
# differential_evolution step 34: f(x)= 0.0190269
# differential_evolution step 35: f(x)= 0.0190269
# differential_evolution step 36: f(x)= 0.0190269
# differential_evolution step 37: f(x)= 0.0190269
# differential_evolution step 38: f(x)= 0.0189787
# differential_evolution step 39: f(x)= 0.0189787
# differential_evolution step 40: f(x)= 0.0189787
# differential_evolution step 41: f(x)= 0.0189787
# differential_evolution step 42: f(x)= 0.0189787
# differential_evolution step 43: f(x)= 0.0189069
# differential_evolution step 44: f(x)= 0.0187874
# differential_evolution step 45: f(x)= 0.0187804
# differential_evolution step 46: f(x)= 0.0187562
# differential_evolution step 47: f(x)= 0.0187562
# differential_evolution step 48: f(x)= 0.0187562
# differential_evolution step 49: f(x)= 0.0187562
# differential_evolution step 50: f(x)= 0.0187463
# end diff evolution
# result was:  [0.03103326 0.07786967 0.34348405 0.13282616]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0391246
# differential_evolution step 2: f(x)= 0.0391246
# differential_evolution step 3: f(x)= 0.0391246
# differential_evolution step 4: f(x)= 0.0380939
# differential_evolution step 5: f(x)= 0.0380939
# differential_evolution step 6: f(x)= 0.0370059
# differential_evolution step 7: f(x)= 0.0332344
# differential_evolution step 8: f(x)= 0.0332344
# differential_evolution step 9: f(x)= 0.0328448
# differential_evolution step 10: f(x)= 0.0328448
# differential_evolution step 11: f(x)= 0.0304743
# differential_evolution step 12: f(x)= 0.0304743
# differential_evolution step 13: f(x)= 0.0304743
# differential_evolution step 14: f(x)= 0.0298011
# differential_evolution step 15: f(x)= 0.0298011
# differential_evolution step 16: f(x)= 0.0298011
# differential_evolution step 17: f(x)= 0.0298011
# differential_evolution step 18: f(x)= 0.0298011
# differential_evolution step 19: f(x)= 0.0293228
# differential_evolution step 20: f(x)= 0.0293228
# differential_evolution step 21: f(x)= 0.0293228
# differential_evolution step 22: f(x)= 0.0293228
# differential_evolution step 23: f(x)= 0.029282
# differential_evolution step 24: f(x)= 0.0292748
# differential_evolution step 25: f(x)= 0.0292591
# differential_evolution step 26: f(x)= 0.0292591
# end diff evolution
# result was:  [0.31825333 0.264556   0.07888202 0.01671809]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0532263
# differential_evolution step 2: f(x)= 0.0514332
# differential_evolution step 3: f(x)= 0.0514332
# differential_evolution step 4: f(x)= 0.0514332
# differential_evolution step 5: f(x)= 0.0481156
# differential_evolution step 6: f(x)= 0.0379615
# differential_evolution step 7: f(x)= 0.0379615
# differential_evolution step 8: f(x)= 0.0379615
# differential_evolution step 9: f(x)= 0.0379615
# differential_evolution step 10: f(x)= 0.0379615
# differential_evolution step 11: f(x)= 0.0379615
# differential_evolution step 12: f(x)= 0.0379615
# differential_evolution step 13: f(x)= 0.0367653
# differential_evolution step 14: f(x)= 0.0367653
# differential_evolution step 15: f(x)= 0.0367653
# differential_evolution step 16: f(x)= 0.0364726
# differential_evolution step 17: f(x)= 0.0363863
# differential_evolution step 18: f(x)= 0.0363863
# differential_evolution step 19: f(x)= 0.0357475
# differential_evolution step 20: f(x)= 0.0357475
# differential_evolution step 21: f(x)= 0.0355068
# differential_evolution step 22: f(x)= 0.0355068
# differential_evolution step 23: f(x)= 0.0355068
# differential_evolution step 24: f(x)= 0.0355068
# differential_evolution step 25: f(x)= 0.0355068
# differential_evolution step 26: f(x)= 0.0355068
# differential_evolution step 27: f(x)= 0.0355068
# end diff evolution
# result was:  [0.05579727 0.00879483 0.16783591 0.38570987]
# integrating geodesic
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0531986
# differential_evolution step 2: f(x)= 0.0531986
# differential_evolution step 3: f(x)= 0.0531986
# differential_evolution step 4: f(x)= 0.0484655
# differential_evolution step 5: f(x)= 0.0463326
# differential_evolution step 6: f(x)= 0.0439979
# differential_evolution step 7: f(x)= 0.0439979
# differential_evolution step 8: f(x)= 0.04295
# differential_evolution step 9: f(x)= 0.04295
# differential_evolution step 10: f(x)= 0.0414124
# differential_evolution step 11: f(x)= 0.0382852
# differential_evolution step 12: f(x)= 0.0382852
# differential_evolution step 13: f(x)= 0.0382852
# differential_evolution step 14: f(x)= 0.0380615
# differential_evolution step 15: f(x)= 0.0377345
# differential_evolution step 16: f(x)= 0.0377345
# differential_evolution step 17: f(x)= 0.0377345
# differential_evolution step 18: f(x)= 0.0373868
# differential_evolution step 19: f(x)= 0.0364333
# differential_evolution step 20: f(x)= 0.0361869
# differential_evolution step 21: f(x)= 0.0361869
# differential_evolution step 22: f(x)= 0.0359959
# differential_evolution step 23: f(x)= 0.0359959
# differential_evolution step 24: f(x)= 0.0359959
# differential_evolution step 25: f(x)= 0.0359959
# differential_evolution step 26: f(x)= 0.0358391
# differential_evolution step 27: f(x)= 0.0358391
# differential_evolution step 28: f(x)= 0.0358391
# differential_evolution step 29: f(x)= 0.0358391
# differential_evolution step 30: f(x)= 0.0358391
# differential_evolution step 31: f(x)= 0.0358299
# differential_evolution step 32: f(x)= 0.0357048
# end diff evolution
# result was:  [0.04690678 0.00999731 0.16839993 0.37431552]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0450641
# differential_evolution step 2: f(x)= 0.0317124
# differential_evolution step 3: f(x)= 0.0317124
# differential_evolution step 4: f(x)= 0.0317124
# differential_evolution step 5: f(x)= 0.0242132
# differential_evolution step 6: f(x)= 0.0242132
# differential_evolution step 7: f(x)= 0.0242132
# differential_evolution step 8: f(x)= 0.0242132
# differential_evolution step 9: f(x)= 0.0224881
# differential_evolution step 10: f(x)= 0.0224881
# differential_evolution step 11: f(x)= 0.0224881
# differential_evolution step 12: f(x)= 0.0224881
# differential_evolution step 13: f(x)= 0.0224881
# differential_evolution step 14: f(x)= 0.0224881
# differential_evolution step 15: f(x)= 0.0224881
# differential_evolution step 16: f(x)= 0.0222611
# differential_evolution step 17: f(x)= 0.0208011
# differential_evolution step 18: f(x)= 0.0208011
# differential_evolution step 19: f(x)= 0.0203097
# differential_evolution step 20: f(x)= 0.0203097
# differential_evolution step 21: f(x)= 0.0203097
# differential_evolution step 22: f(x)= 0.0203097
# differential_evolution step 23: f(x)= 0.0203097
# differential_evolution step 24: f(x)= 0.0203097
# differential_evolution step 25: f(x)= 0.0203097
# differential_evolution step 26: f(x)= 0.0203097
# differential_evolution step 27: f(x)= 0.0197772
# differential_evolution step 28: f(x)= 0.01976
# differential_evolution step 29: f(x)= 0.0194889
# differential_evolution step 30: f(x)= 0.0186661
# differential_evolution step 31: f(x)= 0.0186661
# differential_evolution step 32: f(x)= 0.0186661
# differential_evolution step 33: f(x)= 0.0186661
# differential_evolution step 34: f(x)= 0.0186661
# differential_evolution step 35: f(x)= 0.0183997
# differential_evolution step 36: f(x)= 0.0183997
# differential_evolution step 37: f(x)= 0.0172333
# differential_evolution step 38: f(x)= 0.0172333
# differential_evolution step 39: f(x)= 0.0172333
# differential_evolution step 40: f(x)= 0.0172333
# differential_evolution step 41: f(x)= 0.0172333
# differential_evolution step 42: f(x)= 0.0171385
# differential_evolution step 43: f(x)= 0.0171325
# differential_evolution step 44: f(x)= 0.0170662
# differential_evolution step 45: f(x)= 0.0170507
# differential_evolution step 46: f(x)= 0.0168784
# differential_evolution step 47: f(x)= 0.0168784
# differential_evolution step 48: f(x)= 0.0168784
# differential_evolution step 49: f(x)= 0.0168099
# differential_evolution step 50: f(x)= 0.0167312
# end diff evolution
# result was:  [0.11397994 0.21740142 0.29505028 0.01181872]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0327469
# differential_evolution step 2: f(x)= 0.0283551
# differential_evolution step 3: f(x)= 0.0268715
# differential_evolution step 4: f(x)= 0.0268715
# differential_evolution step 5: f(x)= 0.0243152
# differential_evolution step 6: f(x)= 0.0215298
# differential_evolution step 7: f(x)= 0.019493
# differential_evolution step 8: f(x)= 0.019493
# differential_evolution step 9: f(x)= 0.019493
# differential_evolution step 10: f(x)= 0.0187877
# differential_evolution step 11: f(x)= 0.0173269
# differential_evolution step 12: f(x)= 0.0167432
# differential_evolution step 13: f(x)= 0.0167432
# differential_evolution step 14: f(x)= 0.0167432
# differential_evolution step 15: f(x)= 0.0167432
# differential_evolution step 16: f(x)= 0.0167432
# differential_evolution step 17: f(x)= 0.0165657
# differential_evolution step 18: f(x)= 0.0163054
# differential_evolution step 19: f(x)= 0.0163054
# differential_evolution step 20: f(x)= 0.0151849
# differential_evolution step 21: f(x)= 0.0151849
# differential_evolution step 22: f(x)= 0.0151849
# differential_evolution step 23: f(x)= 0.0151849
# differential_evolution step 24: f(x)= 0.0151849
# differential_evolution step 25: f(x)= 0.0151849
# differential_evolution step 26: f(x)= 0.0149758
# differential_evolution step 27: f(x)= 0.0149758
# differential_evolution step 28: f(x)= 0.0149758
# differential_evolution step 29: f(x)= 0.0149758
# differential_evolution step 30: f(x)= 0.0145338
# differential_evolution step 31: f(x)= 0.0145338
# differential_evolution step 32: f(x)= 0.0145338
# differential_evolution step 33: f(x)= 0.0144958
# differential_evolution step 34: f(x)= 0.0144867
# differential_evolution step 35: f(x)= 0.0143231
# differential_evolution step 36: f(x)= 0.0142834
# differential_evolution step 37: f(x)= 0.0141759
# differential_evolution step 38: f(x)= 0.0141759
# differential_evolution step 39: f(x)= 0.0141759
# differential_evolution step 40: f(x)= 0.0141759
# differential_evolution step 41: f(x)= 0.0141642
# differential_evolution step 42: f(x)= 0.0141151
# differential_evolution step 43: f(x)= 0.0141151
# differential_evolution step 44: f(x)= 0.0141151
# differential_evolution step 45: f(x)= 0.0141151
# differential_evolution step 46: f(x)= 0.0141143
# end diff evolution
# result was:  [0.13913675 0.35338672 0.17010058 0.04164577]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0431067
# differential_evolution step 2: f(x)= 0.0344877
# differential_evolution step 3: f(x)= 0.0311524
# differential_evolution step 4: f(x)= 0.0307009
# differential_evolution step 5: f(x)= 0.0250317
# differential_evolution step 6: f(x)= 0.0250317
# differential_evolution step 7: f(x)= 0.019582
# differential_evolution step 8: f(x)= 0.0175498
# differential_evolution step 9: f(x)= 0.0175498
# differential_evolution step 10: f(x)= 0.0175495
# differential_evolution step 11: f(x)= 0.0169711
# differential_evolution step 12: f(x)= 0.0169711
# differential_evolution step 13: f(x)= 0.0158574
# differential_evolution step 14: f(x)= 0.0158574
# differential_evolution step 15: f(x)= 0.0158308
# differential_evolution step 16: f(x)= 0.0158308
# differential_evolution step 17: f(x)= 0.0158308
# differential_evolution step 18: f(x)= 0.0158308
# differential_evolution step 19: f(x)= 0.0158308
# differential_evolution step 20: f(x)= 0.0158308
# differential_evolution step 21: f(x)= 0.0149396
# differential_evolution step 22: f(x)= 0.0149396
# differential_evolution step 23: f(x)= 0.0149396
# differential_evolution step 24: f(x)= 0.0149396
# differential_evolution step 25: f(x)= 0.0147123
# differential_evolution step 26: f(x)= 0.0147123
# differential_evolution step 27: f(x)= 0.0147123
# differential_evolution step 28: f(x)= 0.0140741
# differential_evolution step 29: f(x)= 0.0140741
# differential_evolution step 30: f(x)= 0.0140741
# differential_evolution step 31: f(x)= 0.0139744
# differential_evolution step 32: f(x)= 0.013956
# differential_evolution step 33: f(x)= 0.0135094
# differential_evolution step 34: f(x)= 0.0135094
# differential_evolution step 35: f(x)= 0.0135094
# differential_evolution step 36: f(x)= 0.0133462
# differential_evolution step 37: f(x)= 0.0133462
# differential_evolution step 38: f(x)= 0.0133462
# differential_evolution step 39: f(x)= 0.0132958
# differential_evolution step 40: f(x)= 0.0132398
# differential_evolution step 41: f(x)= 0.013226
# differential_evolution step 42: f(x)= 0.013226
# differential_evolution step 43: f(x)= 0.0131808
# differential_evolution step 44: f(x)= 0.0131808
# differential_evolution step 45: f(x)= 0.0131808
# differential_evolution step 46: f(x)= 0.0131808
# differential_evolution step 47: f(x)= 0.0131808
# differential_evolution step 48: f(x)= 0.0131808
# differential_evolution step 49: f(x)= 0.0131808
# differential_evolution step 50: f(x)= 0.0131764
# end diff evolution
# result was:  [0.19953959 0.36109801 0.11992108 0.04750521]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0479443
# differential_evolution step 2: f(x)= 0.0479443
# differential_evolution step 3: f(x)= 0.0475593
# differential_evolution step 4: f(x)= 0.041636
# differential_evolution step 5: f(x)= 0.041636
# differential_evolution step 6: f(x)= 0.039911
# differential_evolution step 7: f(x)= 0.0377763
# differential_evolution step 8: f(x)= 0.0348437
# differential_evolution step 9: f(x)= 0.0339168
# differential_evolution step 10: f(x)= 0.0339168
# differential_evolution step 11: f(x)= 0.0326467
# differential_evolution step 12: f(x)= 0.0326467
# differential_evolution step 13: f(x)= 0.0324866
# differential_evolution step 14: f(x)= 0.032173
# differential_evolution step 15: f(x)= 0.0317698
# differential_evolution step 16: f(x)= 0.0317209
# differential_evolution step 17: f(x)= 0.0312817
# differential_evolution step 18: f(x)= 0.0309469
# differential_evolution step 19: f(x)= 0.0308018
# differential_evolution step 20: f(x)= 0.0308018
# differential_evolution step 21: f(x)= 0.0307755
# differential_evolution step 22: f(x)= 0.0307755
# differential_evolution step 23: f(x)= 0.0307755
# end diff evolution
# result was:  [0.42805425 0.09004718 0.08539949 0.01221334]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0512115
# differential_evolution step 2: f(x)= 0.0497316
# differential_evolution step 3: f(x)= 0.0497316
# differential_evolution step 4: f(x)= 0.0448599
# differential_evolution step 5: f(x)= 0.028962
# differential_evolution step 6: f(x)= 0.028962
# differential_evolution step 7: f(x)= 0.028962
# differential_evolution step 8: f(x)= 0.028962
# differential_evolution step 9: f(x)= 0.0279143
# differential_evolution step 10: f(x)= 0.0279143
# differential_evolution step 11: f(x)= 0.0279143
# differential_evolution step 12: f(x)= 0.026666
# differential_evolution step 13: f(x)= 0.0260935
# differential_evolution step 14: f(x)= 0.0260935
# differential_evolution step 15: f(x)= 0.0256174
# differential_evolution step 16: f(x)= 0.0256174
# differential_evolution step 17: f(x)= 0.0252719
# differential_evolution step 18: f(x)= 0.0252719
# differential_evolution step 19: f(x)= 0.0252719
# differential_evolution step 20: f(x)= 0.0252719
# differential_evolution step 21: f(x)= 0.0252237
# differential_evolution step 22: f(x)= 0.0252237
# differential_evolution step 23: f(x)= 0.0252167
# differential_evolution step 24: f(x)= 0.0252167
# differential_evolution step 25: f(x)= 0.0252167
# differential_evolution step 26: f(x)= 0.0252071
# differential_evolution step 27: f(x)= 0.0251234
# differential_evolution step 28: f(x)= 0.0250975
# differential_evolution step 29: f(x)= 0.0250637
# differential_evolution step 30: f(x)= 0.0250637
# differential_evolution step 31: f(x)= 0.0250637
# differential_evolution step 32: f(x)= 0.0250199
# differential_evolution step 33: f(x)= 0.0250043
# end diff evolution
# result was:  [0.34583143 0.21604206 0.14907838 0.0162005 ]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0534753
# differential_evolution step 2: f(x)= 0.0534753
# differential_evolution step 3: f(x)= 0.0381039
# differential_evolution step 4: f(x)= 0.0381039
# differential_evolution step 5: f(x)= 0.0381039
# differential_evolution step 6: f(x)= 0.0354664
# differential_evolution step 7: f(x)= 0.0299652
# differential_evolution step 8: f(x)= 0.0299652
# differential_evolution step 9: f(x)= 0.0299652
# differential_evolution step 10: f(x)= 0.0299652
# differential_evolution step 11: f(x)= 0.0299652
# differential_evolution step 12: f(x)= 0.0299652
# differential_evolution step 13: f(x)= 0.0299652
# differential_evolution step 14: f(x)= 0.0294907
# differential_evolution step 15: f(x)= 0.0281922
# differential_evolution step 16: f(x)= 0.0271763
# differential_evolution step 17: f(x)= 0.0257161
# differential_evolution step 18: f(x)= 0.0253869
# differential_evolution step 19: f(x)= 0.0253869
# differential_evolution step 20: f(x)= 0.0253807
# differential_evolution step 21: f(x)= 0.0250396
# differential_evolution step 22: f(x)= 0.0249987
# differential_evolution step 23: f(x)= 0.0249987
# differential_evolution step 24: f(x)= 0.0249987
# differential_evolution step 25: f(x)= 0.0249987
# differential_evolution step 26: f(x)= 0.0248736
# differential_evolution step 27: f(x)= 0.0248661
# differential_evolution step 28: f(x)= 0.0247898
# differential_evolution step 29: f(x)= 0.0247533
# differential_evolution step 30: f(x)= 0.0246838
# differential_evolution step 31: f(x)= 0.0246661
# differential_evolution step 32: f(x)= 0.0246661
# end diff evolution
# result was:  [0.02504546 0.0648935  0.31243231 0.16904739]
# integrating geodesic
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0406355
# differential_evolution step 2: f(x)= 0.0406355
# differential_evolution step 3: f(x)= 0.0301171
# differential_evolution step 4: f(x)= 0.0301171
# differential_evolution step 5: f(x)= 0.0301171
# differential_evolution step 6: f(x)= 0.0301171
# differential_evolution step 7: f(x)= 0.0299077
# differential_evolution step 8: f(x)= 0.0292118
# differential_evolution step 9: f(x)= 0.0286802
# differential_evolution step 10: f(x)= 0.0286802
# differential_evolution step 11: f(x)= 0.0286802
# differential_evolution step 12: f(x)= 0.0286802
# differential_evolution step 13: f(x)= 0.0278721
# differential_evolution step 14: f(x)= 0.0275511
# differential_evolution step 15: f(x)= 0.0275511
# differential_evolution step 16: f(x)= 0.0272273
# differential_evolution step 17: f(x)= 0.0270058
# differential_evolution step 18: f(x)= 0.0270058
# differential_evolution step 19: f(x)= 0.027005
# differential_evolution step 20: f(x)= 0.027005
# differential_evolution step 21: f(x)= 0.0269981
# end diff evolution
# result was:  [0.4358368  0.08809771 0.1068783  0.00375392]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0408759
# differential_evolution step 2: f(x)= 0.0398438
# differential_evolution step 3: f(x)= 0.0361091
# differential_evolution step 4: f(x)= 0.0361091
# differential_evolution step 5: f(x)= 0.0361091
# differential_evolution step 6: f(x)= 0.0361091
# differential_evolution step 7: f(x)= 0.0357483
# differential_evolution step 8: f(x)= 0.0352495
# differential_evolution step 9: f(x)= 0.0343762
# differential_evolution step 10: f(x)= 0.0328162
# differential_evolution step 11: f(x)= 0.031701
# differential_evolution step 12: f(x)= 0.031701
# differential_evolution step 13: f(x)= 0.0303618
# differential_evolution step 14: f(x)= 0.029485
# differential_evolution step 15: f(x)= 0.0268872
# differential_evolution step 16: f(x)= 0.0268872
# differential_evolution step 17: f(x)= 0.0268872
# differential_evolution step 18: f(x)= 0.0268872
# differential_evolution step 19: f(x)= 0.0249817
# differential_evolution step 20: f(x)= 0.0249817
# differential_evolution step 21: f(x)= 0.0249817
# differential_evolution step 22: f(x)= 0.0249817
# differential_evolution step 23: f(x)= 0.0248743
# differential_evolution step 24: f(x)= 0.0247545
# differential_evolution step 25: f(x)= 0.0247545
# differential_evolution step 26: f(x)= 0.0247545
# differential_evolution step 27: f(x)= 0.0247545
# differential_evolution step 28: f(x)= 0.0247179
# differential_evolution step 29: f(x)= 0.0247179
# differential_evolution step 30: f(x)= 0.0246858
# differential_evolution step 31: f(x)= 0.0246858
# differential_evolution step 32: f(x)= 0.0246647
# differential_evolution step 33: f(x)= 0.0246647
# differential_evolution step 34: f(x)= 0.0246647
# differential_evolution step 35: f(x)= 0.0246647
# differential_evolution step 36: f(x)= 0.0246422
# end diff evolution
# result was:  [0.02296907 0.06477682 0.31074467 0.16902305]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0755757
# differential_evolution step 2: f(x)= 0.0755757
# differential_evolution step 3: f(x)= 0.0615957
# differential_evolution step 4: f(x)= 0.0430745
# differential_evolution step 5: f(x)= 0.0424318
# differential_evolution step 6: f(x)= 0.0409294
# differential_evolution step 7: f(x)= 0.0409294
# differential_evolution step 8: f(x)= 0.0409294
# differential_evolution step 9: f(x)= 0.0365291
# differential_evolution step 10: f(x)= 0.0365291
# differential_evolution step 11: f(x)= 0.0365291
# differential_evolution step 12: f(x)= 0.0348276
# differential_evolution step 13: f(x)= 0.0348276
# differential_evolution step 14: f(x)= 0.0345279
# differential_evolution step 15: f(x)= 0.0345127
# differential_evolution step 16: f(x)= 0.033665
# differential_evolution step 17: f(x)= 0.032041
# differential_evolution step 18: f(x)= 0.0307039
# differential_evolution step 19: f(x)= 0.0304447
# differential_evolution step 20: f(x)= 0.029806
# differential_evolution step 21: f(x)= 0.029806
# differential_evolution step 22: f(x)= 0.029806
# differential_evolution step 23: f(x)= 0.029806
# differential_evolution step 24: f(x)= 0.029806
# differential_evolution step 25: f(x)= 0.0297758
# differential_evolution step 26: f(x)= 0.0293384
# differential_evolution step 27: f(x)= 0.0291049
# differential_evolution step 28: f(x)= 0.0291049
# differential_evolution step 29: f(x)= 0.0289787
# differential_evolution step 30: f(x)= 0.0287572
# differential_evolution step 31: f(x)= 0.0287572
# differential_evolution step 32: f(x)= 0.0287572
# differential_evolution step 33: f(x)= 0.0287572
# differential_evolution step 34: f(x)= 0.0287214
# differential_evolution step 35: f(x)= 0.0287214
# differential_evolution step 36: f(x)= 0.0287214
# differential_evolution step 37: f(x)= 0.0287214
# differential_evolution step 38: f(x)= 0.0287166
# differential_evolution step 39: f(x)= 0.0287166
# differential_evolution step 40: f(x)= 0.0286553
# differential_evolution step 41: f(x)= 0.0286553
# differential_evolution step 42: f(x)= 0.0286553
# differential_evolution step 43: f(x)= 0.0286553
# differential_evolution step 44: f(x)= 0.0286553
# differential_evolution step 45: f(x)= 0.0286553
# differential_evolution step 46: f(x)= 0.0286388
# differential_evolution step 47: f(x)= 0.0286279
# differential_evolution step 48: f(x)= 0.0286279
# end diff evolution
# result was:  [0.00243947 0.02236793 0.13898492 0.41899902]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0435184
# differential_evolution step 2: f(x)= 0.0274976
# differential_evolution step 3: f(x)= 0.026534
# differential_evolution step 4: f(x)= 0.026534
# differential_evolution step 5: f(x)= 0.024673
# differential_evolution step 6: f(x)= 0.0155673
# differential_evolution step 7: f(x)= 0.0155673
# differential_evolution step 8: f(x)= 0.0155673
# differential_evolution step 9: f(x)= 0.0155673
# differential_evolution step 10: f(x)= 0.0155673
# differential_evolution step 11: f(x)= 0.0155673
# differential_evolution step 12: f(x)= 0.0154341
# differential_evolution step 13: f(x)= 0.0142885
# differential_evolution step 14: f(x)= 0.013254
# differential_evolution step 15: f(x)= 0.013254
# differential_evolution step 16: f(x)= 0.013254
# differential_evolution step 17: f(x)= 0.013254
# differential_evolution step 18: f(x)= 0.013254
# differential_evolution step 19: f(x)= 0.013254
# differential_evolution step 20: f(x)= 0.013254
# differential_evolution step 21: f(x)= 0.0129154
# differential_evolution step 22: f(x)= 0.0125184
# differential_evolution step 23: f(x)= 0.0125184
# differential_evolution step 24: f(x)= 0.0124075
# differential_evolution step 25: f(x)= 0.0123893
# differential_evolution step 26: f(x)= 0.0123893
# differential_evolution step 27: f(x)= 0.0123871
# differential_evolution step 28: f(x)= 0.0123871
# differential_evolution step 29: f(x)= 0.0123483
# differential_evolution step 30: f(x)= 0.0123483
# differential_evolution step 31: f(x)= 0.0123483
# differential_evolution step 32: f(x)= 0.012263
# differential_evolution step 33: f(x)= 0.012263
# differential_evolution step 34: f(x)= 0.012263
# differential_evolution step 35: f(x)= 0.012263
# differential_evolution step 36: f(x)= 0.0122516
# differential_evolution step 37: f(x)= 0.0122234
# differential_evolution step 38: f(x)= 0.0122234
# differential_evolution step 39: f(x)= 0.0122234
# differential_evolution step 40: f(x)= 0.0122234
# differential_evolution step 41: f(x)= 0.0122123
# differential_evolution step 42: f(x)= 0.0122123
# differential_evolution step 43: f(x)= 0.0122054
# end diff evolution
# result was:  [0.19356279 0.26682203 0.2144168  0.0202922 ]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0331675
# differential_evolution step 2: f(x)= 0.0331675
# differential_evolution step 3: f(x)= 0.0325735
# differential_evolution step 4: f(x)= 0.0297475
# differential_evolution step 5: f(x)= 0.0297475
# differential_evolution step 6: f(x)= 0.0297475
# differential_evolution step 7: f(x)= 0.0237693
# differential_evolution step 8: f(x)= 0.0237693
# differential_evolution step 9: f(x)= 0.0227078
# differential_evolution step 10: f(x)= 0.0227078
# differential_evolution step 11: f(x)= 0.0227078
# differential_evolution step 12: f(x)= 0.0206188
# differential_evolution step 13: f(x)= 0.0194567
# differential_evolution step 14: f(x)= 0.0194567
# differential_evolution step 15: f(x)= 0.0194567
# differential_evolution step 16: f(x)= 0.0194567
# differential_evolution step 17: f(x)= 0.0194567
# differential_evolution step 18: f(x)= 0.0191877
# differential_evolution step 19: f(x)= 0.0191877
# differential_evolution step 20: f(x)= 0.0191877
# differential_evolution step 21: f(x)= 0.0188745
# differential_evolution step 22: f(x)= 0.0188745
# differential_evolution step 23: f(x)= 0.0186208
# differential_evolution step 24: f(x)= 0.0184087
# differential_evolution step 25: f(x)= 0.0182465
# differential_evolution step 26: f(x)= 0.0182011
# differential_evolution step 27: f(x)= 0.0182011
# differential_evolution step 28: f(x)= 0.0180125
# differential_evolution step 29: f(x)= 0.0180027
# differential_evolution step 30: f(x)= 0.0180027
# differential_evolution step 31: f(x)= 0.0179898
# differential_evolution step 32: f(x)= 0.0179898
# differential_evolution step 33: f(x)= 0.0179836
# differential_evolution step 34: f(x)= 0.0179836
# differential_evolution step 35: f(x)= 0.0179759
# differential_evolution step 36: f(x)= 0.0179759
# differential_evolution step 37: f(x)= 0.0179759
# differential_evolution step 38: f(x)= 0.0179694
# differential_evolution step 39: f(x)= 0.0179694
# differential_evolution step 40: f(x)= 0.0179688
# differential_evolution step 41: f(x)= 0.0179655
# differential_evolution step 42: f(x)= 0.0179655
# differential_evolution step 43: f(x)= 0.0179655
# differential_evolution step 44: f(x)= 0.0179655
# differential_evolution step 45: f(x)= 0.0179655
# end diff evolution
# result was:  [0.1357742  0.17998859 0.29820405 0.01800551]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0540111
# differential_evolution step 2: f(x)= 0.0540111
# differential_evolution step 3: f(x)= 0.0540111
# differential_evolution step 4: f(x)= 0.051995
# differential_evolution step 5: f(x)= 0.0324081
# differential_evolution step 6: f(x)= 0.0324081
# differential_evolution step 7: f(x)= 0.0324081
# differential_evolution step 8: f(x)= 0.0322152
# differential_evolution step 9: f(x)= 0.0284269
# differential_evolution step 10: f(x)= 0.0284269
# differential_evolution step 11: f(x)= 0.0278469
# differential_evolution step 12: f(x)= 0.027686
# differential_evolution step 13: f(x)= 0.0276328
# differential_evolution step 14: f(x)= 0.027311
# differential_evolution step 15: f(x)= 0.0271279
# differential_evolution step 16: f(x)= 0.0269969
# differential_evolution step 17: f(x)= 0.0264486
# differential_evolution step 18: f(x)= 0.0264486
# differential_evolution step 19: f(x)= 0.0264486
# differential_evolution step 20: f(x)= 0.0263666
# differential_evolution step 21: f(x)= 0.0263666
# differential_evolution step 22: f(x)= 0.0263666
# differential_evolution step 23: f(x)= 0.0263666
# differential_evolution step 24: f(x)= 0.0263502
# differential_evolution step 25: f(x)= 0.0262102
# differential_evolution step 26: f(x)= 0.0260644
# differential_evolution step 27: f(x)= 0.0260644
# differential_evolution step 28: f(x)= 0.0260644
# differential_evolution step 29: f(x)= 0.0260644
# differential_evolution step 30: f(x)= 0.0260644
# differential_evolution step 31: f(x)= 0.026048
# differential_evolution step 32: f(x)= 0.0259767
# differential_evolution step 33: f(x)= 0.0259767
# differential_evolution step 34: f(x)= 0.0259197
# differential_evolution step 35: f(x)= 0.0258618
# differential_evolution step 36: f(x)= 0.0258618
# end diff evolution
# result was:  [0.35308427 0.21777762 0.15782117 0.00600215]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0528775
# differential_evolution step 2: f(x)= 0.0429213
# differential_evolution step 3: f(x)= 0.0429213
# differential_evolution step 4: f(x)= 0.0352958
# differential_evolution step 5: f(x)= 0.0292957
# differential_evolution step 6: f(x)= 0.0292957
# differential_evolution step 7: f(x)= 0.0292957
# differential_evolution step 8: f(x)= 0.0229921
# differential_evolution step 9: f(x)= 0.0196183
# differential_evolution step 10: f(x)= 0.0178113
# differential_evolution step 11: f(x)= 0.0178113
# differential_evolution step 12: f(x)= 0.0178113
# differential_evolution step 13: f(x)= 0.0178113
# differential_evolution step 14: f(x)= 0.0178113
# differential_evolution step 15: f(x)= 0.0178113
# differential_evolution step 16: f(x)= 0.0176908
# differential_evolution step 17: f(x)= 0.0175881
# differential_evolution step 18: f(x)= 0.0174765
# differential_evolution step 19: f(x)= 0.0174765
# differential_evolution step 20: f(x)= 0.017438
# differential_evolution step 21: f(x)= 0.017438
# differential_evolution step 22: f(x)= 0.017438
# differential_evolution step 23: f(x)= 0.0173969
# differential_evolution step 24: f(x)= 0.0173969
# differential_evolution step 25: f(x)= 0.0173969
# differential_evolution step 26: f(x)= 0.0173969
# differential_evolution step 27: f(x)= 0.0173511
# differential_evolution step 28: f(x)= 0.0173382
# differential_evolution step 29: f(x)= 0.017331
# end diff evolution
# result was:  [0.29361557 0.24069065 0.16870085 0.00814129]
# integrating geodesic

# %%
for i in range(12):
    print('vals: ', (g_four[0][i,:].reshape([28,28])[14,13:17]))
    plt.imshow(g_four[0][i,:].reshape([28,28]))
    plt.show()
# Out:
# vals:  [0.5 0.  0.  0. ]
# vals:  [0.4358368  0.08809771 0.1068783  0.00375392]
# vals:  [0.35308427 0.21777762 0.15782117 0.00600215]
# vals:  [0.29361557 0.24069065 0.16870085 0.00814129]
# vals:  [0.19356279 0.26682203 0.2144168  0.0202922 ]
# vals:  [0.1357742  0.17998859 0.29820405 0.01800551]
# vals:  [0.02296907 0.06477682 0.31074467 0.16902305]
# vals:  [0.00243947 0.02236793 0.13898492 0.41899902]
# vals:  [0.  0.  0.  0.5]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-d59d6882ca0b> in <module>()
#       1 for i in range(12):
# ----> 2     print('vals: ', (g_four[0][i,:].reshape([28,28])[14,13:17]))
#       3     plt.imshow(g_four[0][i,:].reshape([28,28]))
#       4     plt.show()
#
# IndexError: index 9 is out of bounds for axis 0 with size 9

# %%
g_four[1]
# Out:
# [0.1988582764066274,
#  0.13319850774136102,
#  0.10799347441723887,
#  0.09644975790647,
#  0.08999747232146385]

# %%
distance_geod_array(g_four[0])
# Out:
# integrating geodesic
# array([0.01343382, 0.01293076, 0.00862103, 0.00869505, 0.00887731,
#        0.0090446 , 0.01449938, 0.01389553])

# %%
g_twelve = compute_geodesic(start_pic, end_pic, num_div=9, num_passes=1)
# Out:
# integrating geodesic
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0510069
# differential_evolution step 2: f(x)= 0.0249059
# differential_evolution step 3: f(x)= 0.00651522
# differential_evolution step 4: f(x)= 0.00651522
# differential_evolution step 5: f(x)= 0.00651522
# differential_evolution step 6: f(x)= 0.00641671
# differential_evolution step 7: f(x)= 0.00641671
# differential_evolution step 8: f(x)= 0.00593552
# differential_evolution step 9: f(x)= 0.00593552
# differential_evolution step 10: f(x)= 0.00593552
# differential_evolution step 11: f(x)= 0.00433276
# differential_evolution step 12: f(x)= 0.00433276
# differential_evolution step 13: f(x)= 0.00398254
# differential_evolution step 14: f(x)= 0.00398254
# differential_evolution step 15: f(x)= 0.00149669
# differential_evolution step 16: f(x)= 0.00143264
# differential_evolution step 17: f(x)= 0.00143264
# differential_evolution step 18: f(x)= 0.00143264
# differential_evolution step 19: f(x)= 0.00143264
# differential_evolution step 20: f(x)= 0.00142653
# differential_evolution step 21: f(x)= 0.00142653
# differential_evolution step 22: f(x)= 0.00123878
# differential_evolution step 23: f(x)= 0.00123878
# differential_evolution step 24: f(x)= 0.000627719
# differential_evolution step 25: f(x)= 0.000627719
# differential_evolution step 26: f(x)= 0.000541381
# differential_evolution step 27: f(x)= 0.000541381
# differential_evolution step 28: f(x)= 0.000523602
# differential_evolution step 29: f(x)= 0.000490613
# differential_evolution step 30: f(x)= 0.00030841
# differential_evolution step 31: f(x)= 0.000245915
# differential_evolution step 32: f(x)= 0.000202406
# differential_evolution step 33: f(x)= 0.000202406
# differential_evolution step 34: f(x)= 0.000202406
# differential_evolution step 35: f(x)= 0.000152466
# differential_evolution step 36: f(x)= 0.000152466
# differential_evolution step 37: f(x)= 0.000152466
# differential_evolution step 38: f(x)= 0.000152466
# differential_evolution step 39: f(x)= 8.95469e-05
# differential_evolution step 40: f(x)= 8.95469e-05
# differential_evolution step 41: f(x)= 7.34598e-05
# differential_evolution step 42: f(x)= 7.34598e-05
# differential_evolution step 43: f(x)= 3.88654e-05
# differential_evolution step 44: f(x)= 3.88654e-05
# differential_evolution step 45: f(x)= 3.6785e-05
# differential_evolution step 46: f(x)= 2.96505e-05
# differential_evolution step 47: f(x)= 2.7614e-05
# differential_evolution step 48: f(x)= 1.19726e-05
# differential_evolution step 49: f(x)= 1.19726e-05
# differential_evolution step 50: f(x)= 1.19726e-05
# end diff evolution
# result was:  [0.00000000e+00 4.99999999e-01 1.81552597e-08 0.00000000e+00]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.103176
# differential_evolution step 2: f(x)= 0.0891483
# differential_evolution step 3: f(x)= 0.0860514
# differential_evolution step 4: f(x)= 0.0807608
# differential_evolution step 5: f(x)= 0.0694278
# differential_evolution step 6: f(x)= 0.0652366
# differential_evolution step 7: f(x)= 0.0652366
# differential_evolution step 8: f(x)= 0.0652366
# differential_evolution step 9: f(x)= 0.0652366
# differential_evolution step 10: f(x)= 0.0652366
# differential_evolution step 11: f(x)= 0.0652366
# differential_evolution step 12: f(x)= 0.0652366
# differential_evolution step 13: f(x)= 0.0652366
# differential_evolution step 14: f(x)= 0.0652366
# differential_evolution step 15: f(x)= 0.0652366
# differential_evolution step 16: f(x)= 0.0652366
# differential_evolution step 17: f(x)= 0.0652366
# differential_evolution step 18: f(x)= 0.0651182
# differential_evolution step 19: f(x)= 0.0651182
# differential_evolution step 20: f(x)= 0.0651182
# differential_evolution step 21: f(x)= 0.0648525
# differential_evolution step 22: f(x)= 0.0648525
# differential_evolution step 23: f(x)= 0.0648525
# differential_evolution step 24: f(x)= 0.0646993
# differential_evolution step 25: f(x)= 0.0646993
# differential_evolution step 26: f(x)= 0.0646993
# differential_evolution step 27: f(x)= 0.0642983
# differential_evolution step 28: f(x)= 0.0642983
# differential_evolution step 29: f(x)= 0.0642983
# differential_evolution step 30: f(x)= 0.0635917
# differential_evolution step 31: f(x)= 0.0635917
# differential_evolution step 32: f(x)= 0.0635917
# differential_evolution step 33: f(x)= 0.0635917
# differential_evolution step 34: f(x)= 0.0635917
# differential_evolution step 35: f(x)= 0.0635917
# differential_evolution step 36: f(x)= 0.0635917
# differential_evolution step 37: f(x)= 0.0635917
# differential_evolution step 38: f(x)= 0.0635917
# differential_evolution step 39: f(x)= 0.0635869
# differential_evolution step 40: f(x)= 0.0634726
# differential_evolution step 41: f(x)= 0.0634343
# differential_evolution step 42: f(x)= 0.0634343
# differential_evolution step 43: f(x)= 0.0634163
# differential_evolution step 44: f(x)= 0.0634163
# differential_evolution step 45: f(x)= 0.0634163
# differential_evolution step 46: f(x)= 0.0634163
# end diff evolution
# result was:  [0.01810752 0.02361159 0.32579264 0.19890063]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0934692
# differential_evolution step 2: f(x)= 0.0499819
# differential_evolution step 3: f(x)= 0.0499819
# differential_evolution step 4: f(x)= 0.0499819
# differential_evolution step 5: f(x)= 0.0367562
# differential_evolution step 6: f(x)= 0.0367562
# differential_evolution step 7: f(x)= 0.0367562
# differential_evolution step 8: f(x)= 0.0340968
# differential_evolution step 9: f(x)= 0.0340968
# differential_evolution step 10: f(x)= 0.0321724
# differential_evolution step 11: f(x)= 0.0307733
# differential_evolution step 12: f(x)= 0.0307733
# differential_evolution step 13: f(x)= 0.0305082
# differential_evolution step 14: f(x)= 0.0305082
# differential_evolution step 15: f(x)= 0.0303476
# differential_evolution step 16: f(x)= 0.0303476
# differential_evolution step 17: f(x)= 0.0298733
# differential_evolution step 18: f(x)= 0.0298733
# differential_evolution step 19: f(x)= 0.0298733
# differential_evolution step 20: f(x)= 0.0298733
# differential_evolution step 21: f(x)= 0.0298733
# differential_evolution step 22: f(x)= 0.0297824
# differential_evolution step 23: f(x)= 0.0297824
# differential_evolution step 24: f(x)= 0.0297824
# differential_evolution step 25: f(x)= 0.0297078
# differential_evolution step 26: f(x)= 0.029453
# differential_evolution step 27: f(x)= 0.029453
# differential_evolution step 28: f(x)= 0.029381
# differential_evolution step 29: f(x)= 0.029381
# differential_evolution step 30: f(x)= 0.029381
# differential_evolution step 31: f(x)= 0.029381
# differential_evolution step 32: f(x)= 0.0293323
# differential_evolution step 33: f(x)= 0.0293323
# end diff evolution
# result was:  [0.10738184 0.02579533 0.41277967 0.07062204]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0245738
# differential_evolution step 2: f(x)= 0.0245738
# differential_evolution step 3: f(x)= 0.0245738
# differential_evolution step 4: f(x)= 0.0115373
# differential_evolution step 5: f(x)= 0.00690548
# differential_evolution step 6: f(x)= 0.00690548
# differential_evolution step 7: f(x)= 0.00690548
# differential_evolution step 8: f(x)= 0.0011249
# differential_evolution step 9: f(x)= 0.0011249
# differential_evolution step 10: f(x)= 0.0011249
# differential_evolution step 11: f(x)= 0.0011249
# differential_evolution step 12: f(x)= 0.0011249
# differential_evolution step 13: f(x)= 0.0011249
# differential_evolution step 14: f(x)= 0.0011249
# differential_evolution step 15: f(x)= 0.0011249
# differential_evolution step 16: f(x)= 0.0011249
# differential_evolution step 17: f(x)= 0.0011249
# differential_evolution step 18: f(x)= 0.0011249
# differential_evolution step 19: f(x)= 0.0011249
# differential_evolution step 20: f(x)= 0.0011249
# differential_evolution step 21: f(x)= 0.000589817
# differential_evolution step 22: f(x)= 0.000589817
# differential_evolution step 23: f(x)= 0.000553067
# differential_evolution step 24: f(x)= 0.000553067
# differential_evolution step 25: f(x)= 0.000553067
# differential_evolution step 26: f(x)= 0.000553067
# differential_evolution step 27: f(x)= 0.00053998
# differential_evolution step 28: f(x)= 0.000408117
# differential_evolution step 29: f(x)= 0.000408117
# differential_evolution step 30: f(x)= 0.000278762
# differential_evolution step 31: f(x)= 0.000229676
# differential_evolution step 32: f(x)= 0.000130745
# differential_evolution step 33: f(x)= 0.000130745
# differential_evolution step 34: f(x)= 0.000130745
# differential_evolution step 35: f(x)= 0.000130745
# differential_evolution step 36: f(x)= 0.000114166
# differential_evolution step 37: f(x)= 0.000114166
# differential_evolution step 38: f(x)= 0.000104345
# differential_evolution step 39: f(x)= 0.000104345
# differential_evolution step 40: f(x)= 9.42292e-05
# differential_evolution step 41: f(x)= 9.42292e-05
# differential_evolution step 42: f(x)= 5.35949e-05
# differential_evolution step 43: f(x)= 3.08301e-05
# differential_evolution step 44: f(x)= 3.08301e-05
# differential_evolution step 45: f(x)= 3.08301e-05
# differential_evolution step 46: f(x)= 2.08401e-05
# differential_evolution step 47: f(x)= 2.08401e-05
# differential_evolution step 48: f(x)= 2.08401e-05
# differential_evolution step 49: f(x)= 2.08401e-05
# differential_evolution step 50: f(x)= 2.08401e-05
# end diff evolution
# result was:  [0.00000000e+00 5.00000141e-01 0.00000000e+00 6.74349744e-09]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0975253
# differential_evolution step 2: f(x)= 0.0930722
# differential_evolution step 3: f(x)= 0.0711634
# differential_evolution step 4: f(x)= 0.0625732
# differential_evolution step 5: f(x)= 0.0625732
# differential_evolution step 6: f(x)= 0.0602277
# differential_evolution step 7: f(x)= 0.0589177
# differential_evolution step 8: f(x)= 0.0589177
# differential_evolution step 9: f(x)= 0.0589177
# differential_evolution step 10: f(x)= 0.0589177
# differential_evolution step 11: f(x)= 0.05891
# differential_evolution step 12: f(x)= 0.0580136
# differential_evolution step 13: f(x)= 0.0580136
# differential_evolution step 14: f(x)= 0.057267
# differential_evolution step 15: f(x)= 0.057267
# differential_evolution step 16: f(x)= 0.057267
# differential_evolution step 17: f(x)= 0.0571507
# differential_evolution step 18: f(x)= 0.0550334
# differential_evolution step 19: f(x)= 0.0550334
# differential_evolution step 20: f(x)= 0.0550334
# differential_evolution step 21: f(x)= 0.0550334
# differential_evolution step 22: f(x)= 0.0550065
# differential_evolution step 23: f(x)= 0.0550065
# differential_evolution step 24: f(x)= 0.0550065
# differential_evolution step 25: f(x)= 0.0550065
# differential_evolution step 26: f(x)= 0.0550065
# differential_evolution step 27: f(x)= 0.0550065
# differential_evolution step 28: f(x)= 0.0550065
# differential_evolution step 29: f(x)= 0.0545565
# differential_evolution step 30: f(x)= 0.0545565
# differential_evolution step 31: f(x)= 0.0545565
# differential_evolution step 32: f(x)= 0.0545565
# differential_evolution step 33: f(x)= 0.0545565
# differential_evolution step 34: f(x)= 0.0545565
# differential_evolution step 35: f(x)= 0.0545565
# differential_evolution step 36: f(x)= 0.0542155
# differential_evolution step 37: f(x)= 0.0541907
# differential_evolution step 38: f(x)= 0.0541907
# differential_evolution step 39: f(x)= 0.0541907
# differential_evolution step 40: f(x)= 0.0541907
# differential_evolution step 41: f(x)= 0.0541907
# differential_evolution step 42: f(x)= 0.0537241
# differential_evolution step 43: f(x)= 0.0537241
# differential_evolution step 44: f(x)= 0.0537241
# differential_evolution step 45: f(x)= 0.0537241
# differential_evolution step 46: f(x)= 0.0537241
# differential_evolution step 47: f(x)= 0.0537241
# differential_evolution step 48: f(x)= 0.0537241
# differential_evolution step 49: f(x)= 0.0536925
# differential_evolution step 50: f(x)= 0.0536925
# end diff evolution
# result was:  [1.30037384e-03 2.79978521e-01 3.01177398e-01 1.56869913e-07]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.091694
# differential_evolution step 2: f(x)= 0.0837391
# differential_evolution step 3: f(x)= 0.0837391
# differential_evolution step 4: f(x)= 0.083236
# differential_evolution step 5: f(x)= 0.0801963
# differential_evolution step 6: f(x)= 0.0801963
# differential_evolution step 7: f(x)= 0.0787683
# differential_evolution step 8: f(x)= 0.0730326
# differential_evolution step 9: f(x)= 0.0705533
# differential_evolution step 10: f(x)= 0.0705533
# differential_evolution step 11: f(x)= 0.0705533
# differential_evolution step 12: f(x)= 0.0705533
# differential_evolution step 13: f(x)= 0.0697801
# differential_evolution step 14: f(x)= 0.0697801
# differential_evolution step 15: f(x)= 0.0697801
# differential_evolution step 16: f(x)= 0.0695605
# differential_evolution step 17: f(x)= 0.0677933
# differential_evolution step 18: f(x)= 0.0677933
# differential_evolution step 19: f(x)= 0.0677933
# differential_evolution step 20: f(x)= 0.0677933
# differential_evolution step 21: f(x)= 0.0677933
# differential_evolution step 22: f(x)= 0.0674921
# differential_evolution step 23: f(x)= 0.0674921
# differential_evolution step 24: f(x)= 0.0674921
# differential_evolution step 25: f(x)= 0.0671453
# differential_evolution step 26: f(x)= 0.0671453
# differential_evolution step 27: f(x)= 0.0671453
# differential_evolution step 28: f(x)= 0.0671453
# differential_evolution step 29: f(x)= 0.0671453
# differential_evolution step 30: f(x)= 0.0671453
# differential_evolution step 31: f(x)= 0.0671453
# differential_evolution step 32: f(x)= 0.0671453
# differential_evolution step 33: f(x)= 0.0671453
# differential_evolution step 34: f(x)= 0.0671453
# differential_evolution step 35: f(x)= 0.0671453
# differential_evolution step 36: f(x)= 0.0671453
# differential_evolution step 37: f(x)= 0.0671453
# differential_evolution step 38: f(x)= 0.0671453
# differential_evolution step 39: f(x)= 0.0671453
# differential_evolution step 40: f(x)= 0.0671453
# differential_evolution step 41: f(x)= 0.0671453
# differential_evolution step 42: f(x)= 0.0671453
# differential_evolution step 43: f(x)= 0.0671453
# differential_evolution step 44: f(x)= 0.0671453
# differential_evolution step 45: f(x)= 0.0671453
# differential_evolution step 46: f(x)= 0.0671453
# differential_evolution step 47: f(x)= 0.0671453
# differential_evolution step 48: f(x)= 0.0671453
# differential_evolution step 49: f(x)= 0.0671453
# differential_evolution step 50: f(x)= 0.0671453
# end diff evolution
# result was:  [0.31570002 0.22728042 0.13274335 0.01447751]
# begin diff evolution
# differential_evolution step 1: f(x)= 0.0520044
# differential_evolution step 2: f(x)= 0.0304737
# differential_evolution step 3: f(x)= 0.0304737
# differential_evolution step 4: f(x)= 0.029792
# differential_evolution step 5: f(x)= 0.0278318
# differential_evolution step 6: f(x)= 0.0278318
# differential_evolution step 7: f(x)= 0.0278318
# differential_evolution step 8: f(x)= 0.026764
# differential_evolution step 9: f(x)= 0.0225394
# differential_evolution step 10: f(x)= 0.0224857
# differential_evolution step 11: f(x)= 0.0215234
# differential_evolution step 12: f(x)= 0.0215234
# differential_evolution step 13: f(x)= 0.0215234
# differential_evolution step 14: f(x)= 0.0215234
# differential_evolution step 15: f(x)= 0.0214687
# differential_evolution step 16: f(x)= 0.0214002
# differential_evolution step 17: f(x)= 0.0214002
# differential_evolution step 18: f(x)= 0.0214002
# differential_evolution step 19: f(x)= 0.0211598
# differential_evolution step 20: f(x)= 0.0211598
# differential_evolution step 21: f(x)= 0.0210853
# differential_evolution step 22: f(x)= 0.0210853
# differential_evolution step 23: f(x)= 0.0208335
# differential_evolution step 24: f(x)= 0.0208335
# differential_evolution step 25: f(x)= 0.0205958
# differential_evolution step 26: f(x)= 0.019838
# differential_evolution step 27: f(x)= 0.0197373
# differential_evolution step 28: f(x)= 0.0197373
# differential_evolution step 29: f(x)= 0.0194958
# differential_evolution step 30: f(x)= 0.0194958
# differential_evolution step 31: f(x)= 0.0194958
# differential_evolution step 32: f(x)= 0.0194958
# differential_evolution step 33: f(x)= 0.0194958
# differential_evolution step 34: f(x)= 0.0191438
# differential_evolution step 35: f(x)= 0.0191438
# differential_evolution step 36: f(x)= 0.0191438
# differential_evolution step 37: f(x)= 0.0191438
# differential_evolution step 38: f(x)= 0.0191438
# differential_evolution step 39: f(x)= 0.0191438
# differential_evolution step 40: f(x)= 0.0191438
# differential_evolution step 41: f(x)= 0.0191438
# differential_evolution step 42: f(x)= 0.0190847
# differential_evolution step 43: f(x)= 0.0190678
# differential_evolution step 44: f(x)= 0.0190678
# differential_evolution step 45: f(x)= 0.0190678
# differential_evolution step 46: f(x)= 0.0190212
# differential_evolution step 47: f(x)= 0.0190212
# differential_evolution step 48: f(x)= 0.0190212
# differential_evolution step 49: f(x)= 0.0190212
# differential_evolution step 50: f(x)= 0.0190212
# end diff evolution
# result was:  [2.36352483e-04 1.36333650e-01 3.71702609e-01 4.47765143e-02]
# integrating geodesic

# %%
for i in range(12):
    print('vals: ', (g_twelve[0][i,:].reshape([28,28])[14,13:17]))
    plt.imshow(g_twelve[0][i,:].reshape([28,28]))
    plt.show()
# Out:
# vals:  [0.5 0.  0.  0. ]
# vals:  [0.31570002 0.22728042 0.13274335 0.01447751]
# vals:  [0.00000000e+00 5.00000141e-01 0.00000000e+00 6.74349744e-09]
# vals:  [0.00000000e+00 4.99999999e-01 1.81552597e-08 0.00000000e+00]
# vals:  [1.30037384e-03 2.79978521e-01 3.01177398e-01 1.56869913e-07]
# vals:  [2.36352483e-04 1.36333650e-01 3.71702609e-01 4.47765143e-02]
# vals:  [0.10738184 0.02579533 0.41277967 0.07062204]
# vals:  [0.01810752 0.02361159 0.32579264 0.19890063]
# vals:  [0.  0.  0.  0.5]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-22f5ba152f26> in <module>()
#       1 for i in range(12):
# ----> 2     print('vals: ', (g_twelve[0][i,:].reshape([28,28])[14,13:17]))
#       3     plt.imshow(g_twelve[0][i,:].reshape([28,28]))
#       4     plt.show()
#
# IndexError: index 9 is out of bounds for axis 0 with size 9

# %%
g_twelve[1]
# Out:
# [0.1988582764066274,
#  0.167671222327094,
#  0.10957027188020135,
#  0.10208269782729407,
#  0.10005653287269269,
#  0.0960075563248525,
#  0.09275266509019617,
#  0.09143386657928118,
#  0.09128313742386317,
#  0.08454497982962465,
#  0.08389079433946443,
#  0.08938406803726096,
#  0.08254487981989553]

# %%
distance_geod_array(g_twelve[0])
# Out:
# integrating geodesic
# array([0.01080757, 0.00945182, 0.00954318, 0.00951346, 0.00954071,
#        0.0115688 , 0.0110219 , 0.01109744])

# %%
distance_geod_array(g_twelve[0])
# Out:
# integrating geodesic
# array([0.01080757, 0.00945182, 0.00954318, 0.00951346, 0.00954071,
#        0.01122702, 0.01423135, 0.01547557])

# %%
np.sum(distance_geod_array(g_twelve[0]))
# Out:
# integrating geodesic
# 0.08979067849187078

# %%
import cProfile

# %%
cProfile.run('integrate.romberg(lambda t: interp_integrand(g_twelve[0][0,:], g_twelve[0][8,:], t), 0, 1, tol=1e-3, rtol=1e-5)')
# Out:
#          10334 function calls (10208 primitive calls) in 0.119 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         9    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#         9    0.000    0.000    0.068    0.008 <ipython-input-22-87ff647bb1a2>:2(compute_vec_grad)
#         9    0.015    0.002    0.115    0.013 <ipython-input-23-452a847b6082>:1(compute_metric)
#         9    0.001    0.000    0.118    0.013 <ipython-input-24-a19eec878bcc>:1(interp_integrand)
#         9    0.000    0.000    0.118    0.013 <string>:1(<lambda>)
#         1    0.000    0.000    0.119    0.119 <string>:1(<module>)
#         9    0.000    0.000    0.000    0.000 <string>:12(__new__)
#         3    0.000    0.000    0.000    0.000 _methods.py:31(_sum)
#        42    0.000    0.000    0.000    0.000 _weakrefset.py:70(__contains__)
#        21    0.000    0.000    0.000    0.000 abc.py:180(__instancecheck__)
#       108    0.000    0.000    0.002    0.000 c_api_util.py:125(tf_output)
#        18    0.000    0.000    0.000    0.000 compat.py:48(as_bytes)
#         9    0.000    0.000    0.000    0.000 context.py:117(push)
#         9    0.000    0.000    0.000    0.000 context.py:133(pop)
#         9    0.000    0.000    0.000    0.000 context.py:302(executing_eagerly)
#        18    0.000    0.000    0.000    0.000 context.py:544(context_switches)
#        27    0.000    0.000    0.000    0.000 context.py:560(context)
#         9    0.000    0.000    0.000    0.000 context.py:594(executing_eagerly)
#        18    0.000    0.000    0.000    0.000 contextlib.py:157(helper)
#        18    0.000    0.000    0.000    0.000 contextlib.py:59(__init__)
#      18/9    0.000    0.000    0.000    0.000 contextlib.py:79(__enter__)
#      18/9    0.000    0.000    0.000    0.000 contextlib.py:85(__exit__)
#        18    0.000    0.000    0.000    0.000 dtypes.py:129(as_numpy_dtype)
#         3    0.000    0.000    0.000    0.000 fromnumeric.py:1778(sum)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:50(_wrapfunc)
#         9    0.000    0.000    0.000    0.000 fromnumeric.py:529(transpose)
#        18    0.000    0.000    0.000    0.000 nest.py:106(is_sequence)
#         9    0.000    0.000    0.000    0.000 nest.py:186(flatten_dict_items)
#         5    0.000    0.000    0.000    0.000 numeric.py:1917(isscalar)
#         9    0.000    0.000    0.009    0.001 numeric.py:2157(identity)
#        30    0.000    0.000    0.000    0.000 numeric.py:424(asarray)
#       108    0.000    0.000    0.000    0.000 ops.py:109(_as_graph_element)
#        54    0.000    0.000    0.000    0.000 ops.py:1850(name)
#       180    0.000    0.000    0.001    0.000 ops.py:2218(type)
#       108    0.000    0.000    0.000    0.000 ops.py:2227(graph)
#         9    0.000    0.000    0.000    0.000 ops.py:3036(version)
#       504    0.000    0.000    0.000    0.000 ops.py:315(op)
#        18    0.000    0.000    0.000    0.000 ops.py:320(dtype)
#       108    0.000    0.000    0.000    0.000 ops.py:325(graph)
#        18    0.000    0.000    0.000    0.000 ops.py:330(name)
#         9    0.000    0.000    0.000    0.000 ops.py:3309(building_function)
#        18    0.000    0.000    0.000    0.000 ops.py:342(shape)
#       108    0.000    0.000    0.001    0.000 ops.py:3557(as_graph_element)
#       108    0.000    0.000    0.000    0.000 ops.py:3592(_as_graph_element_locked)
#         9    0.000    0.000    0.000    0.000 ops.py:3809(as_default)
#        18    0.000    0.000    0.000    0.000 ops.py:472(get_shape)
#        18    0.000    0.000    0.000    0.000 ops.py:4838(is_feedable)
#        90    0.000    0.000    0.000    0.000 ops.py:4846(is_fetchable)
#        90    0.000    0.000    0.000    0.000 ops.py:5038(get_default)
#        18    0.000    0.000    0.000    0.000 ops.py:5055(get_controller)
#        90    0.000    0.000    0.000    0.000 ops.py:5225(get_default)
#        18    0.000    0.000    0.000    0.000 ops.py:5245(get_controller)
#       108    0.000    0.000    0.000    0.000 ops.py:540(value_index)
#        90    0.000    0.000    0.000    0.000 ops.py:5522(get_default_graph)
#       108    0.000    0.000    0.002    0.000 ops.py:598(_as_tf_output)
#       630    0.000    0.000    0.000    0.000 ops.py:616(__hash__)
#       324    0.000    0.000    0.000    0.000 pywrap_tensorflow_internal.py:39(_swig_setattr_nondynamic)
#       324    0.000    0.000    0.001    0.000 pywrap_tensorflow_internal.py:58(_swig_setattr)
#       108    0.000    0.000    0.000    0.000 pywrap_tensorflow_internal.py:62(_swig_getattr_nondynamic)
#       108    0.000    0.000    0.000    0.000 pywrap_tensorflow_internal.py:73(_swig_getattr)
#       324    0.000    0.000    0.001    0.000 pywrap_tensorflow_internal.py:943(<lambda>)
#       108    0.000    0.000    0.000    0.000 pywrap_tensorflow_internal.py:945(<lambda>)
#       108    0.000    0.000    0.001    0.000 pywrap_tensorflow_internal.py:956(__init__)
#       108    0.000    0.000    0.000    0.000 pywrap_tensorflow_internal.py:963(<lambda>)
#         5    0.000    0.000    0.119    0.024 quadrature.py:119(vfunc)
#         4    0.000    0.000    0.119    0.030 quadrature.py:587(_difftrap)
#         6    0.000    0.000    0.000    0.000 quadrature.py:613(_romberg_diff)
#         1    0.000    0.000    0.119    0.119 quadrature.py:639(romberg)
#         1    0.000    0.000    0.000    0.000 quadrature.py:90(vectorize1)
#         9    0.001    0.000    0.068    0.008 session.py:1046(_run)
#        18    0.000    0.000    0.000    0.000 session.py:1049(_feed_fn)
#        90    0.000    0.000    0.000    0.000 session.py:125(<lambda>)
#        18    0.000    0.000    0.000    0.000 session.py:126(<lambda>)
#         9    0.000    0.000    0.062    0.007 session.py:1271(_do_run)
#        27    0.000    0.000    0.001    0.000 session.py:1294(<genexpr>)
#         9    0.000    0.000    0.002    0.000 session.py:1295(<listcomp>)
#         9    0.000    0.000    0.000    0.000 session.py:1296(<listcomp>)
#         9    0.000    0.000    0.059    0.007 session.py:1303(_run_fn)
#         9    0.000    0.000    0.059    0.007 session.py:1320(_do_call)
#         9    0.000    0.000    0.000    0.000 session.py:1337(_extend_graph)
#         9    0.000    0.000    0.000    0.000 session.py:1378(_update_with_movers)
#         9    0.000    0.000    0.059    0.007 session.py:1404(_call_tf_sessionrun)
#      99/9    0.000    0.000    0.002    0.000 session.py:226(for_fetch)
#        90    0.000    0.000    0.001    0.000 session.py:262(__init__)
#        90    0.000    0.000    0.000    0.000 session.py:295(unique_fetches)
#        90    0.000    0.000    0.000    0.000 session.py:298(build_results)
#         9    0.000    0.000    0.000    0.000 session.py:306(_uniquify_fetches)
#         9    0.000    0.000    0.002    0.000 session.py:345(__init__)
#         9    0.000    0.000    0.001    0.000 session.py:352(<listcomp>)
#         9    0.000    0.000    0.000    0.000 session.py:355(unique_fetches)
#         9    0.000    0.000    0.000    0.000 session.py:358(build_results)
#        90    0.000    0.000    0.000    0.000 session.py:362(<listcomp>)
#         9    0.000    0.000    0.004    0.000 session.py:414(__init__)
#         9    0.000    0.000    0.000    0.000 session.py:448(<listcomp>)
#        90    0.000    0.000    0.000    0.000 session.py:450(_assert_fetchable)
#         9    0.000    0.000    0.000    0.000 session.py:455(fetches)
#         9    0.000    0.000    0.000    0.000 session.py:463(targets)
#         9    0.000    0.000    0.001    0.000 session.py:471(build_results)
#        63    0.000    0.000    0.000    0.000 session.py:717(graph)
#         9    0.000    0.000    0.068    0.008 session.py:790(run)
#        18    0.000    0.000    0.000    0.000 session_ops.py:256(_get_handle_feeder)
#        18    0.000    0.000    0.000    0.000 session_ops.py:276(_get_handle_mover)
#         9    0.000    0.000    0.000    0.000 six.py:586(iteritems)
#        18    0.000    0.000    0.000    0.000 tensor_shape.py:30(__init__)
#        36    0.000    0.000    0.000    0.000 tensor_shape.py:463(as_dimension)
#        18    0.000    0.000    0.000    0.000 tensor_shape.py:503(__init__)
#        18    0.000    0.000    0.000    0.000 tensor_shape.py:538(<listcomp>)
#        18    0.000    0.000    0.000    0.000 tensor_shape.py:552(dims)
#        18    0.000    0.000    0.000    0.000 tensor_shape.py:562(ndims)
#        18    0.000    0.000    0.000    0.000 tensor_shape.py:784(is_compatible_with)
#        18    0.000    0.000    0.000    0.000 tensor_shape.py:83(value)
#        18    0.000    0.000    0.000    0.000 tensor_shape.py:88(is_compatible_with)
#        18    0.000    0.000    0.000    0.000 tensor_shape.py:935(as_shape)
#         9    0.007    0.001    0.009    0.001 twodim_base.py:140(eye)
#         9    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x10b399850}
#         9    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.ExtendSession}
#        18    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.IsSequence}
#        54    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.TF_OperationName}
#       180    0.001    0.000    0.001    0.000 {built-in method _pywrap_tensorflow_internal.TF_OperationOpType}
#       108    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.TF_Output_index_set}
#       108    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.TF_Output_oper_set}
#         9    0.059    0.007    0.059    0.007 {built-in method _pywrap_tensorflow_internal.TF_SessionRun_wrapper}
#       108    0.000    0.000    0.000    0.000 {built-in method _pywrap_tensorflow_internal.new_TF_Output}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#         1    0.000    0.000    0.119    0.119 {built-in method builtins.exec}
#       138    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       630    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#      1244    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        27    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#       228    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#     36/18    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.arange}
#        30    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.array}
#        27    0.025    0.001    0.025    0.001 {built-in method numpy.core.multiarray.dot}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.core.multiarray.empty}
#         9    0.001    0.000    0.001    0.000 {built-in method numpy.core.multiarray.zeros}
#       744    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        18    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#       612    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        36    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        18    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        18    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         9    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
